# %% [markdown]
# # 📂 **Project: Automatic Argumentation Analysis - Naive Approach**
#
# In this notebook, we implement a **basic argument mining system** from scratch using the [PyTorch](https://pytorch.org) library. This **naive approach** serves as an initial step in exploring **argumentation analysis** by focusing on simplified techniques, which are essential for understanding the core components of the task.
#
# The implementation includes **simple modeling approaches**, closely mirroring functionalities often found in **advanced libraries** like [Huggingface](https://huggingface.co). This makes the project an excellent starting point for learning about the fundamental building blocks of **argument mining**, including **tokenizers**, **datasets**, and **basic models**. It provides a solid foundation to build on and transition to more sophisticated methods, such as using **Large Language Models (LLMs)**.
#
# This naive implementation also lays the groundwork for the **enhanced approach** that we will explore later, where we replace these basic techniques with **state-of-the-art LLMs** to improve accuracy and scalability.
#
# Authors: **Nassim Lattab** and **Mohamed Azzaoui**.
#
# ---

# %% [markdown]
# ### Preparing the environment and uploading data

# %%
# %cd /content
# !ls
# !rm -rf /content/*

# !git clone https://github.com/bencrabbe/argumentation_base.git
# %cd argumentation_base

# !git pull origin main

# %cd data
# !sh download_data.sh

# %cd ..
# Out:
# /content
# argumentation_base
# Cloning into 'argumentation_base'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 77 (delta 35), reused 61 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (77/77), 18.50 KiB | 1.32 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/argumentation_base
# From https://github.com/bencrabbe/argumentation_base
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# /content/argumentation_base/data
# --2024-12-25 19:42:59--  https://tudatalib.ulb.tu-darmstadt.de/bitstream/handle/tudatalib/2422/ArgumentAnnotatedEssays-2.0.zip
# Resolving tudatalib.ulb.tu-darmstadt.de (tudatalib.ulb.tu-darmstadt.de)... 130.83.152.157
# Connecting to tudatalib.ulb.tu-darmstadt.de (tudatalib.ulb.tu-darmstadt.de)|130.83.152.157|:443... connected.
# HTTP request sent, awaiting response... 200 200
# Length: unspecified [application/zip]
# Saving to: ‘ArgumentAnnotatedEssays-2.0.zip’
#
# ArgumentAnnotatedEs     [    <=>             ]   1.97M  1.95MB/s    in 1.0s
#
# 2024-12-25 19:43:00 (1.95 MB/s) - ‘ArgumentAnnotatedEssays-2.0.zip’ saved [2064482]
#
# Archive:  ArgumentAnnotatedEssays-2.0.zip
#    creating: ArgumentAnnotatedEssays-2.0/
#   inflating: ArgumentAnnotatedEssays-2.0/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/ArgumentAnnotatedEssays-2.0/
#   inflating: __MACOSX/ArgumentAnnotatedEssays-2.0/._.DS_Store
#   inflating: ArgumentAnnotatedEssays-2.0/brat-project-final.zip
#   inflating: ArgumentAnnotatedEssays-2.0/guideline.pdf
#   inflating: __MACOSX/ArgumentAnnotatedEssays-2.0/._guideline.pdf
#   inflating: ArgumentAnnotatedEssays-2.0/license.pdf
#   inflating: __MACOSX/ArgumentAnnotatedEssays-2.0/._license.pdf
#   inflating: ArgumentAnnotatedEssays-2.0/prompts.csv
#   inflating: ArgumentAnnotatedEssays-2.0/README.txt
#   inflating: __MACOSX/ArgumentAnnotatedEssays-2.0/._README.txt
#   inflating: ArgumentAnnotatedEssays-2.0/train-test-split.csv
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 49	assigned	O
# 50	1077	O
# 51	patients	O
# 52	to	O
# 53	receive	O
# 54	docetaxel	O
# 55	at	O
# 56	75	O
# 57	mg	O
# 58	/	O
# 59	m2	O
# 60	of	O
# 61	body	O
# 62	surface	O
# 63	area	O
# 64	(	O
# 65	1	O
# 66	-	O
# 67	hour	O
# 68	intravenous	O
# 69	infusion	O
# 70	)	O
# 71	or	O
# 72	paclitaxel	O
# 73	at	O
# 74	175	O
# 75	mg	O
# 76	/	O
# 77	m2	O
# 78	(	O
# 79	3	O
# 80	-	O
# 81	hour	O
# 82	intravenous	O
# 83	infusion	O
# 84	)	O
# 85	.	O
# 86	Both	O
# 87	treatments	O
# 88	then	O
# 89	were	O
# 90	followed	O
# 91	by	O
# 92	carboplatin	O
# 93	to	O
# 94	an	O
# 95	area	O
# 96	under	O
# 97	the	O
# 98	plasma	O
# 99	concentration-time	O
# 100	curve	O
# 101	of	O
# 102	5	O
# 103	.	O
# 104	The	O
# 105	treatments	O
# 106	were	O
# 107	repeated	O
# 108	every	O
# 109	3	O
# 110	weeks	O
# 111	for	O
# 112	six	O
# 113	cycles	O
# 114	;	O
# 115	in	O
# 116	responding	O
# 117	patients	O
# 118	,	O
# 119	an	O
# 120	additional	O
# 121	three	O
# 122	cycles	O
# 123	of	O
# 124	single-agent	O
# 125	carboplatin	O
# 126	was	O
# 127	permitted	O
# 128	.	O
# 129	Survival	O
# 130	curves	O
# 131	were	O
# 132	calculated	O
# 133	by	O
# 134	the	O
# 135	Kaplan-Meier	O
# 136	method	O
# 137	,	O
# 138	and	O
# 139	hazard	O
# 140	ratios	O
# 141	were	O
# 142	estimated	O
# 143	with	O
# 144	the	O
# 145	Cox	O
# 146	proportional	O
# 147	hazards	O
# 148	model	O
# 149	.	O
# 150	All	O
# 151	statistical	O
# 152	tests	O
# 153	were	O
# 154	two-sided	O
# 155	.	O
# 156	After	B-Premise
# 157	a	I-Premise
# 158	median	I-Premise
# 159	follow-up	I-Premise
# 160	of	I-Premise
# 161	23	I-Premise
# 162	months	I-Premise
# 163	,	I-Premise
# 164	both	I-Premise
# 165	groups	I-Premise
# 166	had	I-Premise
# 167	similar	I-Premise
# 168	progression-free	I-Premise
# 169	survival	I-Premise
# 170	(	I-Premise
# 171	medians	I-Premise
# 172	of	I-Premise
# 173	15.0	I-Premise
# 174	months	I-Premise
# 175	for	I-Premise
# 176	docetaxel-carboplatin	I-Premise
# 177	and	I-Premise
# 178	14.8	I-Premise
# 179	months	I-Premise
# 180	for	I-Premise
# 181	paclitaxel-carboplatin	I-Premise
# 182	;	I-Premise
# 183	hazard	I-Premise
# 184	ratio	I-Premise
# 185	[	I-Premise
# 186	HR	I-Premise
# 187	]	I-Premise
# 188	docetaxel-paclitaxel	I-Premise
# 189	=	I-Premise
# 190	0.97	I-Premise
# 191	,	I-Premise
# 192	95	I-Premise
# 193	%	I-Premise
# 194	confidence	I-Premise
# 195	interval	I-Premise
# 196	[	I-Premise
# 197	CI	I-Premise
# 198	]	I-Premise
# 199	=	I-Premise
# 200	0.83	I-Premise
# 201	to	I-Premise
# 202	1.13	I-Premise
# 203	;	I-Premise
# 204	P	I-Premise
# 205	=	I-Premise
# 206	.	I-Premise
# 207	707	I-Premise
# 208	)	I-Premise
# 209	,	I-Premise
# 210	overall	I-Premise
# 211	survival	I-Premise
# 212	rates	I-Premise
# 213	at	I-Premise
# 214	2	I-Premise
# 215	years	I-Premise
# 216	(	I-Premise
# 217	64.2	I-Premise
# 218	%	I-Premise
# 219	and	I-Premise
# 220	68.9	I-Premise
# 221	%	I-Premise
# 222	,	I-Premise
# 223	respectively	I-Premise
# 224	;	I-Premise
# 225	HR	I-Premise
# 226	=	I-Premise
# 227	1.13	I-Premise
# 228	,	I-Premise
# 229	95	I-Premise
# 230	%	I-Premise
# 231	CI	I-Premise
# 232	=	I-Premise
# 233	0.92	I-Premise
# 234	to	I-Premise
# 235	1.39	I-Premise
# 236	;	I-Premise
# 237	P	I-Premise
# 238	=	I-Premise
# 239	.	I-Premise
# 240	238	I-Premise
# 241	)	I-Premise
# 242	,	I-Premise
# 243	and	I-Premise
# 244	objective	I-Premise
# 245	tumor	I-Premise
# 246	(	I-Premise
# 247	58.7	I-Premise
# 248	%	I-Premise
# 249	and	I-Premise
# 250	59.5	I-Premise
# 251	%	I-Premise
# 252	,	I-Premise
# 253	respectively	I-Premise
# 254	;	I-Premise
# 255	difference	I-Premise
# 256	between	I-Premise
# 257	docetaxel	I-Premise
# 258	and	I-Premise
# 259	paclitaxel	I-Premise
# 260	=	I-Premise
# 261	-0.8	I-Premise
# 262	%	I-Premise
# 263	,	I-Premise
# 264	95	I-Premise
# 265	%	I-Premise
# 266	CI	I-Premise
# 267	=	I-Premise
# 268	-8.6	I-Premise
# 269	%	I-Premise
# 270	to	I-Premise
# 271	7.1	I-Premise
# 272	%	I-Premise
# 273	;	I-Premise
# 274	P	I-Premise
# 275	=	I-Premise
# 276	.	I-Premise
# 277	868	I-Premise
# 278	)	I-Premise
# 279	and	I-Premise
# 280	CA	I-Premise
# 281	-	I-Premise
# 282	125	I-Premise
# 283	(	I-Premise
# 284	75.8	I-Premise
# 285	%	I-Premise
# 286	and	I-Premise
# 287	76.8	I-Premise
# 288	%	I-Premise
# 289	,	I-Premise
# 290	respectively	I-Premise
# 291	;	I-Premise
# 292	difference	I-Premise
# 293	docetaxel-paclitaxel	I-Premise
# 294	=	I-Premise
# 295	-1.0	I-Premise
# 296	%	I-Premise
# 297	,	I-Premise
# 298	95	I-Premise
# 299	%	I-Premise
# 300	CI	I-Premise
# 301	=	I-Premise
# 302	-7.2	I-Premise
# 303	%	I-Premise
# 304	to	I-Premise
# 305	5.1	I-Premise
# 306	%	I-Premise
# 307	;	I-Premise
# 308	P	I-Premise
# 309	=	I-Premise
# 310	.	I-Premise
# 311	794	I-Premise
# 312	)	I-Premise
# 313	response	I-Premise
# 314	rates	I-Premise
# 315	.	O
# 316	However	B-Premise
# 317	,	I-Premise
# 318	docetaxel-carboplatin	I-Premise
# 319	was	I-Premise
# 320	associated	I-Premise
# 321	with	I-Premise
# 322	substantially	I-Premise
# 323	less	I-Premise
# 324	overall	I-Premise
# 325	and	I-Premise
# 326	grade	I-Premise
# 327	2	I-Premise
# 328	or	I-Premise
# 329	higher	I-Premise
# 330	neurotoxicity	I-Premise
# 331	than	I-Premise
# 332	paclitaxel-carboplatin	I-Premise
# 333	(	I-Premise
# 334	grade	I-Premise
# 335	>	I-Premise
# 336	or	I-Premise
# 337	=	I-Premise
# 338	2	I-Premise
# 339	neurosensory	I-Premise
# 340	toxicity	I-Premise
# 341	in	I-Premise
# 342	11	I-Premise
# 343	%	I-Premise
# 344	versus	I-Premise
# 345	30	I-Premise
# 346	%	I-Premise
# 347	,	I-Premise
# 348	difference	I-Premise
# 349	=	I-Premise
# 350	19	I-Premise
# 351	%	I-Premise
# 352	,	I-Premise
# 353	95	I-Premise
# 354	%	I-Premise
# 355	CI	I-Premise
# 356	=	I-Premise
# 357	15	I-Premise
# 358	%	I-Premise
# 359	to	I-Premise
# 360	24	I-Premise
# 361	%	I-Premise
# 362	;	I-Premise
# 363	P	I-Premise
# 364	<	I-Premise
# 365	.	I-Premise
# 366	001	I-Premise
# 367	;	I-Premise
# 368	grade	I-Premise
# 369	>	I-Premise
# 370	or	I-Premise
# 371	=	I-Premise
# 372	2	I-Premise
# 373	neuromotor	I-Premise
# 374	toxicity	I-Premise
# 375	in	I-Premise
# 376	3	I-Premise
# 377	%	I-Premise
# 378	versus	I-Premise
# 379	7	I-Premise
# 380	%	I-Premise
# 381	,	I-Premise
# 382	difference	I-Premise
# 383	=	I-Premise
# 384	4	I-Premise
# 385	%	I-Premise
# 386	,	I-Premise
# 387	95	I-Premise
# 388	%	I-Premise
# 389	CI	I-Premise
# 390	=	I-Premise
# 391	1	I-Premise
# 392	%	I-Premise
# 393	to	I-Premise
# 394	7	I-Premise
# 395	%	I-Premise
# 396	;	I-Premise
# 397	P	I-Premise
# 398	<	I-Premise
# 399	.	I-Premise
# 400	001	I-Premise
# 401	)	I-Premise
# 402	.	O
# 403	Treatment	B-Premise
# 404	with	I-Premise
# 405	docetaxel-carboplatin	I-Premise
# 406	was	I-Premise
# 407	associated	I-Premise
# 408	with	I-Premise
# 409	statistically	I-Premise
# 410	significantly	I-Premise
# 411	more	I-Premise
# 412	grade	I-Premise
# 413	3-4	I-Premise
# 414	neutropenia	I-Premise
# 415	(	I-Premise
# 416	94	I-Premise
# 417	%	I-Premise
# 418	versus	I-Premise
# 419	84	I-Premise
# 420	%	I-Premise
# 421	,	I-Premise
# 422	difference	I-Premise
# 423	=	I-Premise
# 424	11	I-Premise
# 425	%	I-Premise
# 426	,	I-Premise
# 427	95	I-Premise
# 428	%	I-Premise
# 429	CI	I-Premise
# 430	=	I-Premise
# 431	7	I-Premise
# 432	%	I-Premise
# 433	to	I-Premise
# 434	14	I-Premise
# 435	%	I-Premise
# 436	;	I-Premise
# 437	P	I-Premise
# 438	<	I-Premise
# 439	.	I-Premise
# 440	001	I-Premise
# 441	)	I-Premise
# 442	and	I-Premise
# 443	neutropenic	I-Premise
# 444	complications	I-Premise
# 445	than	I-Premise
# 446	treatment	I-Premise
# 447	with	I-Premise
# 448	paclitaxel-carboplatin	I-Premise
# 449	,	O
# 450	although	B-Premise
# 451	myelosuppression	I-Premise
# 452	did	I-Premise
# 453	not	I-Premise
# 454	influence	I-Premise
# 455	dose	I-Premise
# 456	delivery	I-Premise
# 457	or	I-Premise
# 458	patient	I-Premise
# 459	safety	I-Premise
# 460	.	O
# 461	Global	B-Premise
# 462	quality	I-Premise
# 463	of	I-Premise
# 464	life	I-Premise
# 465	was	I-Premise
# 466	similar	I-Premise
# 467	in	I-Premise
# 468	both	I-Premise
# 469	arms	I-Premise
# 470	,	O
# 471	but	B-Premise
# 472	substantive	I-Premise
# 473	differences	I-Premise
# 474	in	I-Premise
# 475	many	I-Premise
# 476	symptom	I-Premise
# 477	scores	I-Premise
# 478	favored	I-Premise
# 479	docetaxel	I-Premise
# 480	.	O
# 481	Docetaxel-carboplatin	B-Claim
# 482	appears	I-Claim
# 483	to	I-Claim
# 484	be	I-Claim
# 485	similar	I-Claim
# 486	to	I-Claim
# 487	paclitaxel-carboplatin	I-Claim
# 488	in	I-Claim
# 489	terms	I-Claim
# 490	of	I-Claim
# 491	progression-free	I-Claim
# 492	survival	I-Claim
# 493	and	I-Claim
# 494	response	I-Claim
# 495	,	O
# 496	although	B-Claim
# 497	longer	I-Claim
# 498	follow-up	I-Claim
# 499	is	I-Claim
# 500	required	I-Claim
# 501	for	I-Claim
# 502	a	I-Claim
# 503	definitive	I-Claim
# 504	statement	I-Claim
# 505	on	I-Claim
# 506	survival	I-Claim
# 507	.	O
# 508	Thus	B-MajorClaim
# 509	,	I-MajorClaim
# 510	docetaxel-carboplatin	I-MajorClaim
# 511	represents	I-MajorClaim
# 512	an	I-MajorClaim
# 513	alternative	I-MajorClaim
# 514	first-line	I-MajorClaim
# 515	chemotherapy	I-MajorClaim
# 516	regimen	I-MajorClaim
# 517	for	I-MajorClaim
# 518	patients	I-MajorClaim
# 519	with	I-MajorClaim
# 520	newly	I-MajorClaim
# 521	diagnosed	I-MajorClaim
# 522	ovarian	I-MajorClaim
# 523	cancer	I-MajorClaim
# 524	.	O
#
# (496, 507)	Partial-Attack	(481, 495)
# (481, 495)	Support	(508, 524)
# (471, 480)	Partial-Attack	(461, 470)
# (450, 460)	Partial-Attack	(403, 449)
# (156, 315)	Support	(481, 495)
# (316, 402)	Support	(471, 480)
#
# 0	The	O
# 1	majority	O
# 2	of	O
# 3	prostate	O
# 4	carcinoma	O
# 5	survivors	O
# 6	experience	O
# 7	enduring	O
# 8	sexual	O
# 9	difficulties	O
# 10	and	O
# 11	associated	O
# 12	distress	O
# 13	in	O
# 14	the	O
# 15	years	O
# 16	after	O
# 17	definitive	O
# 18	treatment	O
# 19	.	O
# 20	A	O
# 21	counseling	O
# 22	intervention	O
# 23	aimed	O
# 24	at	O
# 25	improving	O
# 26	levels	O
# 27	of	O
# 28	sexual	O
# 29	satisfaction	O
# 30	and	O
# 31	increasing	O
# 32	successful	O
# 33	utilization	O
# 34	of	O
# 35	medical	O
# 36	treatment	O
# 37	for	O
# 38	erectile	O
# 39	dysfunction	O
# 40	(	O
# 41	ED	O
# 42	)	O
# 43	was	O
# 44	developed	O
# 45	and	O
# 46	pilot-tested	O
# 47	for	O
# 48	both	O
# 49	the	O
# 50	survivor	O
# 51	of	O
# 52	prostate	O
# 53	carcinoma	O
# 54	and	O
# 55	his	O
# 56	partner	O
# 57	.	O
# 58	All	O
# 59	male	O
# 60	participants	O
# 61	were	O
# 62	3	O
# 63	-	O
# 64	month	O
# 65	to	O
# 66	5	O
# 67	-	O
# 68	year	O
# 69	survivors	O
# 70	of	O
# 71	localized	O
# 72	prostate	O
# 73	carcinoma	O
# 74	who	O
# 75	had	O
# 76	been	O
# 77	treated	O
# 78	with	O
# 79	radical	O
# 80	prostatectomy	O
# 81	or	O
# 82	radiation	O
# 83	therapy	O
# 84	,	O
# 85	and	O
# 86	were	O
# 87	married	O
# 88	or	O
# 89	in	O
# 90	a	O
# 91	committed	O
# 92	relationship	O
# 93	.	O
# 94	Couples	O
# 95	were	O
# 96	randomized	O
# 97	to	O
# 98	attend	O
# 99	four	O
# 100	sessions	O
# 101	of	O
# 102	counseling	O
# 103	together	O
# 104	or	O
# 105	to	O
# 106	have	O
# 107	the	O
# 108	man	O
# 109	attend	O
# 110	alone	O
# 111	.	O
# 112	In	O
# 113	both	O
# 114	groups	O
# 115	,	O
# 116	partners	O
# 117	completed	O
# 118	behavioral	O
# 119	homework	O
# 120	.	O
# 121	The	O
# 122	sessions	O
# 123	included	O
# 124	education	O
# 125	on	O
# 126	prostate	O
# 127	carcinoma	O
# 128	and	O
# 129	sexual	O
# 130	function	O
# 131	and	O
# 132	options	O
# 133	to	O
# 134	treat	O
# 135	ED	O
# 136	as	O
# 137	well	O
# 138	as	O
# 139	sexual	O
# 140	communication	O
# 141	and	O
# 142	stimulation	O
# 143	skills	O
# 144	.	O
# 145	Standardized	O
# 146	questionnaires	O
# 147	at	O
# 148	baseline	O
# 149	,	O
# 150	posttreatment	O
# 151	,	O
# 152	and	O
# 153	at	O
# 154	3	O
# 155	-	O
# 156	month	O
# 157	and	O
# 158	6	O
# 159	-	O
# 160	month	O
# 161	follow-up	O
# 162	assessed	O
# 163	sexual	O
# 164	function	O
# 165	,	O
# 166	marital	O
# 167	adjustment	O
# 168	,	O
# 169	psychologic	O
# 170	distress	O
# 171	,	O
# 172	and	O
# 173	utilization	O
# 174	of	O
# 175	treatments	O
# 176	for	O
# 177	ED	O
# 178	.	O
# 179	Fifty-one	O
# 180	of	O
# 181	84	O
# 182	couples	O
# 183	randomized	O
# 184	to	O
# 185	treatment	O
# 186	completed	O
# 187	the	O
# 188	intervention	O
# 189	(	O
# 190	61	O
# 191	%	O
# 192	)	O
# 193	.	O
# 194	Attendance	O
# 195	by	O
# 196	the	O
# 197	partner	O
# 198	did	O
# 199	not	O
# 200	affect	O
# 201	outcomes	O
# 202	.	O
# 203	Participants	B-Premise
# 204	completing	I-Premise
# 205	the	I-Premise
# 206	intervention	I-Premise
# 207	demonstrated	I-Premise
# 208	improvement	I-Premise
# 209	in	I-Premise
# 210	male	I-Premise
# 211	overall	I-Premise
# 212	distress	I-Premise
# 213	(	I-Premise
# 214	P	I-Premise
# 215	<	I-Premise
# 216	0.01	I-Premise
# 217	)	I-Premise
# 218	,	I-Premise
# 219	male	I-Premise
# 220	global	I-Premise
# 221	sexual	I-Premise
# 222	function	I-Premise
# 223	(	I-Premise
# 224	P	I-Premise
# 225	<	I-Premise
# 226	0.0001	I-Premise
# 227	)	I-Premise
# 228	,	I-Premise
# 229	and	I-Premise
# 230	female	I-Premise
# 231	global	I-Premise
# 232	sexual	I-Premise
# 233	function	I-Premise
# 234	(	I-Premise
# 235	P	I-Premise
# 236	<	I-Premise
# 237	0.05	I-Premise
# 238	)	I-Premise
# 239	at	I-Premise
# 240	3	I-Premise
# 241	-	I-Premise
# 242	month	I-Premise
# 243	follow-up	I-Premise
# 244	,	O
# 245	but	B-Premise
# 246	regression	I-Premise
# 247	toward	I-Premise
# 248	baseline	I-Premise
# 249	was	I-Premise
# 250	noted	I-Premise
# 251	at	I-Premise
# 252	6	I-Premise
# 253	-	I-Premise
# 254	month	I-Premise
# 255	follow-up	I-Premise
# 256	.	O
# 257	However	B-Premise
# 258	,	I-Premise
# 259	utilization	I-Premise
# 260	of	I-Premise
# 261	ED	I-Premise
# 262	treatments	I-Premise
# 263	increased	I-Premise
# 264	from	I-Premise
# 265	31	I-Premise
# 266	%	I-Premise
# 267	at	I-Premise
# 268	the	I-Premise
# 269	time	I-Premise
# 270	of	I-Premise
# 271	study	I-Premise
# 272	entry	I-Premise
# 273	to	I-Premise
# 274	49	I-Premise
# 275	%	I-Premise
# 276	at	I-Premise
# 277	the	I-Premise
# 278	6	I-Premise
# 279	-	I-Premise
# 280	month	I-Premise
# 281	follow-up	I-Premise
# 282	(	I-Premise
# 283	P	I-Premise
# 284	=	I-Premise
# 285	0.003	I-Premise
# 286	)	I-Premise
# 287	.	O
# 288	The	B-Claim
# 289	results	I-Claim
# 290	of	I-Claim
# 291	this	I-Claim
# 292	brief	I-Claim
# 293	pilot	I-Claim
# 294	counseling	I-Claim
# 295	intervention	I-Claim
# 296	demonstrated	I-Claim
# 297	significant	I-Claim
# 298	gains	I-Claim
# 299	in	I-Claim
# 300	sexual	I-Claim
# 301	function	I-Claim
# 302	and	I-Claim
# 303	satisfaction	I-Claim
# 304	and	I-Claim
# 305	increased	I-Claim
# 306	utilization	I-Claim
# 307	of	I-Claim
# 308	treatments	I-Claim
# 309	for	I-Claim
# 310	ED	I-Claim
# 311	.	O
# 312	However	B-Claim
# 313	,	I-Claim
# 314	modifications	I-Claim
# 315	are	I-Claim
# 316	needed	I-Claim
# 317	in	I-Claim
# 318	future	I-Claim
# 319	randomized	I-Claim
# 320	trials	I-Claim
# 321	to	I-Claim
# 322	reduce	I-Claim
# 323	the	I-Claim
# 324	rate	I-Claim
# 325	of	I-Claim
# 326	premature	I-Claim
# 327	termination	I-Claim
# 328	and	I-Claim
# 329	to	I-Claim
# 330	improve	I-Claim
# 331	long-term	I-Claim
# 332	maintenance	I-Claim
# 333	of	I-Claim
# 334	gains	I-Claim
# 335	.	O
#
# (312, 335)	Partial-Attack	(288, 311)
# (245, 256)	Partial-Attack	(203, 244)
# (203, 244)	Support	(288, 311)
# (257, 287)	Support	(288, 311)
#
# 0	Chemotherapy	B-Claim
# 1	can	I-Claim
# 2	profoundly	I-Claim
# 3	affect	I-Claim
# 4	patients	I-Claim
# 5	'	I-Claim
# 6	quality	I-Claim
# 7	of	I-Claim
# 8	life	I-Claim
# 9	(	I-Claim
# 10	QOL	I-Claim
# 11	)	I-Claim
# 12	,	O
# 13	yet	O
# 14	few	O
# 15	clinical	O
# 16	trials	O
# 17	in	O
# 18	advanced	O
# 19	cervical	O
# 20	cancer	O
# 21	have	O
# 22	included	O
# 23	QOL	O
# 24	outcomes	O
# 25	.	O
# 26	Our	O
# 27	purpose	O
# 28	was	O
# 29	to	O
# 30	assess	O
# 31	the	O
# 32	impact	O
# 33	of	O
# 34	cisplatin	O
# 35	(	O
# 36	C	O
# 37	)	O
# 38	versus	O
# 39	cisplatin	O
# 40	plus	O
# 41	paclitaxel	O
# 42	(	O
# 43	CP	O
# 44	)	O
# 45	on	O
# 46	overall	O
# 47	QOL	O
# 48	and	O
# 49	pain	O
# 50	in	O
# 51	cervical	O
# 52	cancer	O
# 53	patients	O
# 54	.	O
# 55	QOL	O
# 56	was	O
# 57	assessed	O
# 58	using	O
# 59	FACT-Cx	O
# 60	,	O
# 61	consisting	O
# 62	of	O
# 63	the	O
# 64	Functional	O
# 65	Assessment	O
# 66	of	O
# 67	Cancer	O
# 68	Therapy	O
# 69	(	O
# 70	FACT-G	O
# 71	)	O
# 72	plus	O
# 73	a	O
# 74	cervix	O
# 75	cancer-specific	O
# 76	subscale	O
# 77	,	O
# 78	the	O
# 79	Brief	O
# 80	Pain	O
# 81	Inventory-Short	O
# 82	Form	O
# 83	(	O
# 84	BPI-SF	O
# 85	)	O
# 86	,	O
# 87	and	O
# 88	a	O
# 89	neurotoxicity	O
# 90	subscale	O
# 91	.	O
# 92	Time	O
# 93	points	O
# 94	were	O
# 95	:	O
# 96	baseline	O
# 97	(	O
# 98	prior	O
# 99	to	O
# 100	randomization	O
# 101	)	O
# 102	and	O
# 103	prior	O
# 104	to	O
# 105	chemotherapy	O
# 106	cycles	O
# 107	2	O
# 108	,	O
# 109	3	O
# 110	,	O
# 111	and	O
# 112	4	O
# 113	.	O
# 114	Overall	B-Premise
# 115	(	I-Premise
# 116	FACT-G	I-Premise
# 117	)	I-Premise
# 118	scores	I-Premise
# 119	did	I-Premise
# 120	not	I-Premise
# 121	differ	I-Premise
# 122	significantly	I-Premise
# 123	between	I-Premise
# 124	arms	I-Premise
# 125	at	I-Premise
# 126	the	I-Premise
# 127	fourth	I-Premise
# 128	assessment	I-Premise
# 129	(	I-Premise
# 130	C	I-Premise
# 131	=	I-Premise
# 132	70.3	I-Premise
# 133	(	I-Premise
# 134	19.6	I-Premise
# 135	);	I-Premise
# 136	CP	I-Premise
# 137	=	I-Premise
# 138	72.8	I-Premise
# 139	(	I-Premise
# 140	17.4	I-Premise
# 141	)	I-Premise
# 142	)	I-Premise
# 143	.	O
# 144	Scores	B-Premise
# 145	were	I-Premise
# 146	stable	I-Premise
# 147	over	I-Premise
# 148	time	I-Premise
# 149	and	I-Premise
# 150	considerably	I-Premise
# 151	lower	I-Premise
# 152	than	I-Premise
# 153	the	I-Premise
# 154	general	I-Premise
# 155	population	I-Premise
# 156	norms	I-Premise
# 157	.	O
# 158	The	B-Premise
# 159	BPI-SF	I-Premise
# 160	revealed	I-Premise
# 161	a	I-Premise
# 162	decline	I-Premise
# 163	in	I-Premise
# 164	pain	I-Premise
# 165	scores	I-Premise
# 166	in	I-Premise
# 167	both	I-Premise
# 168	arms	I-Premise
# 169	from	I-Premise
# 170	the	I-Premise
# 171	first	I-Premise
# 172	to	I-Premise
# 173	fourth	I-Premise
# 174	assessments	I-Premise
# 175	.	O
# 176	The	B-Premise
# 177	CP	I-Premise
# 178	arm	I-Premise
# 179	produced	I-Premise
# 180	a	I-Premise
# 181	significantly	I-Premise
# 182	higher	I-Premise
# 183	response	I-Premise
# 184	rate	I-Premise
# 185	and	I-Premise
# 186	progression-free	I-Premise
# 187	survival	I-Premise
# 188	(	I-Premise
# 189	PFS	I-Premise
# 190	)	O
# 191	but	B-Premise
# 192	not	I-Premise
# 193	overall	I-Premise
# 194	survival	I-Premise
# 195	(	I-Premise
# 196	OS	I-Premise
# 197	)	I-Premise
# 198	.	O
# 199	Greater	B-Premise
# 200	myelosuppression	I-Premise
# 201	was	I-Premise
# 202	reported	I-Premise
# 203	in	I-Premise
# 204	the	I-Premise
# 205	combination	I-Premise
# 206	arm	I-Premise
# 207	.	O
# 208	The	B-Premise
# 209	rate	I-Premise
# 210	of	I-Premise
# 211	QOL	I-Premise
# 212	drop-out	I-Premise
# 213	for	I-Premise
# 214	any	I-Premise
# 215	reason	I-Premise
# 216	was	I-Premise
# 217	higher	I-Premise
# 218	for	I-Premise
# 219	C	I-Premise
# 220	(	I-Premise
# 221	53	I-Premise
# 222	%	I-Premise
# 223	)	I-Premise
# 224	compared	I-Premise
# 225	to	I-Premise
# 226	CP	I-Premise
# 227	(	I-Premise
# 228	38	I-Premise
# 229	%	I-Premise
# 230	)	I-Premise
# 231	(	I-Premise
# 232	P	I-Premise
# 233	<	I-Premise
# 234	0.05	I-Premise
# 235	)	I-Premise
# 236	.	O
# 237	At	O
# 238	the	O
# 239	fourth	O
# 240	time	O
# 241	point	O
# 242	,	O
# 243	60	O
# 244	%	O
# 245	of	O
# 246	living	O
# 247	patients	O
# 248	in	O
# 249	both	O
# 250	arms	O
# 251	completed	O
# 252	a	O
# 253	QOL	O
# 254	assessment	O
# 255	.	O
# 256	There	B-Claim
# 257	was	I-Claim
# 258	no	I-Claim
# 259	significant	I-Claim
# 260	difference	I-Claim
# 261	in	I-Claim
# 262	overall	I-Claim
# 263	QOL	I-Claim
# 264	scores	I-Claim
# 265	between	I-Claim
# 266	treatment	I-Claim
# 267	arms	I-Claim
# 268	or	I-Claim
# 269	serially	I-Claim
# 270	.	O
# 271	Combined	B-Claim
# 272	with	I-Claim
# 273	QOL	I-Claim
# 274	results	I-Claim
# 275	,	I-Claim
# 276	the	I-Claim
# 277	significant	I-Claim
# 278	increase	I-Claim
# 279	in	I-Claim
# 280	response	I-Claim
# 281	and	I-Claim
# 282	PFS	I-Claim
# 283	in	I-Claim
# 284	the	I-Claim
# 285	CP	I-Claim
# 286	arm	I-Claim
# 287	and	I-Claim
# 288	the	I-Claim
# 289	higher	I-Claim
# 290	drop-out	I-Claim
# 291	rate	I-Claim
# 292	in	I-Claim
# 293	the	I-Claim
# 294	C	I-Claim
# 295	arm	I-Claim
# 296	suggest	I-Claim
# 297	a	I-Claim
# 298	better	I-Claim
# 299	outcome	I-Claim
# 300	for	I-Claim
# 301	the	I-Claim
# 302	combination	I-Claim
# 303	regimen	I-Claim
# 304	despite	I-Claim
# 305	its	I-Claim
# 306	increased	I-Claim
# 307	myelosuppression	I-Claim
# 308	.	O
#
# (199, 207)	Support	(271, 308)
# (176, 190)	Support	(271, 308)
# (191, 198)	Partial-Attack	(176, 190)
# (158, 175)	Support	(271, 308)
# (208, 236)	Support	(271, 308)
# (256, 270)	Support	(271, 308)
#
# 0	Patients	B-Claim
# 1	with	I-Claim
# 2	advanced	I-Claim
# 3	non-small	I-Claim
# 4	cell	I-Claim
# 5	lung	I-Claim
# 6	cancer	I-Claim
# 7	(	I-Claim
# 8	NSCLC	I-Claim
# 9	)	I-Claim
# 10	do	I-Claim
# 11	not	I-Claim
# 12	have	I-Claim
# 13	curative	I-Claim
# 14	treatment	I-Claim
# 15	options	I-Claim
# 16	;	O
# 17	therefore	O
# 18	,	O
# 19	treatments	O
# 20	should	O
# 21	prolong	O
# 22	survival	O
# 23	and	O
# 24	improve	O
# 25	quality	O
# 26	of	O
# 27	life	O
# 28	(	O
# 29	QoL	O
# 30	)	O
# 31	.	O
# 32	We	O
# 33	compared	O
# 34	the	O
# 35	effect	O
# 36	on	O
# 37	QoL	O
# 38	of	O
# 39	two	O
# 40	docetaxel-platinum	O
# 41	regimens	O
# 42	with	O
# 43	vinorelbine-cisplatin	O
# 44	.	O
# 45	QoL	O
# 46	was	O
# 47	assessed	O
# 48	by	O
# 49	the	O
# 50	Lung	O
# 51	Cancer	O
# 52	Symptom	O
# 53	Scale	O
# 54	(	O
# 55	LCSS	O
# 56	)	O
# 57	and	O
# 58	the	O
# 59	general	O
# 60	EuroQol	O
# 61	five-dimensional	O
# 62	questionnaire	O
# 63	(	O
# 64	EQ	O
# 65	-	O
# 66	5D	O
# 67	)	O
# 68	in	O
# 69	926	O
# 70	chemotherapy-naïve	O
# 71	patients	O
# 72	with	O
# 73	stages	O
# 74	IIIB	O
# 75	to	O
# 76	IV	O
# 77	NSCLC	O
# 78	.	O
# 79	Patients	O
# 80	were	O
# 81	randomly	O
# 82	assigned	O
# 83	to	O
# 84	receive	O
# 85	:	O
# 86	docetaxel	O
# 87	75	O
# 88	mg	O
# 89	/	O
# 90	m2	O
# 91	plus	O
# 92	cisplatin	O
# 93	75	O
# 94	mg	O
# 95	/	O
# 96	m2	O
# 97	,	O
# 98	every	O
# 99	3	O
# 100	weeks	O
# 101	(	O
# 102	DC	O
# 103	);	O
# 104	docetaxel	O
# 105	75	O
# 106	mg	O
# 107	/	O
# 108	m2	O
# 109	and	O
# 110	carboplatin	O
# 111	6	O
# 112	mg	O
# 113	/	O
# 114	ml	O
# 115	min	O
# 116	,	O
# 117	every	O
# 118	3	O
# 119	weeks	O
# 120	(	O
# 121	DCb	O
# 122	);	O
# 123	or	O
# 124	vinorelbine	O
# 125	25	O
# 126	mg	O
# 127	/	O
# 128	m2	O
# 129	/	O
# 130	week	O
# 131	plus	O
# 132	cisplatin	O
# 133	100	O
# 134	mg	O
# 135	/	O
# 136	m2	O
# 137	,	O
# 138	every	O
# 139	4	O
# 140	weeks	O
# 141	(	O
# 142	VC	O
# 143	)	O
# 144	.	O
# 145	Overall	B-Premise
# 146	,	I-Premise
# 147	patients	I-Premise
# 148	treated	I-Premise
# 149	with	I-Premise
# 150	either	I-Premise
# 151	docetaxel-containing	I-Premise
# 152	regimen	I-Premise
# 153	had	I-Premise
# 154	better	I-Premise
# 155	QoL	I-Premise
# 156	than	I-Premise
# 157	VC-treated	I-Premise
# 158	patients	I-Premise
# 159	(	I-Premise
# 160	LCSS	I-Premise
# 161	global	I-Premise
# 162	item	I-Premise
# 163	"	I-Premise
# 164	QoL	I-Premise
# 165	today	I-Premise
# 166	"	I-Premise
# 167	:	I-Premise
# 168	P=	I-Premise
# 169	0.064	I-Premise
# 170	for	I-Premise
# 171	DC	I-Premise
# 172	and	I-Premise
# 173	P=	I-Premise
# 174	0.016	I-Premise
# 175	for	I-Premise
# 176	DCb	I-Premise
# 177	versus	I-Premise
# 178	VC	I-Premise
# 179	;	I-Premise
# 180	EQ	I-Premise
# 181	-	I-Premise
# 182	5D	I-Premise
# 183	global	I-Premise
# 184	item	I-Premise
# 185	"	I-Premise
# 186	health	I-Premise
# 187	state	I-Premise
# 188	today	I-Premise
# 189	"	I-Premise
# 190	:	I-Premise
# 191	P=	I-Premise
# 192	0.016	I-Premise
# 193	for	I-Premise
# 194	DC	I-Premise
# 195	and	I-Premise
# 196	P	I-Premise
# 197	<	I-Premise
# 198	0.001	I-Premise
# 199	for	I-Premise
# 200	DCb	I-Premise
# 201	versus	I-Premise
# 202	VC	I-Premise
# 203	)	I-Premise
# 204	.	O
# 205	DC-treated	B-Premise
# 206	patients	I-Premise
# 207	experienced	I-Premise
# 208	improved	I-Premise
# 209	pain	I-Premise
# 210	relief	I-Premise
# 211	compared	I-Premise
# 212	with	I-Premise
# 213	VC	I-Premise
# 214	(	I-Premise
# 215	P=	I-Premise
# 216	0.033	I-Premise
# 217	)	I-Premise
# 218	,	O
# 219	whereas	O
# 220	pain	B-Premise
# 221	relief	I-Premise
# 222	with	I-Premise
# 223	DCb	I-Premise
# 224	and	I-Premise
# 225	VC	I-Premise
# 226	was	I-Premise
# 227	similar	I-Premise
# 228	.	O
# 229	Patients	B-Premise
# 230	treated	I-Premise
# 231	with	I-Premise
# 232	either	I-Premise
# 233	docetaxel	I-Premise
# 234	regimen	I-Premise
# 235	had	I-Premise
# 236	more	I-Premise
# 237	favorable	I-Premise
# 238	changes	I-Premise
# 239	in	I-Premise
# 240	performance	I-Premise
# 241	status	I-Premise
# 242	(	I-Premise
# 243	P=	I-Premise
# 244	0.065	I-Premise
# 245	for	I-Premise
# 246	DC	I-Premise
# 247	and	I-Premise
# 248	P	I-Premise
# 249	<	I-Premise
# 250	0.001	I-Premise
# 251	for	I-Premise
# 252	DCb	I-Premise
# 253	versus	I-Premise
# 254	VC	I-Premise
# 255	)	I-Premise
# 256	and	I-Premise
# 257	mean	I-Premise
# 258	weight	I-Premise
# 259	loss	I-Premise
# 260	(	I-Premise
# 261	0.06	I-Premise
# 262	kg	I-Premise
# 263	,	I-Premise
# 264	gain	I-Premise
# 265	of	I-Premise
# 266	0.08	I-Premise
# 267	kg	I-Premise
# 268	,	I-Premise
# 269	and	I-Premise
# 270	2.27	I-Premise
# 271	kg	I-Premise
# 272	for	I-Premise
# 273	DC	I-Premise
# 274	,	I-Premise
# 275	DCb	I-Premise
# 276	,	I-Premise
# 277	and	I-Premise
# 278	VC	I-Premise
# 279	,	I-Premise
# 280	respectively	I-Premise
# 281	;	I-Premise
# 282	P	I-Premise
# 283	<	I-Premise
# 284	0.001	I-Premise
# 285	for	I-Premise
# 286	both	I-Premise
# 287	DC	I-Premise
# 288	versus	I-Premise
# 289	VC	I-Premise
# 290	and	I-Premise
# 291	DCb	I-Premise
# 292	versus	I-Premise
# 293	VC	I-Premise
# 294	)	I-Premise
# 295	.	O
# 296	The	B-Claim
# 297	TAX	I-Claim
# 298	326	I-Claim
# 299	study	I-Claim
# 300	shows	I-Claim
# 301	that	I-Claim
# 302	docetaxel-platinum	I-Claim
# 303	regimens	I-Claim
# 304	relieve	I-Claim
# 305	symptoms	I-Claim
# 306	and	I-Claim
# 307	improve	I-Claim
# 308	QoL	I-Claim
# 309	in	I-Claim
# 310	patients	I-Claim
# 311	with	I-Claim
# 312	advanced	I-Claim
# 313	NSCLC	I-Claim
# 314	.	O
# 315	DCb	B-Claim
# 316	and	I-Claim
# 317	DC	I-Claim
# 318	were	I-Claim
# 319	superior	I-Claim
# 320	to	I-Claim
# 321	VC	I-Claim
# 322	in	I-Claim
# 323	all	I-Claim
# 324	QoL	I-Claim
# 325	outcomes	I-Claim
# 326	assessed	I-Claim
# 327	except	I-Claim
# 328	for	I-Claim
# 329	the	I-Claim
# 330	difference	I-Claim
# 331	between	I-Claim
# 332	DC	I-Claim
# 333	and	I-Claim
# 334	VC	I-Claim
# 335	in	I-Claim
# 336	LCSS	I-Claim
# 337	"	I-Claim
# 338	QoL	I-Claim
# 339	today	I-Claim
# 340	"	I-Claim
# 341	,	I-Claim
# 342	which	I-Claim
# 343	was	I-Claim
# 344	not	I-Claim
# 345	significant	I-Claim
# 346	.	O
#
# (145, 204)	Support	(315, 346)
# (205, 218)	Support	(315, 346)
# (220, 228)	Support	(296, 314)
# (229, 295)	Support	(296, 314)
#
# 0	It	B-Claim
# 1	has	I-Claim
# 2	been	I-Claim
# 3	shown	I-Claim
# 4	that	I-Claim
# 5	nonpharmacologic	I-Claim
# 6	interventions	I-Claim
# 7	are	I-Claim
# 8	effective	I-Claim
# 9	management	I-Claim
# 10	techniques	I-Claim
# 11	for	I-Claim
# 12	cancer-related	I-Claim
# 13	fatigue	I-Claim
# 14	(	I-Claim
# 15	CRF	I-Claim
# 16	)	I-Claim
# 17	in	I-Claim
# 18	cancer	I-Claim
# 19	survivors	I-Claim
# 20	.	O
# 21	However	O
# 22	,	O
# 23	few	O
# 24	studies	O
# 25	have	O
# 26	investigated	O
# 27	their	O
# 28	effectiveness	O
# 29	in	O
# 30	patients	O
# 31	who	O
# 32	are	O
# 33	receiving	O
# 34	chemotherapy	O
# 35	.	O
# 36	In	O
# 37	this	O
# 38	study	O
# 39	,	O
# 40	the	O
# 41	authors	O
# 42	tested	O
# 43	the	O
# 44	effectiveness	O
# 45	of	O
# 46	a	O
# 47	brief	O
# 48	behaviorally	O
# 49	oriented	O
# 50	intervention	O
# 51	in	O
# 52	reducing	O
# 53	CRF	O
# 54	and	O
# 55	improving	O
# 56	physical	O
# 57	function	O
# 58	and	O
# 59	associated	O
# 60	distress	O
# 61	in	O
# 62	individuals	O
# 63	who	O
# 64	were	O
# 65	receiving	O
# 66	chemotherapy	O
# 67	.	O
# 68	For	O
# 69	this	O
# 70	randomized	O
# 71	controlled	O
# 72	trial	O
# 73	,	O
# 74	60	O
# 75	patients	O
# 76	with	O
# 77	cancer	O
# 78	were	O
# 79	recruited	O
# 80	and	O
# 81	received	O
# 82	either	O
# 83	usual	O
# 84	care	O
# 85	or	O
# 86	the	O
# 87	intervention	O
# 88	.	O
# 89	The	O
# 90	intervention	O
# 91	was	O
# 92	delivered	O
# 93	on	O
# 94	an	O
# 95	individual	O
# 96	basis	O
# 97	on	O
# 98	3	O
# 99	occasions	O
# 100	over	O
# 101	a	O
# 102	period	O
# 103	from	O
# 104	9	O
# 105	weeks	O
# 106	to	O
# 107	12	O
# 108	weeks	O
# 109	,	O
# 110	and	O
# 111	the	O
# 112	objective	O
# 113	of	O
# 114	the	O
# 115	intervention	O
# 116	was	O
# 117	to	O
# 118	alter	O
# 119	fatigue-related	O
# 120	thoughts	O
# 121	and	O
# 122	behavior	O
# 123	.	O
# 124	Primary	O
# 125	outcomes	O
# 126	were	O
# 127	assessed	O
# 128	as	O
# 129	follows	O
# 130	:	O
# 131	CRF	O
# 132	using	O
# 133	the	O
# 134	Visual	O
# 135	Analogue	O
# 136	Scale-Global	O
# 137	Fatigue	O
# 138	;	O
# 139	physical	O
# 140	functioning	O
# 141	using	O
# 142	the	O
# 143	European	O
# 144	Organization	O
# 145	for	O
# 146	Research	O
# 147	and	O
# 148	Treatment	O
# 149	of	O
# 150	Cancer	O
# 151	Quality-of-Life	O
# 152	Core	O
# 153	30	O
# 154	Questionnaire	O
# 155	,	O
# 156	and	O
# 157	CRF-associated	O
# 158	distress	O
# 159	using	O
# 160	the	O
# 161	Fatigue	O
# 162	Outcome	O
# 163	Measure	O
# 164	.	O
# 165	Assessments	O
# 166	were	O
# 167	made	O
# 168	on	O
# 169	4	O
# 170	occasions	O
# 171	:	O
# 172	at	O
# 173	baseline	O
# 174	(	O
# 175	T0	O
# 176	)	O
# 177	,	O
# 178	at	O
# 179	the	O
# 180	end	O
# 181	of	O
# 182	chemotherapy	O
# 183	(	O
# 184	T1	O
# 185	)	O
# 186	,	O
# 187	1	O
# 188	month	O
# 189	after	O
# 190	chemotherapy	O
# 191	(	O
# 192	T2	O
# 193	)	O
# 194	,	O
# 195	and	O
# 196	9	O
# 197	months	O
# 198	after	O
# 199	recruitment	O
# 200	(	O
# 201	T3	O
# 202	)	O
# 203	.	O
# 204	Normally	O
# 205	distributed	O
# 206	data	O
# 207	were	O
# 208	analyzed	O
# 209	using	O
# 210	t	O
# 211	tests	O
# 212	and	O
# 213	random-slope	O
# 214	/	O
# 215	random-intercept	O
# 216	mixed	O
# 217	models	O
# 218	.	O
# 219	The	B-Premise
# 220	intervention	I-Premise
# 221	demonstrated	I-Premise
# 222	a	I-Premise
# 223	trend	I-Premise
# 224	toward	I-Premise
# 225	improved	I-Premise
# 226	CRF	I-Premise
# 227	,	O
# 228	although	B-Premise
# 229	this	I-Premise
# 230	effect	I-Premise
# 231	was	I-Premise
# 232	reduced	I-Premise
# 233	once	I-Premise
# 234	confounders	I-Premise
# 235	had	I-Premise
# 236	been	I-Premise
# 237	controlled	I-Premise
# 238	statistically	I-Premise
# 239	.	O
# 240	There	B-Premise
# 241	was	I-Premise
# 242	a	I-Premise
# 243	significant	I-Premise
# 244	improvement	I-Premise
# 245	in	I-Premise
# 246	physical	I-Premise
# 247	functioning	I-Premise
# 248	(	I-Premise
# 249	coefficient	I-Premise
# 250	,	I-Premise
# 251	10.0	I-Premise
# 252	;	I-Premise
# 253	95	I-Premise
# 254	%	I-Premise
# 255	confidence	I-Premise
# 256	interval	I-Premise
# 257	,	I-Premise
# 258	2.5-	I-Premise
# 259	17.5	I-Premise
# 260	;	I-Premise
# 261	P	I-Premise
# 262	=	I-Premise
# 263	.	I-Premise
# 264	009	I-Premise
# 265	)	I-Premise
# 266	,	I-Premise
# 267	and	I-Premise
# 268	this	I-Premise
# 269	effect	I-Premise
# 270	remained	I-Premise
# 271	once	I-Premise
# 272	the	I-Premise
# 273	confounding	I-Premise
# 274	effects	I-Premise
# 275	of	I-Premise
# 276	mood	I-Premise
# 277	disturbance	I-Premise
# 278	and	I-Premise
# 279	comorbid	I-Premise
# 280	disorders	I-Premise
# 281	were	I-Premise
# 282	controlled	I-Premise
# 283	statistically	I-Premise
# 284	.	O
# 285	No	B-Premise
# 286	decrease	I-Premise
# 287	in	I-Premise
# 288	fatigue-related	I-Premise
# 289	distress	I-Premise
# 290	was	I-Premise
# 291	detected	I-Premise
# 292	.	O
# 293	The	B-Claim
# 294	behaviorally	I-Claim
# 295	oriented	I-Claim
# 296	intervention	I-Claim
# 297	brought	I-Claim
# 298	about	I-Claim
# 299	significant	I-Claim
# 300	improvements	I-Claim
# 301	in	I-Claim
# 302	physical	I-Claim
# 303	functioning	I-Claim
# 304	,	I-Claim
# 305	indicated	I-Claim
# 306	a	I-Claim
# 307	trend	I-Claim
# 308	toward	I-Claim
# 309	improved	I-Claim
# 310	CRF	I-Claim
# 311	,	I-Claim
# 312	but	I-Claim
# 313	detected	I-Claim
# 314	no	I-Claim
# 315	effect	I-Claim
# 316	for	I-Claim
# 317	fatigue-related	I-Claim
# 318	distress	I-Claim
# 319	.	O
#
# (285, 292)	Support	(293, 319)
# (219, 227)	Support	(293, 319)
# (228, 239)	Partial-Attack	(219, 227)
# (240, 284)	Support	(293, 319)
#
# 0	Exercise	O
# 1	training	O
# 2	improves	O
# 3	supportive	O
# 4	care	O
# 5	outcomes	O
# 6	in	O
# 7	patients	O
# 8	with	O
# 9	breast	O
# 10	cancer	O
# 11	who	O
# 12	are	O
# 13	receiving	O
# 14	adjuvant	O
# 15	therapy	O
# 16	,	O
# 17	but	O
# 18	the	O
# 19	responses	O
# 20	are	O
# 21	heterogeneous	O
# 22	.	O
# 23	In	O
# 24	this	O
# 25	study	O
# 26	,	O
# 27	the	O
# 28	authors	O
# 29	examined	O
# 30	personal	O
# 31	and	O
# 32	clinical	O
# 33	factors	O
# 34	that	O
# 35	may	O
# 36	predict	O
# 37	exercise	O
# 38	training	O
# 39	responses	O
# 40	.	O
# 41	Breast	O
# 42	cancer	O
# 43	patients	O
# 44	who	O
# 45	were	O
# 46	initiating	O
# 47	adjuvant	O
# 48	chemotherapy	O
# 49	(	O
# 50	N	O
# 51	=	O
# 52	242	O
# 53	)	O
# 54	were	O
# 55	assigned	O
# 56	randomly	O
# 57	to	O
# 58	receive	O
# 59	usual	O
# 60	care	O
# 61	(	O
# 62	UC	O
# 63	)	O
# 64	(	O
# 65	n	O
# 66	=	O
# 67	82	O
# 68	)	O
# 69	,	O
# 70	resistance	O
# 71	exercise	O
# 72	training	O
# 73	(	O
# 74	RET	O
# 75	)	O
# 76	(	O
# 77	n	O
# 78	=	O
# 79	82	O
# 80	)	O
# 81	,	O
# 82	or	O
# 83	aerobic	O
# 84	exercise	O
# 85	training	O
# 86	(	O
# 87	AET	O
# 88	)	O
# 89	(	O
# 90	n	O
# 91	=	O
# 92	78	O
# 93	)	O
# 94	for	O
# 95	the	O
# 96	duration	O
# 97	of	O
# 98	chemotherapy	O
# 99	.	O
# 100	Endpoints	O
# 101	were	O
# 102	quality	O
# 103	of	O
# 104	life	O
# 105	(	O
# 106	QoL	O
# 107	)	O
# 108	,	O
# 109	aerobic	O
# 110	fitness	O
# 111	,	O
# 112	muscular	O
# 113	strength	O
# 114	,	O
# 115	lean	O
# 116	body	O
# 117	mass	O
# 118	,	O
# 119	and	O
# 120	body	O
# 121	fat	O
# 122	.	O
# 123	Moderators	O
# 124	were	O
# 125	patient	O
# 126	preference	O
# 127	for	O
# 128	group	O
# 129	assignment	O
# 130	,	O
# 131	marital	O
# 132	status	O
# 133	,	O
# 134	age	O
# 135	,	O
# 136	disease	O
# 137	stage	O
# 138	,	O
# 139	and	O
# 140	chemotherapy	O
# 141	regimen	O
# 142	.	O
# 143	Adjusted	O
# 144	linear	O
# 145	mixed-model	O
# 146	analyses	O
# 147	demonstrated	O
# 148	that	O
# 149	patient	O
# 150	preference	O
# 151	moderated	O
# 152	QoL	O
# 153	response	O
# 154	(	O
# 155	P=	O
# 156	.	O
# 157	005	O
# 158	)	O
# 159	.	O
# 160	Patients	B-Premise
# 161	who	I-Premise
# 162	preferred	I-Premise
# 163	RET	I-Premise
# 164	improved	I-Premise
# 165	QoL	I-Premise
# 166	when	I-Premise
# 167	they	I-Premise
# 168	were	I-Premise
# 169	assigned	I-Premise
# 170	to	I-Premise
# 171	receive	I-Premise
# 172	RET	I-Premise
# 173	compared	I-Premise
# 174	with	I-Premise
# 175	UC	I-Premise
# 176	(	I-Premise
# 177	mean	I-Premise
# 178	difference	I-Premise
# 179	,	I-Premise
# 180	16.5	I-Premise
# 181	;	I-Premise
# 182	95	I-Premise
# 183	%	I-Premise
# 184	confidence	I-Premise
# 185	interval	I-Premise
# 186	[	I-Premise
# 187	95	I-Premise
# 188	%	I-Premise
# 189	CI	I-Premise
# 190	]	I-Premise
# 191	,	I-Premise
# 192	4.3-	I-Premise
# 193	28.7	I-Premise
# 194	;	I-Premise
# 195	P=	I-Premise
# 196	.	I-Premise
# 197	008	I-Premise
# 198	)	I-Premise
# 199	or	I-Premise
# 200	AET	I-Premise
# 201	(	I-Premise
# 202	mean	I-Premise
# 203	difference	I-Premise
# 204	,	I-Premise
# 205	11	I-Premise
# 206	;	I-Premise
# 207	95	I-Premise
# 208	%	I-Premise
# 209	CI	I-Premise
# 210	,	I-Premise
# 211	-1.1-	I-Premise
# 212	23.4	I-Premise
# 213	;	I-Premise
# 214	P=	I-Premise
# 215	.	I-Premise
# 216	076	I-Premise
# 217	)	I-Premise
# 218	.	O
# 219	Patients	B-Premise
# 220	who	I-Premise
# 221	had	I-Premise
# 222	no	I-Premise
# 223	preference	I-Premise
# 224	had	I-Premise
# 225	improved	I-Premise
# 226	QoL	I-Premise
# 227	when	I-Premise
# 228	they	I-Premise
# 229	were	I-Premise
# 230	assigned	I-Premise
# 231	to	I-Premise
# 232	receive	I-Premise
# 233	AET	I-Premise
# 234	compared	I-Premise
# 235	with	I-Premise
# 236	RET	I-Premise
# 237	(	I-Premise
# 238	mean	I-Premise
# 239	difference	I-Premise
# 240	,	I-Premise
# 241	23	I-Premise
# 242	;	I-Premise
# 243	95	I-Premise
# 244	%	I-Premise
# 245	CI	I-Premise
# 246	,	I-Premise
# 247	4.9-	I-Premise
# 248	41	I-Premise
# 249	;	I-Premise
# 250	P=	I-Premise
# 251	.	I-Premise
# 252	014	I-Premise
# 253	)	I-Premise
# 254	.	O
# 255	Marital	B-Premise
# 256	status	I-Premise
# 257	also	I-Premise
# 258	moderated	I-Premise
# 259	QoL	I-Premise
# 260	response	I-Premise
# 261	(	I-Premise
# 262	P=	I-Premise
# 263	.	I-Premise
# 264	026	I-Premise
# 265	)	I-Premise
# 266	,	I-Premise
# 267	age	I-Premise
# 268	moderated	I-Premise
# 269	aerobic	I-Premise
# 270	fitness	I-Premise
# 271	response	I-Premise
# 272	(	I-Premise
# 273	P=	I-Premise
# 274	.	I-Premise
# 275	029	I-Premise
# 276	)	I-Premise
# 277	,	I-Premise
# 278	chemotherapy	I-Premise
# 279	regimen	I-Premise
# 280	moderated	I-Premise
# 281	strength	I-Premise
# 282	gain	I-Premise
# 283	(	I-Premise
# 284	P=	I-Premise
# 285	.	I-Premise
# 286	009	I-Premise
# 287	)	I-Premise
# 288	,	I-Premise
# 289	and	I-Premise
# 290	disease	I-Premise
# 291	stage	I-Premise
# 292	moderated	I-Premise
# 293	both	I-Premise
# 294	lean	I-Premise
# 295	body	I-Premise
# 296	mass	I-Premise
# 297	gain	I-Premise
# 298	(	I-Premise
# 299	P	I-Premise
# 300	<	I-Premise
# 301	.	I-Premise
# 302	001	I-Premise
# 303	)	I-Premise
# 304	and	I-Premise
# 305	fat	I-Premise
# 306	loss	I-Premise
# 307	(	I-Premise
# 308	P=	I-Premise
# 309	.	I-Premise
# 310	059	I-Premise
# 311	)	I-Premise
# 312	.	O
# 313	Unmarried	B-Premise
# 314	,	I-Premise
# 315	younger	I-Premise
# 316	patients	I-Premise
# 317	who	I-Premise
# 318	were	I-Premise
# 319	receiving	I-Premise
# 320	nontaxane-based	I-Premise
# 321	therapies	I-Premise
# 322	and	I-Premise
# 323	had	I-Premise
# 324	more	I-Premise
# 325	advanced	I-Premise
# 326	disease	I-Premise
# 327	stage	I-Premise
# 328	experienced	I-Premise
# 329	better	I-Premise
# 330	outcomes	I-Premise
# 331	.	O
# 332	The	O
# 333	findings	O
# 334	were	O
# 335	not	O
# 336	explained	O
# 337	by	O
# 338	differences	O
# 339	in	O
# 340	adherence	O
# 341	.	O
# 342	Patient	B-Claim
# 343	preference	I-Claim
# 344	,	I-Claim
# 345	demographic	I-Claim
# 346	variables	I-Claim
# 347	,	I-Claim
# 348	and	I-Claim
# 349	medical	I-Claim
# 350	variables	I-Claim
# 351	moderated	I-Claim
# 352	the	I-Claim
# 353	effects	I-Claim
# 354	of	I-Claim
# 355	exercise	I-Claim
# 356	training	I-Claim
# 357	in	I-Claim
# 358	breast	I-Claim
# 359	cancer	I-Claim
# 360	patients	I-Claim
# 361	who	I-Claim
# 362	were	I-Claim
# 363	receiving	I-Claim
# 364	chemotherapy	I-Claim
# 365	.	O
# 366	If	O
# 367	replicated	O
# 368	,	O
# 369	these	O
# 370	results	O
# 371	may	O
# 372	inform	O
# 373	clinical	O
# 374	practice	O
# 375	.	O
#
# (160, 218)	Support	(342, 365)
# (219, 254)	Support	(342, 365)
# (255, 312)	Support	(342, 365)
# (313, 331)	Support	(342, 365)
#
# 0	Compared	O
# 1	with	O
# 2	placebo	O
# 3	,	O
# 4	prophylactic	O
# 5	treatment	O
# 6	with	O
# 7	bisphosphonates	O
# 8	reduces	O
# 9	risk	O
# 10	of	O
# 11	skeletal	O
# 12	events	O
# 13	in	O
# 14	patients	O
# 15	with	O
# 16	multiple	O
# 17	myeloma	O
# 18	.	O
# 19	However	O
# 20	,	O
# 21	because	O
# 22	of	O
# 23	toxicity	O
# 24	associated	O
# 25	with	O
# 26	long-term	O
# 27	bisphosphonate	O
# 28	treatment	O
# 29	,	O
# 30	establishing	O
# 31	the	O
# 32	lowest	O
# 33	effective	O
# 34	dose	O
# 35	is	O
# 36	important	O
# 37	.	O
# 38	This	O
# 39	study	O
# 40	compared	O
# 41	the	O
# 42	effect	O
# 43	of	O
# 44	two	O
# 45	doses	O
# 46	of	O
# 47	pamidronate	O
# 48	on	O
# 49	health-related	O
# 50	quality	O
# 51	of	O
# 52	life	O
# 53	and	O
# 54	skeletal	O
# 55	morbidity	O
# 56	in	O
# 57	patients	O
# 58	with	O
# 59	newly	O
# 60	diagnosed	O
# 61	multiple	O
# 62	myeloma	O
# 63	.	O
# 64	This	O
# 65	double-blind	O
# 66	,	O
# 67	randomised	O
# 68	,	O
# 69	phase	O
# 70	3	O
# 71	trial	O
# 72	was	O
# 73	undertaken	O
# 74	at	O
# 75	37	O
# 76	clinics	O
# 77	in	O
# 78	Denmark	O
# 79	,	O
# 80	Norway	O
# 81	,	O
# 82	and	O
# 83	Sweden	O
# 84	.	O
# 85	Patients	O
# 86	with	O
# 87	multiple	O
# 88	myeloma	O
# 89	who	O
# 90	were	O
# 91	starting	O
# 92	antimyeloma	O
# 93	treatment	O
# 94	were	O
# 95	randomly	O
# 96	assigned	O
# 97	in	O
# 98	a	O
# 99	1:1	O
# 100	ratio	O
# 101	to	O
# 102	receive	O
# 103	one	O
# 104	of	O
# 105	two	O
# 106	doses	O
# 107	of	O
# 108	pamidronate	O
# 109	(	O
# 110	30	O
# 111	mg	O
# 112	or	O
# 113	90	O
# 114	mg	O
# 115	)	O
# 116	given	O
# 117	by	O
# 118	intravenous	O
# 119	infusion	O
# 120	once	O
# 121	a	O
# 122	month	O
# 123	for	O
# 124	at	O
# 125	least	O
# 126	3	O
# 127	years	O
# 128	.	O
# 129	Randomisation	O
# 130	was	O
# 131	done	O
# 132	by	O
# 133	use	O
# 134	of	O
# 135	a	O
# 136	central	O
# 137	,	O
# 138	computerised	O
# 139	minimisation	O
# 140	system	O
# 141	.	O
# 142	Primary	O
# 143	outcome	O
# 144	was	O
# 145	physical	O
# 146	function	O
# 147	after	O
# 148	12	O
# 149	months	O
# 150	estimated	O
# 151	by	O
# 152	the	O
# 153	European	O
# 154	Organisation	O
# 155	for	O
# 156	Research	O
# 157	and	O
# 158	Treatment	O
# 159	of	O
# 160	Cancer	O
# 161	(	O
# 162	EORTC	O
# 163	)	O
# 164	QLQ-C	O
# 165	30	O
# 166	questionnaire	O
# 167	(	O
# 168	scale	O
# 169	0-100	O
# 170	)	O
# 171	.	O
# 172	All	O
# 173	patients	O
# 174	who	O
# 175	returned	O
# 176	questionnaires	O
# 177	at	O
# 178	12	O
# 179	months	O
# 180	and	O
# 181	were	O
# 182	still	O
# 183	on	O
# 184	study	O
# 185	treatment	O
# 186	were	O
# 187	included	O
# 188	in	O
# 189	the	O
# 190	analysis	O
# 191	of	O
# 192	the	O
# 193	primary	O
# 194	endpoint	O
# 195	.	O
# 196	From	O
# 197	January	O
# 198	,	O
# 199	2001	O
# 200	,	O
# 201	until	O
# 202	August	O
# 203	,	O
# 204	2005	O
# 205	,	O
# 206	504	O
# 207	patients	O
# 208	were	O
# 209	randomly	O
# 210	assigned	O
# 211	to	O
# 212	pamidronate	O
# 213	30	O
# 214	mg	O
# 215	or	O
# 216	90	O
# 217	mg	O
# 218	(	O
# 219	252	O
# 220	in	O
# 221	each	O
# 222	group	O
# 223	)	O
# 224	.	O
# 225	157	O
# 226	patients	O
# 227	in	O
# 228	the	O
# 229	90	O
# 230	mg	O
# 231	group	O
# 232	and	O
# 233	156	O
# 234	in	O
# 235	the	O
# 236	30	O
# 237	mg	O
# 238	group	O
# 239	were	O
# 240	included	O
# 241	in	O
# 242	the	O
# 243	primary	O
# 244	analysis	O
# 245	.	O
# 246	Mean	B-Premise
# 247	physical	I-Premise
# 248	function	I-Premise
# 249	at	I-Premise
# 250	12	I-Premise
# 251	months	I-Premise
# 252	was	I-Premise
# 253	66	I-Premise
# 254	points	I-Premise
# 255	(	I-Premise
# 256	95	I-Premise
# 257	%	I-Premise
# 258	CI	I-Premise
# 259	62	I-Premise
# 260	·	I-Premise
# 261	9-70	I-Premise
# 262	·	I-Premise
# 263	0	I-Premise
# 264	)	I-Premise
# 265	in	I-Premise
# 266	the	I-Premise
# 267	90	I-Premise
# 268	mg	I-Premise
# 269	group	I-Premise
# 270	and	I-Premise
# 271	68	I-Premise
# 272	points	I-Premise
# 273	(	I-Premise
# 274	64	I-Premise
# 275	·	I-Premise
# 276	6-71	I-Premise
# 277	·	I-Premise
# 278	4	I-Premise
# 279	)	I-Premise
# 280	in	I-Premise
# 281	the	I-Premise
# 282	30	I-Premise
# 283	mg	I-Premise
# 284	group	I-Premise
# 285	(	I-Premise
# 286	95	I-Premise
# 287	%	I-Premise
# 288	CI	I-Premise
# 289	of	I-Premise
# 290	difference	I-Premise
# 291	-	I-Premise
# 292	6	I-Premise
# 293	·	I-Premise
# 294	6	I-Premise
# 295	to	I-Premise
# 296	3	I-Premise
# 297	·	I-Premise
# 298	3	I-Premise
# 299	;	I-Premise
# 300	p=	I-Premise
# 301	0	I-Premise
# 302	·	I-Premise
# 303	52	I-Premise
# 304	)	I-Premise
# 305	.	O
# 306	Median	B-Premise
# 307	time	I-Premise
# 308	to	I-Premise
# 309	first	I-Premise
# 310	skeletal-related	I-Premise
# 311	event	I-Premise
# 312	in	I-Premise
# 313	patients	I-Premise
# 314	who	I-Premise
# 315	had	I-Premise
# 316	such	I-Premise
# 317	an	I-Premise
# 318	event	I-Premise
# 319	was	I-Premise
# 320	9	I-Premise
# 321	·	I-Premise
# 322	2	I-Premise
# 323	months	I-Premise
# 324	(8	I-Premise
# 325	·	I-Premise
# 326	1-10	I-Premise
# 327	·	I-Premise
# 328	7	I-Premise
# 329	)	I-Premise
# 330	in	I-Premise
# 331	the	I-Premise
# 332	90	I-Premise
# 333	mg	I-Premise
# 334	group	I-Premise
# 335	and	I-Premise
# 336	10	I-Premise
# 337	·	I-Premise
# 338	2	I-Premise
# 339	months	I-Premise
# 340	(	I-Premise
# 341	7	I-Premise
# 342	·	I-Premise
# 343	3-14	I-Premise
# 344	·	I-Premise
# 345	0	I-Premise
# 346	)	I-Premise
# 347	in	I-Premise
# 348	the	I-Premise
# 349	30	I-Premise
# 350	mg	I-Premise
# 351	group	I-Premise
# 352	(	I-Premise
# 353	p=	I-Premise
# 354	0	I-Premise
# 355	·	I-Premise
# 356	63	I-Premise
# 357	)	I-Premise
# 358	.	O
# 359	In	O
# 360	a	O
# 361	retrospective	O
# 362	analysis	O
# 363	,	O
# 364	eight	B-Premise
# 365	patients	I-Premise
# 366	in	I-Premise
# 367	the	I-Premise
# 368	pamidronate	I-Premise
# 369	90	I-Premise
# 370	mg	I-Premise
# 371	group	I-Premise
# 372	developed	I-Premise
# 373	osteonecrosis	I-Premise
# 374	of	I-Premise
# 375	the	I-Premise
# 376	jaw	I-Premise
# 377	compared	I-Premise
# 378	with	I-Premise
# 379	two	I-Premise
# 380	patients	I-Premise
# 381	in	I-Premise
# 382	the	I-Premise
# 383	30	I-Premise
# 384	mg	I-Premise
# 385	group	I-Premise
# 386	.	O
# 387	Monthly	B-Claim
# 388	infusion	I-Claim
# 389	of	I-Claim
# 390	pamidronate	I-Claim
# 391	30	I-Claim
# 392	mg	I-Claim
# 393	should	I-Claim
# 394	be	I-Claim
# 395	the	I-Claim
# 396	recommended	I-Claim
# 397	dose	I-Claim
# 398	for	I-Claim
# 399	prevention	I-Claim
# 400	of	I-Claim
# 401	bone	I-Claim
# 402	disease	I-Claim
# 403	in	I-Claim
# 404	patients	I-Claim
# 405	with	I-Claim
# 406	multiple	I-Claim
# 407	myeloma	I-Claim
# 408	.	O
#
# (364, 386)	Support	(387, 408)
# (306, 358)	Support	(387, 408)
# (246, 305)	Support	(387, 408)
#
# 0	The	B-Claim
# 1	addition	I-Claim
# 2	of	I-Claim
# 3	bevacizumab	I-Claim
# 4	to	I-Claim
# 5	paclitaxel	I-Claim
# 6	improved	I-Claim
# 7	progression-free	I-Claim
# 8	survival	I-Claim
# 9	(	I-Claim
# 10	PFS	I-Claim
# 11	)	I-Claim
# 12	of	I-Claim
# 13	patients	I-Claim
# 14	with	I-Claim
# 15	metastatic	I-Claim
# 16	breast	I-Claim
# 17	cancer	I-Claim
# 18	(	I-Claim
# 19	MBC	I-Claim
# 20	)	I-Claim
# 21	.	O
# 22	We	O
# 23	examined	O
# 24	the	O
# 25	efficacy	O
# 26	and	O
# 27	safety	O
# 28	of	O
# 29	adding	O
# 30	gemcitabine	O
# 31	to	O
# 32	paclitaxel	O
# 33	/	O
# 34	bevacizumab	O
# 35	(	O
# 36	PB	O
# 37	)	O
# 38	.	O
# 39	In	O
# 40	this	O
# 41	multicenter	O
# 42	,	O
# 43	open-label	O
# 44	,	O
# 45	randomized	O
# 46	phase	O
# 47	II	O
# 48	trial	O
# 49	,	O
# 50	women	O
# 51	with	O
# 52	locally	O
# 53	advanced	O
# 54	or	O
# 55	MBC	O
# 56	were	O
# 57	randomly	O
# 58	assigned	O
# 59	to	O
# 60	receive	O
# 61	paclitaxel	O
# 62	90	O
# 63	mg	O
# 64	/	O
# 65	m	O
# 66	(	O
# 67	2	O
# 68	)	O
# 69	(	O
# 70	days	O
# 71	1	O
# 72	,	O
# 73	8	O
# 74	,	O
# 75	15	O
# 76	)	O
# 77	and	O
# 78	bevacizumab	O
# 79	10	O
# 80	mg	O
# 81	/	O
# 82	kg	O
# 83	(	O
# 84	days	O
# 85	1	O
# 86	,	O
# 87	15	O
# 88	)	O
# 89	with	O
# 90	or	O
# 91	without	O
# 92	gemcitabine	O
# 93	1500	O
# 94	mg	O
# 95	/	O
# 96	m	O
# 97	(	O
# 98	2	O
# 99	)	O
# 100	(	O
# 101	days	O
# 102	1	O
# 103	,	O
# 104	15	O
# 105	)	O
# 106	in	O
# 107	28	O
# 108	-	O
# 109	day	O
# 110	cycles	O
# 111	.	O
# 112	Patients	O
# 113	with	O
# 114	prior	O
# 115	cytotoxic	O
# 116	therapy	O
# 117	for	O
# 118	MBC	O
# 119	were	O
# 120	ineligible	O
# 121	.	O
# 122	The	O
# 123	primary	O
# 124	endpoint	O
# 125	was	O
# 126	investigator-assessed	O
# 127	overall	O
# 128	response	O
# 129	rate	O
# 130	(	O
# 131	ORR	O
# 132	);	O
# 133	secondary	O
# 134	endpoints	O
# 135	were	O
# 136	PFS	O
# 137	,	O
# 138	overall	O
# 139	survival	O
# 140	(	O
# 141	OS	O
# 142	)	O
# 143	,	O
# 144	safety	O
# 145	,	O
# 146	and	O
# 147	quality	O
# 148	of	O
# 149	life	O
# 150	.	O
# 151	Ninety-four	O
# 152	patients	O
# 153	received	O
# 154	PB	O
# 155	,	O
# 156	and	O
# 157	93	O
# 158	received	O
# 159	paclitaxel	O
# 160	/	O
# 161	bevacizumab	O
# 162	/	O
# 163	gemcitabine	O
# 164	(	O
# 165	PB	O
# 166	+	O
# 167	G	O
# 168	)	O
# 169	.	O
# 170	The	B-Premise
# 171	ORRs	I-Premise
# 172	were	I-Premise
# 173	48.9	I-Premise
# 174	%	I-Premise
# 175	(	I-Premise
# 176	95	I-Premise
# 177	%	I-Premise
# 178	confidence	I-Premise
# 179	interval	I-Premise
# 180	[	I-Premise
# 181	CI	I-Premise
# 182	]	I-Premise
# 183	,	I-Premise
# 184	38.5	I-Premise
# 185	%	I-Premise
# 186	-59.5	I-Premise
# 187	%	I-Premise
# 188	)	I-Premise
# 189	and	I-Premise
# 190	58.7	I-Premise
# 191	%	I-Premise
# 192	(	I-Premise
# 193	95	I-Premise
# 194	%	I-Premise
# 195	CI	I-Premise
# 196	,	I-Premise
# 197	47.9	I-Premise
# 198	%	I-Premise
# 199	-68.9	I-Premise
# 200	%	I-Premise
# 201	;	I-Premise
# 202	P	I-Premise
# 203	=	I-Premise
# 204	.	I-Premise
# 205	117	I-Premise
# 206	)	I-Premise
# 207	with	I-Premise
# 208	PB	I-Premise
# 209	and	I-Premise
# 210	PB	I-Premise
# 211	+	I-Premise
# 212	G	I-Premise
# 213	,	I-Premise
# 214	respectively	I-Premise
# 215	.	O
# 216	The	B-Premise
# 217	median	I-Premise
# 218	PFS	I-Premise
# 219	was	I-Premise
# 220	8.8	I-Premise
# 221	months	I-Premise
# 222	(	I-Premise
# 223	95	I-Premise
# 224	%	I-Premise
# 225	CI	I-Premise
# 226	,	I-Premise
# 227	8.1-	I-Premise
# 228	10.4	I-Premise
# 229	months	I-Premise
# 230	)	I-Premise
# 231	and	I-Premise
# 232	11.3	I-Premise
# 233	months	I-Premise
# 234	(	I-Premise
# 235	95	I-Premise
# 236	%	I-Premise
# 237	CI	I-Premise
# 238	,	I-Premise
# 239	9.7-	I-Premise
# 240	12.7	I-Premise
# 241	months	I-Premise
# 242	;	I-Premise
# 243	P	I-Premise
# 244	=	I-Premise
# 245	.	I-Premise
# 246	247	I-Premise
# 247	;	I-Premise
# 248	hazard	I-Premise
# 249	ratio	I-Premise
# 250	,	I-Premise
# 251	0.82	I-Premise
# 252	);	I-Premise
# 253	the	I-Premise
# 254	median	I-Premise
# 255	OS	I-Premise
# 256	was	I-Premise
# 257	25.0	I-Premise
# 258	months	I-Premise
# 259	(	I-Premise
# 260	95	I-Premise
# 261	%	I-Premise
# 262	CI	I-Premise
# 263	,	I-Premise
# 264	18.8-	I-Premise
# 265	not	I-Premise
# 266	assessable	I-Premise
# 267	[	I-Premise
# 268	N	I-Premise
# 269	/	I-Premise
# 270	A	I-Premise
# 271	]	I-Premise
# 272	months	I-Premise
# 273	)	I-Premise
# 274	and	I-Premise
# 275	24.3	I-Premise
# 276	months	I-Premise
# 277	(	I-Premise
# 278	95	I-Premise
# 279	%	I-Premise
# 280	CI	I-Premise
# 281	,	I-Premise
# 282	20.3-	I-Premise
# 283	N	I-Premise
# 284	/	I-Premise
# 285	A	I-Premise
# 286	months	I-Premise
# 287	;	I-Premise
# 288	P	I-Premise
# 289	=	I-Premise
# 290	.	I-Premise
# 291	475	I-Premise
# 292	;	I-Premise
# 293	hazard	I-Premise
# 294	ratio	I-Premise
# 295	,	I-Premise
# 296	0.84	I-Premise
# 297	)	I-Premise
# 298	,	I-Premise
# 299	with	I-Premise
# 300	PB	I-Premise
# 301	and	I-Premise
# 302	PB	I-Premise
# 303	+	I-Premise
# 304	G	I-Premise
# 305	,	I-Premise
# 306	respectively	I-Premise
# 307	.	O
# 308	There	B-Premise
# 309	was	I-Premise
# 310	significantly	I-Premise
# 311	more	I-Premise
# 312	grade	I-Premise
# 313	3-4	I-Premise
# 314	neutropenia	I-Premise
# 315	(	I-Premise
# 316	P	I-Premise
# 317	=	I-Premise
# 318	.	I-Premise
# 319	001	I-Premise
# 320	)	I-Premise
# 321	and	I-Premise
# 322	dyspnea	I-Premise
# 323	(	I-Premise
# 324	P	I-Premise
# 325	=	I-Premise
# 326	.	I-Premise
# 327	014	I-Premise
# 328	)	I-Premise
# 329	with	I-Premise
# 330	PB	I-Premise
# 331	+	I-Premise
# 332	G	I-Premise
# 333	.	O
# 334	Patients	B-Premise
# 335	treated	I-Premise
# 336	with	I-Premise
# 337	PB	I-Premise
# 338	experienced	I-Premise
# 339	more	I-Premise
# 340	improvement	I-Premise
# 341	in	I-Premise
# 342	total	I-Premise
# 343	FACT-B	I-Premise
# 344	(	I-Premise
# 345	Functional	I-Premise
# 346	Assessment	I-Premise
# 347	of	I-Premise
# 348	Cancer	I-Premise
# 349	Therapy-Breast	I-Premise
# 350	)	I-Premise
# 351	(	I-Premise
# 352	P	I-Premise
# 353	=	I-Premise
# 354	.	I-Premise
# 355	021	I-Premise
# 356	)	I-Premise
# 357	,	I-Premise
# 358	FACT-B	I-Premise
# 359	Social	I-Premise
# 360	/	I-Premise
# 361	Family	I-Premise
# 362	Well-being	I-Premise
# 363	(	I-Premise
# 364	P	I-Premise
# 365	=	I-Premise
# 366	.	I-Premise
# 367	041	I-Premise
# 368	)	I-Premise
# 369	,	I-Premise
# 370	and	I-Premise
# 371	Breast	I-Premise
# 372	Cancer-Additional	I-Premise
# 373	Concerns	I-Premise
# 374	(	I-Premise
# 375	P	I-Premise
# 376	=	I-Premise
# 377	.	I-Premise
# 378	008	I-Premise
# 379	)	I-Premise
# 380	scores	I-Premise
# 381	than	I-Premise
# 382	patients	I-Premise
# 383	treated	I-Premise
# 384	with	I-Premise
# 385	PB	I-Premise
# 386	+	I-Premise
# 387	G	I-Premise
# 388	.	O
# 389	The	B-Claim
# 390	addition	I-Claim
# 391	of	I-Claim
# 392	gemcitabine	I-Claim
# 393	to	I-Claim
# 394	PB	I-Claim
# 395	was	I-Claim
# 396	not	I-Claim
# 397	associated	I-Claim
# 398	with	I-Claim
# 399	a	I-Claim
# 400	statistically	I-Claim
# 401	significant	I-Claim
# 402	improvement	I-Claim
# 403	in	I-Claim
# 404	ORR	I-Claim
# 405	.	O
# 406	Treatment	B-Claim
# 407	with	I-Claim
# 408	PB	I-Claim
# 409	+	I-Claim
# 410	G	I-Claim
# 411	increased	I-Claim
# 412	the	I-Claim
# 413	incidence	I-Claim
# 414	of	I-Claim
# 415	severe	I-Claim
# 416	neutropenia	I-Claim
# 417	and	I-Claim
# 418	dyspnea	I-Claim
# 419	,	O
# 420	although	B-Claim
# 421	the	I-Claim
# 422	regimen	I-Claim
# 423	generally	I-Claim
# 424	was	I-Claim
# 425	well	I-Claim
# 426	tolerated	I-Claim
# 427	.	O
#
# (420, 427)	Partial-Attack	(406, 419)
# (308, 333)	Support	(406, 419)
# (170, 215)	Support	(389, 405)
# (216, 307)	Support	(0, 21)
#
# 0	For	B-Claim
# 1	men	I-Claim
# 2	with	I-Claim
# 3	localised	I-Claim
# 4	prostate	I-Claim
# 5	cancer	I-Claim
# 6	,	I-Claim
# 7	surgery	I-Claim
# 8	provides	I-Claim
# 9	a	I-Claim
# 10	survival	I-Claim
# 11	benefit	I-Claim
# 12	compared	I-Claim
# 13	with	I-Claim
# 14	watchful	I-Claim
# 15	waiting	I-Claim
# 16	.	O
# 17	Treatments	O
# 18	are	O
# 19	associated	O
# 20	with	O
# 21	morbidity	O
# 22	.	O
# 23	Results	O
# 24	for	O
# 25	functional	O
# 26	outcome	O
# 27	and	O
# 28	quality	O
# 29	of	O
# 30	life	O
# 31	are	O
# 32	rarely	O
# 33	reported	O
# 34	beyond	O
# 35	10	O
# 36	years	O
# 37	and	O
# 38	are	O
# 39	lacking	O
# 40	from	O
# 41	randomised	O
# 42	settings	O
# 43	.	O
# 44	We	O
# 45	report	O
# 46	results	O
# 47	for	O
# 48	quality	O
# 49	of	O
# 50	life	O
# 51	for	O
# 52	men	O
# 53	in	O
# 54	the	O
# 55	Scandinavian	O
# 56	Prostate	O
# 57	Cancer	O
# 58	Group	O
# 59	Study	O
# 60	Number	O
# 61	4	O
# 62	(	O
# 63	SPCG	O
# 64	-	O
# 65	4	O
# 66	)	O
# 67	after	O
# 68	a	O
# 69	median	O
# 70	follow-up	O
# 71	of	O
# 72	more	O
# 73	than	O
# 74	12	O
# 75	years	O
# 76	.	O
# 77	All	O
# 78	living	O
# 79	Swedish	O
# 80	and	O
# 81	Finnish	O
# 82	men	O
# 83	(	O
# 84	400	O
# 85	of	O
# 86	695	O
# 87	)	O
# 88	randomly	O
# 89	assigned	O
# 90	to	O
# 91	radical	O
# 92	prostatectomy	O
# 93	or	O
# 94	watchful	O
# 95	waiting	O
# 96	in	O
# 97	SPCG	O
# 98	-	O
# 99	4	O
# 100	from	O
# 101	1989	O
# 102	to	O
# 103	1999	O
# 104	were	O
# ...
# 245	gain	I-Claim
# 246	knowledge	I-Claim
# 247	and	I-Claim
# 248	correct	I-Claim
# 249	misconceptions	I-Claim
# 250	in	I-Claim
# 251	managing	I-Claim
# 252	their	I-Claim
# 253	cancer	I-Claim
# 254	pain	I-Claim
# 255	.	O
# 256	Integration	B-Claim
# 257	of	I-Claim
# 258	the	I-Claim
# 259	PMP	I-Claim
# 260	into	I-Claim
# 261	routine	I-Claim
# 262	clinical	I-Claim
# 263	work	I-Claim
# 264	may	I-Claim
# 265	help	I-Claim
# 266	to	I-Claim
# 267	improve	I-Claim
# 268	the	I-Claim
# 269	standard	I-Claim
# 270	of	I-Claim
# 271	care	I-Claim
# 272	for	I-Claim
# 273	cancer	I-Claim
# 274	patients	I-Claim
# 275	.	O
# 276	It	O
# 277	is	O
# 278	recommended	O
# 279	to	O
# 280	provide	O
# 281	pain	O
# 282	management	O
# 283	education	O
# 284	to	O
# 285	all	O
# 286	cancer	O
# 287	patients	O
# 288	.	O
#
# (186, 234)	Partial-Attack	(171, 185)
#
# 0	Surgical	O
# 1	resection	O
# 2	is	O
# 3	regarded	O
# 4	as	O
# 5	the	O
# 6	only	O
# 7	curative	O
# 8	option	O
# 9	for	O
# 10	resectable	O
# 11	oesophageal	O
# 12	cancer	O
# 13	,	O
# 14	but	O
# 15	pulmonary	O
# 16	complications	O
# 17	occurring	O
# 18	in	O
# 19	more	O
# 20	than	O
# 21	half	O
# 22	of	O
# 23	patients	O
# 24	after	O
# 25	open	O
# 26	oesophagectomy	O
# 27	are	O
# 28	a	O
# 29	great	O
# 30	concern	O
# 31	.	O
# 32	We	O
# 33	assessed	O
# 34	whether	O
# 35	minimally	O
# 36	invasive	O
# 37	oesophagectomy	O
# 38	reduces	O
# 39	morbidity	O
# 40	compared	O
# 41	with	O
# 42	open	O
# 43	oesophagectomy	O
# 44	.	O
# 45	We	O
# 46	did	O
# 47	a	O
# 48	multicentre	O
# 49	,	O
# 50	open-label	O
# 51	,	O
# 52	randomised	O
# 53	controlled	O
# 54	trial	O
# 55	at	O
# 56	five	O
# 57	study	O
# 58	centres	O
# 59	in	O
# 60	three	O
# 61	countries	O
# 62	between	O
# 63	June	O
# 64	1	O
# 65	,	O
# 66	2009	O
# 67	,	O
# 68	and	O
# 69	March	O
# 70	31	O
# 71	,	O
# 72	2011	O
# 73	.	O
# 74	Patients	O
# 75	aged	O
# 76	18-75	O
# 77	years	O
# 78	with	O
# 79	resectable	O
# 80	cancer	O
# 81	of	O
# 82	the	O
# 83	oesophagus	O
# 84	or	O
# 85	gastro-oesophageal	O
# 86	junction	O
# 87	were	O
# 88	randomly	O
# 89	assigned	O
# 90	via	O
# 91	a	O
# 92	computer-generated	O
# 93	randomisation	O
# 94	sequence	O
# 95	to	O
# 96	receive	O
# 97	either	O
# 98	open	O
# 99	transthoracic	O
# 100	or	O
# 101	minimally	O
# 102	invasive	O
# 103	transthoracic	O
# 104	oesophagectomy	O
# 105	.	O
# 106	Randomisation	O
# 107	was	O
# 108	stratified	O
# 109	by	O
# 110	centre	O
# 111	.	O
# 112	Patients	O
# 113	,	O
# 114	and	O
# 115	investigators	O
# 116	undertaking	O
# 117	interventions	O
# 118	,	O
# 119	assessing	O
# 120	outcomes	O
# 121	,	O
# 122	and	O
# 123	analysing	O
# 124	data	O
# 125	,	O
# 126	were	O
# 127	not	O
# 128	masked	O
# 129	to	O
# 130	group	O
# 131	assignment	O
# 132	.	O
# 133	The	O
# 134	primary	O
# 135	outcome	O
# 136	was	O
# 137	pulmonary	O
# 138	infection	O
# 139	within	O
# 140	the	O
# 141	first	O
# 142	2	O
# 143	weeks	O
# 144	after	O
# 145	surgery	O
# 146	and	O
# 147	during	O
# 148	the	O
# 149	whole	O
# 150	stay	O
# 151	in	O
# 152	hospital	O
# 153	.	O
# 154	Analysis	O
# 155	was	O
# 156	by	O
# 157	intention	O
# 158	to	O
# 159	treat	O
# 160	.	O
# 161	This	O
# 162	trial	O
# 163	is	O
# 164	registered	O
# 165	with	O
# 166	the	O
# 167	Netherlands	O
# 168	Trial	O
# 169	Register	O
# 170	,	O
# 171	NTR	O
# 172	TC	O
# 173	2452	O
# 174	.	O
# 175	We	O
# 176	randomly	O
# 177	assigned	O
# 178	56	O
# 179	patients	O
# 180	to	O
# 181	the	O
# 182	open	O
# 183	oesophagectomy	O
# 184	group	O
# 185	and	O
# 186	59	O
# 187	to	O
# 188	the	O
# 189	minimally	O
# 190	invasive	O
# 191	oesophagectomy	O
# 192	group	O
# 193	.	O
# 194	16	B-Premise
# 195	(	I-Premise
# 196	29	I-Premise
# 197	%	I-Premise
# 198	)	I-Premise
# 199	patients	I-Premise
# 200	in	I-Premise
# 201	the	I-Premise
# 202	open	I-Premise
# 203	oesophagectomy	I-Premise
# 204	group	I-Premise
# 205	had	I-Premise
# 206	pulmonary	I-Premise
# 207	infection	I-Premise
# 208	in	I-Premise
# 209	the	I-Premise
# 210	first	I-Premise
# 211	2	I-Premise
# 212	weeks	I-Premise
# 213	compared	I-Premise
# 214	with	I-Premise
# 215	five	I-Premise
# 216	(	I-Premise
# 217	9	I-Premise
# 218	%	I-Premise
# 219	)	I-Premise
# 220	in	I-Premise
# 221	the	I-Premise
# 222	minimally	I-Premise
# 223	invasive	I-Premise
# 224	group	I-Premise
# 225	(	I-Premise
# 226	relative	I-Premise
# 227	risk	I-Premise
# 228	[	I-Premise
# 229	RR	I-Premise
# 230	]	I-Premise
# 231	0	I-Premise
# 232	·	I-Premise
# 233	30	I-Premise
# 234	,	I-Premise
# 235	95	I-Premise
# 236	%	I-Premise
# 237	CI	I-Premise
# 238	0	I-Premise
# 239	·	I-Premise
# 240	12-0	I-Premise
# 241	·	I-Premise
# 242	76	I-Premise
# 243	;	I-Premise
# 244	p=	I-Premise
# 245	0	I-Premise
# 246	·	I-Premise
# 247	005	I-Premise
# 248	)	I-Premise
# 249	.	O
# 250	19	B-Premise
# 251	(	I-Premise
# 252	34	I-Premise
# 253	%	I-Premise
# 254	)	I-Premise
# 255	patients	I-Premise
# 256	in	I-Premise
# 257	the	I-Premise
# 258	open	I-Premise
# 259	oesophagectomy	I-Premise
# 260	group	I-Premise
# 261	had	I-Premise
# 262	pulmonary	I-Premise
# 263	infection	I-Premise
# 264	in-hospital	I-Premise
# 265	compared	I-Premise
# 266	with	I-Premise
# 267	seven	I-Premise
# 268	(	I-Premise
# 269	12	I-Premise
# 270	%	I-Premise
# 271	)	I-Premise
# 272	in	I-Premise
# 273	the	I-Premise
# 274	minimally	I-Premise
# 275	invasive	I-Premise
# 276	group	I-Premise
# 277	(	I-Premise
# 278	0	I-Premise
# 279	·	I-Premise
# 280	35	I-Premise
# 281	,	I-Premise
# 282	0	I-Premise
# 283	·	I-Premise
# 284	16-0	I-Premise
# 285	·	I-Premise
# 286	78	I-Premise
# 287	;	I-Premise
# 288	p=	I-Premise
# 289	0	I-Premise
# 290	·	I-Premise
# 291	005	I-Premise
# 292	)	I-Premise
# 293	.	O
# 294	For	B-Premise
# 295	in-hospital	I-Premise
# 296	mortality	I-Premise
# 297	,	I-Premise
# 298	one	I-Premise
# 299	patient	I-Premise
# 300	in	I-Premise
# 301	the	I-Premise
# 302	open	I-Premise
# 303	oesophagectomy	I-Premise
# 304	group	I-Premise
# 305	died	I-Premise
# 306	from	I-Premise
# 307	anastomotic	I-Premise
# 308	leakage	I-Premise
# 309	and	I-Premise
# 310	two	I-Premise
# 311	in	I-Premise
# 312	the	I-Premise
# 313	minimally	I-Premise
# 314	invasive	I-Premise
# 315	group	I-Premise
# 316	from	I-Premise
# 317	aspiration	I-Premise
# 318	and	I-Premise
# 319	mediastinitis	I-Premise
# 320	after	I-Premise
# 321	anastomotic	I-Premise
# 322	leakage	I-Premise
# 323	.	O
# 324	These	B-Claim
# 325	findings	I-Claim
# 326	provide	I-Claim
# 327	evidence	I-Claim
# 328	for	I-Claim
# 329	the	I-Claim
# 330	short-term	I-Claim
# 331	benefits	I-Claim
# 332	of	I-Claim
# 333	minimally	I-Claim
# 334	invasive	I-Claim
# 335	oesophagectomy	I-Claim
# 336	for	I-Claim
# 337	patients	I-Claim
# 338	with	I-Claim
# 339	resectable	I-Claim
# 340	oesophageal	I-Claim
# 341	cancer	I-Claim
# 342	.	O
#
# (250, 293)	Support	(324, 342)
# (194, 249)	Support	(324, 342)
#
# 0	To	O
# 1	prospectively	O
# 2	evaluate	O
# 3	and	O
# 4	compare	O
# 5	health-related	O
# 6	quality-of-life	O
# 7	(	O
# 8	QOL	O
# 9	)	O
# 10	outcomes	O
# 11	in	O
# 12	patients	O
# 13	with	O
# 14	head-neck	O
# 15	squamous	O
# 16	cell	O
# 17	carcinoma	O
# 18	randomized	O
# 19	to	O
# 20	either	O
# 21	intensity-modulated	O
# 22	radiation	O
# 23	therapy	O
# 24	(	O
# 25	IMRT	O
# 26	)	O
# 27	or	O
# 28	three-dimensional	O
# 29	conformal	O
# 30	radiotherapy	O
# 31	(	O
# 32	3D	O
# 33	-	O
# 34	CRT	O
# 35	)	O
# 36	and	O
# 37	assess	O
# 38	serial	O
# 39	longitudinal	O
# 40	change	O
# 41	in	O
# 42	QOL	O
# 43	over	O
# 44	time	O
# 45	.	O
# 46	QOL	O
# 47	outcomes	O
# 48	were	O
# 49	assessed	O
# 50	using	O
# 51	the	O
# 52	European	O
# 53	Organization	O
# 54	for	O
# 55	Research	O
# 56	and	O
# 57	Treatment	O
# 58	of	O
# 59	Cancer	O
# 60	(	O
# 61	EORTC	O
# 62	)	O
# 63	QOL	O
# 64	questionnaire	O
# 65	(	O
# 66	QLQ-C	O
# 67	30	O
# 68	)	O
# 69	and	O
# 70	Head-Neck	O
# 71	module	O
# 72	(	O
# 73	HN	O
# 74	-	O
# 75	35	O
# 76	)	O
# 77	at	O
# 78	baseline	O
# 79	(	O
# 80	pre-treatment	O
# 81	)	O
# 82	and	O
# 83	subsequently	O
# 84	periodically	O
# 85	on	O
# 86	follow-up	O
# 87	.	O
# 88	Mean	O
# 89	scores	O
# 90	of	O
# 91	individual	O
# 92	domains	O
# 93	/	O
# 94	scales	O
# 95	of	O
# 96	3D	O
# 97	-	O
# 98	CRT	O
# 99	and	O
# 100	IMRT	O
# 101	were	O
# 102	compared	O
# 103	using	O
# 104	'	O
# 105	t	O
# 106	'	O
# 107	test	O
# 108	at	O
# 109	each	O
# 110	time	O
# 111	point	O
# 112	;	O
# 113	while	O
# 114	longitudinal	O
# 115	change	O
# 116	in	O
# 117	mean	O
# 118	scores	O
# 119	of	O
# 120	both	O
# 121	groups	O
# 122	over	O
# 123	time	O
# 124	was	O
# 125	evaluated	O
# 126	by	O
# 127	repeated	O
# 128	measurement	O
# 129	analysis	O
# 130	of	O
# 131	variance	O
# 132	.	O
# 133	Fifty	O
# 134	eight	O
# 135	of	O
# 136	the	O
# 137	60	O
# 138	randomized	O
# 139	patients	O
# 140	who	O
# 141	filled	O
# 142	the	O
# 143	QOL	O
# 144	questionnaire	O
# 145	at	O
# 146	least	O
# 147	at	O
# 148	one	O
# 149	time	O
# 150	point	O
# 151	were	O
# 152	included	O
# 153	in	O
# 154	the	O
# 155	analysis	O
# 156	.	O
# 157	Several	O
# 158	general	O
# 159	(	O
# 160	emotional	O
# 161	functioning	O
# 162	,	O
# 163	role	O
# 164	functioning	O
# 165	,	O
# 166	social	O
# 167	contact	O
# 168	)	O
# 169	as	O
# 170	well	O
# 171	as	O
# 172	head	O
# 173	and	O
# 174	neck	O
# 175	cancer-specific	O
# 176	(	O
# 177	dry	O
# 178	mouth	O
# 179	,	O
# 180	opening	O
# 181	mouth	O
# 182	,	O
# 183	sticky	O
# 184	saliva	O
# 185	,	O
# 186	pain	O
# 187	,	O
# 188	senses	O
# 189	)	O
# 190	QOL	O
# 191	domains	O
# 192	were	O
# 193	better	O
# 194	preserved	O
# 195	with	O
# 196	IMRT	O
# 197	compared	O
# 198	to	O
# 199	3D	O
# 200	-	O
# 201	CRT	O
# 202	at	O
# 203	different	O
# 204	time	O
# 205	points	O
# 206	.	O
# 207	Importantly	O
# 208	,	O
# 209	none	O
# 210	of	O
# 211	the	O
# 212	QOL	O
# 213	domains	O
# 214	were	O
# 215	worse	O
# 216	with	O
# 217	IMRT	O
# 218	at	O
# 219	any	O
# 220	time	O
# 221	point	O
# 222	.	O
# 223	There	B-Premise
# 224	was	I-Premise
# 225	substantial	I-Premise
# 226	deterioration	I-Premise
# 227	in	I-Premise
# 228	QOL	I-Premise
# 229	scores	I-Premise
# 230	immediate	I-Premise
# 231	post-treatment	I-Premise
# 232	(	I-Premise
# 233	3	I-Premise
# 234	-	I-Premise
# 235	months	I-Premise
# 236	)	I-Premise
# 237	in	I-Premise
# 238	both	I-Premise
# 239	arms	I-Premise
# 240	.	O
# 241	However	B-Premise
# 242	,	I-Premise
# 243	QOL	I-Premise
# 244	scores	I-Premise
# 245	gradually	I-Premise
# 246	but	I-Premise
# 247	definitely	I-Premise
# 248	improved	I-Premise
# 249	over	I-Premise
# 250	time	I-Premise
# 251	for	I-Premise
# 252	most	I-Premise
# 253	domains	I-Premise
# 254	.	O
# 255	Global	B-Premise
# 256	QOL	I-Premise
# 257	,	I-Premise
# 258	emotional	I-Premise
# 259	/	I-Premise
# 260	role	I-Premise
# 261	functioning	I-Premise
# 262	,	I-Premise
# 263	nausea	I-Premise
# 264	/	I-Premise
# 265	vomiting	I-Premise
# 266	,	I-Premise
# 267	pain	I-Premise
# 268	,	I-Premise
# 269	swallowing	I-Premise
# 270	,	I-Premise
# 271	speech	I-Premise
# 272	,	I-Premise
# 273	social	I-Premise
# 274	contact	I-Premise
# 275	/	I-Premise
# 276	eating	I-Premise
# 277	,	I-Premise
# 278	insomnia	I-Premise
# 279	showed	I-Premise
# 280	rapid	I-Premise
# 281	recovery	I-Premise
# 282	(	I-Premise
# 283	<	I-Premise
# 284	6months	I-Premise
# 285	)	I-Premise
# 286	while	I-Premise
# 287	physical	I-Premise
# 288	/	I-Premise
# 289	cognitive	I-Premise
# 290	functioning	I-Premise
# 291	,	I-Premise
# 292	dry	I-Premise
# 293	mouth	I-Premise
# 294	,	I-Premise
# 295	sticky	I-Premise
# 296	saliva	I-Premise
# 297	,	I-Premise
# 298	fatigue	I-Premise
# 299	,	I-Premise
# 300	senses	I-Premise
# 301	showed	I-Premise
# 302	delayed	I-Premise
# 303	recovery	I-Premise
# 304	(	I-Premise
# 305	>	I-Premise
# 306	6months	I-Premise
# 307	)	I-Premise
# 308	.	O
# 309	There	B-Premise
# 310	were	I-Premise
# 311	no	I-Premise
# 312	significant	I-Premise
# 313	differences	I-Premise
# 314	in	I-Premise
# 315	loco-regional	I-Premise
# 316	or	I-Premise
# 317	survival	I-Premise
# 318	between	I-Premise
# 319	the	I-Premise
# 320	two	I-Premise
# 321	arms	I-Premise
# 322	.	O
# 323	There	B-Claim
# 324	is	I-Claim
# 325	substantial	I-Claim
# 326	deterioration	I-Claim
# 327	in	I-Claim
# 328	QOL	I-Claim
# 329	after	I-Claim
# 330	curative-intent	I-Claim
# 331	head-neck	I-Claim
# 332	irradiation	I-Claim
# 333	that	I-Claim
# 334	gradually	I-Claim
# 335	improves	I-Claim
# 336	over	I-Claim
# 337	time	I-Claim
# 338	.	O
# 339	IMRT	B-Claim
# 340	results	I-Claim
# 341	in	I-Claim
# 342	clinically	I-Claim
# 343	meaningful	I-Claim
# 344	and	I-Claim
# 345	statistically	I-Claim
# 346	better	I-Claim
# 347	QOL	I-Claim
# 348	scores	I-Claim
# 349	for	I-Claim
# 350	some	I-Claim
# 351	domains	I-Claim
# 352	compared	I-Claim
# 353	to	I-Claim
# 354	3D	I-Claim
# 355	-	I-Claim
# 356	CRT	I-Claim
# 357	at	I-Claim
# 358	several	I-Claim
# 359	time	I-Claim
# 360	points	I-Claim
# 361	with	I-Claim
# 362	comparable	I-Claim
# 363	disease	I-Claim
# 364	outcomes	I-Claim
# 365	that	I-Claim
# 366	could	I-Claim
# 367	support	I-Claim
# 368	its	I-Claim
# 369	widespread	I-Claim
# 370	adoption	I-Claim
# 371	in	I-Claim
# 372	routine	I-Claim
# 373	clinical	I-Claim
# 374	practice	I-Claim
# 375	.	O
#
# (223, 240)	Support	(323, 338)
# (241, 254)	Support	(339, 375)
# (255, 308)	Support	(339, 375)
#
# 0	It	O
# 1	is	O
# 2	well	O
# 3	documented	O
# 4	that	O
# 5	stress	O
# 6	is	O
# 7	associated	O
# 8	with	O
# 9	negative	O
# 10	health	O
# 11	outcomes	O
# 12	in	O
# 13	cancer	O
# 14	patients	O
# 15	.	O
# 16	The	O
# 17	purpose	O
# 18	of	O
# 19	this	O
# 20	study	O
# 21	was	O
# 22	to	O
# 23	assess	O
# 24	the	O
# 25	effects	O
# 26	of	O
# 27	a	O
# 28	novel	O
# 29	mindfulness	O
# 30	intervention	O
# 31	called	O
# 32	mindfulness-based	O
# 33	art	O
# 34	therapy	O
# 35	(	O
# 36	MBAT	O
# 37	)	O
# 38	versus	O
# 39	standard	O
# 40	educational	O
# 41	support	O
# 42	,	O
# 43	on	O
# 44	indices	O
# 45	of	O
# 46	stress	O
# 47	and	O
# 48	quality	O
# 49	of	O
# 50	life	O
# 51	in	O
# 52	breast	O
# 53	cancer	O
# 54	patients	O
# 55	with	O
# 56	high	O
# 57	stress	O
# 58	levels	O
# 59	.	O
# 60	A	O
# 61	total	O
# 62	of	O
# 63	191	O
# 64	women	O
# 65	were	O
# 66	enrolled	O
# 67	,	O
# 68	stratified	O
# 69	by	O
# 70	age	O
# 71	and	O
# 72	stress	O
# 73	level	O
# 74	,	O
# 75	and	O
# 76	randomized	O
# 77	to	O
# 78	receive	O
# 79	either	O
# 80	an	O
# 81	8	O
# 82	-	O
# 83	week	O
# 84	MBAT	O
# 85	intervention	O
# 86	or	O
# 87	a	O
# 88	breast	O
# 89	cancer	O
# 90	educational	O
# 91	support	O
# 92	program	O
# 93	of	O
# 94	equal	O
# 95	time	O
# 96	and	O
# 97	duration	O
# 98	.	O
# 99	Psychosocial	O
# 100	stress	O
# 101	was	O
# 102	measured	O
# 103	using	O
# 104	the	O
# 105	Symptoms	O
# 106	Checklist	O
# 107	-	O
# 108	90	O
# 109	-	O
# 110	Revised	O
# 111	,	O
# 112	and	O
# 113	quality	O
# 114	of	O
# 115	life	O
# 116	was	O
# 117	measured	O
# 118	using	O
# 119	the	O
# 120	Medical	O
# 121	Outcomes	O
# 122	Study	O
# 123	Short-Form	O
# 124	Health	O
# 125	Survey	O
# 126	at	O
# 127	baseline	O
# 128	,	O
# 129	immediately	O
# 130	post-intervention	O
# 131	,	O
# 132	and	O
# 133	at	O
# 134	6	O
# 135	months	O
# 136	.	O
# 137	Results	B-Premise
# 138	showed	I-Premise
# 139	overall	I-Premise
# 140	significant	I-Premise
# 141	improvements	I-Premise
# 142	in	I-Premise
# 143	psychosocial	I-Premise
# 144	stress	I-Premise
# 145	and	I-Premise
# 146	quality	I-Premise
# 147	of	I-Premise
# 148	life	I-Premise
# 149	in	I-Premise
# 150	both	I-Premise
# 151	the	I-Premise
# 152	MBAT	I-Premise
# 153	and	I-Premise
# 154	educational	I-Premise
# 155	support	I-Premise
# 156	groups	I-Premise
# 157	immediately	I-Premise
# 158	post-intervention	I-Premise
# 159	;	O
# 160	however	B-Premise
# 161	,	I-Premise
# 162	participants	I-Premise
# 163	with	I-Premise
# 164	high	I-Premise
# 165	stress	I-Premise
# 166	levels	I-Premise
# 167	at	I-Premise
# 168	baseline	I-Premise
# 169	had	I-Premise
# 170	significantly	I-Premise
# 171	improved	I-Premise
# 172	overall	I-Premise
# 173	outcomes	I-Premise
# 174	only	I-Premise
# 175	in	I-Premise
# 176	the	I-Premise
# 177	MBAT	I-Premise
# 178	group	I-Premise
# 179	,	I-Premise
# 180	both	I-Premise
# 181	immediately	I-Premise
# 182	post-intervention	I-Premise
# 183	and	I-Premise
# 184	at	I-Premise
# 185	6	I-Premise
# 186	months	I-Premise
# 187	.	O
# 188	In	O
# 189	addition	O
# 190	,	O
# 191	at	B-Premise
# 192	6	I-Premise
# 193	months	I-Premise
# 194	follow-up	I-Premise
# 195	,	I-Premise
# 196	participants	I-Premise
# 197	attending	I-Premise
# 198	five	I-Premise
# 199	or	I-Premise
# 200	more	I-Premise
# 201	sessions	I-Premise
# 202	trended	I-Premise
# 203	toward	I-Premise
# 204	retaining	I-Premise
# 205	treatment	I-Premise
# 206	effects	I-Premise
# 207	better	I-Premise
# 208	in	I-Premise
# 209	the	I-Premise
# 210	MBAT	I-Premise
# 211	than	I-Premise
# 212	in	I-Premise
# 213	the	I-Premise
# 214	control	I-Premise
# 215	group	I-Premise
# 216	.	O
# 217	Finally	O
# 218	,	O
# 219	black	B-Premise
# 220	women	I-Premise
# 221	and	I-Premise
# 222	white	I-Premise
# 223	women	I-Premise
# 224	were	I-Premise
# 225	similar	I-Premise
# 226	in	I-Premise
# 227	terms	I-Premise
# 228	of	I-Premise
# 229	how	I-Premise
# 230	they	I-Premise
# 231	benefited	I-Premise
# 232	from	I-Premise
# 233	the	I-Premise
# 234	MBAT	I-Premise
# 235	intervention	I-Premise
# 236	,	I-Premise
# 237	even	I-Premise
# 238	though	I-Premise
# 239	white	I-Premise
# 240	participants	I-Premise
# 241	tended	I-Premise
# 242	to	I-Premise
# 243	have	I-Premise
# 244	higher	I-Premise
# 245	educational	I-Premise
# 246	level	I-Premise
# 247	and	I-Premise
# 248	marital	I-Premise
# 249	status	I-Premise
# 250	.	O
# 251	In	B-Claim
# 252	conclusion	I-Claim
# 253	,	I-Claim
# 254	MBAT	I-Claim
# 255	is	I-Claim
# 256	associated	I-Claim
# 257	with	I-Claim
# 258	significant	I-Claim
# 259	,	I-Claim
# 260	sustained	I-Claim
# 261	benefits	I-Claim
# 262	across	I-Claim
# 263	a	I-Claim
# 264	diverse	I-Claim
# 265	range	I-Claim
# 266	of	I-Claim
# 267	breast	I-Claim
# 268	cancer	I-Claim
# 269	patients	I-Claim
# 270	,	I-Claim
# 271	particularly	I-Claim
# 272	those	I-Claim
# 273	with	I-Claim
# 274	high	I-Claim
# 275	stress	I-Claim
# 276	levels	I-Claim
# 277	.	O
#
# (219, 250)	Support	(251, 277)
# (191, 216)	Support	(251, 277)
# (160, 187)	Support	(251, 277)
# (137, 159)	Support	(251, 277)
#
# --------------------------------------------------------------------------------
#
#     num tokens     = 5345
#     num parags     = 42
#     num documents  = 14

# %% [markdown]
# ### Building Vocabulary and BIO Labels
# This cell extracts the vocabulary (all unique words) and BIO labels (annotations) from the training data. The tokens `<unk>` and `<pad>` are added to handle unknown words and padding.

# %%
def build_vocab_and_labels(data):
    vocab = set()
    bio_labels = set()

    for doc in data:
        for paragraph in doc['tokens']:
            for token in paragraph:
                vocab.add(token['str'])
                bio_labels.add(token['arg'])

    # add unknown and padding tokens
    vocab = ["<unk>", "<pad>"] + sorted(vocab)
    bio_labels = sorted(bio_labels)

    return vocab, bio_labels

# %% [markdown]
# ### Naive Tokenizer
# This `NaiveTokenizer` class is a basic implementation designed for preparing input data for training and evaluation. It converts words and BIO labels into numerical indices for the model, handles padding, and decodes outputs, ensuring smooth interaction with the neural network.

# %%
import torch

class NaiveTokenizer:
    def __init__(self, vocab, bio_labels):
        self.word2idx = {word: idx for idx, word in enumerate(vocab)}
        self.idx2word = {idx: word for word, idx in self.word2idx.items()}

        self.label2idx = {label: idx for idx, label in enumerate(bio_labels)}
        self.idx2label = {idx: label for label, idx in self.label2idx.items()}

        self.pad_token = self.word2idx["<pad>"]

    def encode(self, tokens):
        return [self.word2idx.get(token, self.word2idx["<unk>"]) for token in tokens]

    def decode(self, indices):
        return [self.idx2word[idx] for idx in indices]

    def encode_bio_labels(self, labels):
        return [self.label2idx[label] for label in labels]

    def decode_bio_labels(self, indices):
        return [self.idx2label[idx] for idx in indices]

    def pad_batch(self, batch, pad_token):
        max_len = max(len(seq) for seq in batch)
        return torch.tensor([seq + [pad_token] * (max_len - len(seq)) for seq in batch])

    def collate_fn(self, batch):
        """
        Custom collate function for DataLoader.
        Args:
          batch: List of samples from the dataset.
        Returns:
          input_ids_padded: Padded tensor of input IDs.
          bio_labels_padded: Padded tensor of BIO labels.
        """
        input_ids = [sample["input_ids"] for sample in batch]
        bio_labels = [sample["bio_labels"] for sample in batch]

        input_ids_padded = self.pad_batch(input_ids, self.pad_token)
        bio_labels_padded = self.pad_batch(bio_labels, self.pad_token)

        return input_ids_padded, bio_labels_padded

# %% [markdown]
# ### Dataset Construction
# This `ArgumentationDataset` class processes the raw input data and prepares it for the model. Each document is parsed into paragraphs, and tokens within these paragraphs are encoded into numerical indices using the `NaiveTokenizer`. The resulting dataset provides both input IDs (`input_ids`) and their corresponding BIO labels (`bio_labels`), ready for batching and training.

# %%
from torch.utils.data import Dataset

class ArgumentationDataset(Dataset):
    def __init__(self, data, tokenizer):
        """
        Converts raw argumentation data into a PyTorch-compatible dataset.
        Each data sample contains tokenized input IDs and their corresponding BIO labels,
        making it suitable for sequence labeling tasks.
        """
        self.data = []
        for doc in data:
            for paragraph in doc['tokens']:
                token_ids = tokenizer.encode([token['str'] for token in paragraph])
                bio_labels = tokenizer.encode_bio_labels([token['arg'] for token in paragraph])

                self.data.append({
                    "input_ids": token_ids,
                    "bio_labels": bio_labels
                })

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %% [markdown]
# ### NaiveBIOModel: BIO Tagging for Argument Mining
# This model predicts BIO tags (B-Claim, I-Premise, O, etc.) for tokens in a sequence. It uses token embeddings, an LSTM layer for context, and a linear layer to output predictions.

# %%
import torch.nn as nn

class NaiveBIOModel(nn.Module):
    def __init__(self, emb_size, vocab_size, bio_size, pad_id, num_layers=1):
        """
        Model for predicting BIO annotations.
        Args:
          emb_size (int): Size of the embeddings.
          vocab_size (int): Vocabulary size.
          bio_size (int): Number of BIO classes.
          pad_id (int): ID of the padding token.
          num_layers (int): Number of LSTM layers.
        """
        super().__init__()
        self.pad_id = pad_id

        # Tokens embeddings
        self.word_embedding = nn.Embedding(vocab_size, emb_size, padding_idx=pad_id)

        # LSTM for sequential context
        self.lstm = nn.LSTM(emb_size, emb_size, batch_first=True, num_layers=num_layers)

        # Dropout
        self.dropout = nn.Dropout(0.3)

        # Couche linéaire pour prédire les classes BIO
        self.bio_out = nn.Linear(emb_size, bio_size)

    def forward(self, x):
        """
        Forward pass.
        Args:
          x (torch.Tensor): Sequences of encoded tokens (batch, seq_len).
        Returns:
          logits (torch.Tensor): Logits for BIO classes (batch, seq_len, bio_size).
        """
        x_emb = self.word_embedding(x)

        x_emb = self.dropout(self.word_embedding(x))

        lstm_out, _ = self.lstm(x_emb)

        lstm_out = self.dropout(lstm_out)

        logits = self.bio_out(lstm_out)

        return logits

# %% [markdown]
# ### Training Function with Validation
#
# This function trains the model using a training dataset and evaluates it on a validation dataset after each epoch to support a stopping criterion when training, helping to avoid overfitting and allowing for adjustments to hyperparameters if needed.

# %%
def train_model(model, train_dataloader, dev_dataloader, epochs, device="cpu", lr=0.005):
    """
    Train the model and evaluate on the validation set after each epoch.
    Args:
      model (nn.Module): The model to train.
      train_dataloader (DataLoader): DataLoader for the training dataset.
      dev_dataloader (DataLoader): DataLoader for the validation dataset.
      epochs (int): Number of epochs to train.
      device (str): Training device ('cpu' or 'cuda').
      lr (float): Learning rate.
    """

    model.to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-3)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.2, patience=2
    )

    # Define the loss function with class weights
    criterion = nn.CrossEntropyLoss(ignore_index=model.pad_id)

    best_val_loss = float('inf')
    patience = 3
    patience_counter = 0

    for epoch in range(epochs):
        # Training phase
        model.train()
        train_loss = 0

        for inputs, labels in train_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            logits = model(inputs)
            batch_size, seq_len, bio_size = logits.shape
            loss = criterion(
                logits.view(batch_size * seq_len, bio_size),
                labels.view(-1)
            )

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_dataloader)

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, labels in dev_dataloader:
                inputs, labels = inputs.to(device), labels.to(device)

                # Forward pass
                logits = model(inputs)
                batch_size, seq_len, bio_size = logits.shape
                loss = criterion(
                    logits.view(batch_size * seq_len, bio_size),
                    labels.view(-1)
                )

                val_loss += loss.item()

        val_loss /= len(dev_dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        # Update the learning rate scheduler
        scheduler.step(val_loss)

        # Early Stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), "best_model.pth")  # Save the best model
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping: Validation loss did not improve.")
                break

# %% [markdown]
# ### BIO Prediction Function
# This function predicts BIO labels for a given test dataset using a trained model. It processes each document and paragraph in the test data, encodes the tokens, and uses the model to generate predictions. The predicted labels are then decoded back into human-readable BIO format, enabling the reconstruction of a JSON file, which we will demonstrate in the following steps.

# %%
def predict_bio(model, tokenizer, test_data, device="cpu"):
    """
    Predict BIO annotations for a test dataset.
    Args:
      model (nn.Module): Trained model.
      tokenizer (NaiveTokenizer): Tokenizer used for encoding and decoding.
      test_data (list): Test dataset in JSON format.
      device (str): Device for inference ('cpu' or 'cuda').
    Returns:
      list: List of BIO predictions for each paragraph in the test dataset.
    """
    model.eval()
    model.to(device)
    predictions = []

    with torch.no_grad():
        for doc in test_data:
            doc_predictions = []
            for paragraph in doc['tokens']:
                token_ids = tokenizer.encode([token['str'] for token in paragraph])
                input_tensor = torch.tensor([token_ids]).to(device)

                logits = model(input_tensor)
                bio_preds = torch.argmax(logits, dim=2).squeeze(0).tolist()
                bio_labels = tokenizer.decode_bio_labels(bio_preds)
                doc_predictions.append(bio_labels)

            predictions.append(doc_predictions)

    return predictions

# %% [markdown]
# ### JSON Reconstruction
# This section reconstructs a JSON file that includes tokens and spans derived from the model's predictions, while preserving the original relations from the dataset.

# %%
import json

def create_predictions_json(predictions, test_data, output_filepath, device="cpu"):
    """
    This function reconstructs a JSON file from model predictions while preserving the original relations.
    It updates the tokens and spans using the predicted BIO labels, but keeps the relations from the test data unchanged.

    Args:
        predictions (list): List of predicted BIO labels for each document.
        test_data (list): Original test data in JSON format.
        output_filepath (str): Filepath where the reconstructed JSON will be saved.
        device (str): Device used for processing ('cpu' or 'cuda').
    """
    # Initialize the output data structure
    output_data = []
    for doc, doc_preds in zip(test_data, predictions):
        # Initialize a new document structure for predictions
        pred_doc = {"tokens": [], "spans": [], "rels": doc["rels"]}  # Keep the original relations

        for paragraph, bio_preds in zip(doc['tokens'], doc_preds):
            # Reconstruct tokens with predicted BIO labels
            reconstructed_paragraph = []
            for token, bio_label in zip(paragraph, bio_preds):
                token["arg"] = bio_label  # Assign predicted label to each token
                reconstructed_paragraph.append(token)

            pred_doc["tokens"].append(reconstructed_paragraph)

            # Reconstruct spans based on predicted BIO labels
            spans = reconstruct_spans(reconstructed_paragraph, bio_preds)
            if spans:  # Add spans if any were found
                pred_doc["spans"].extend(spans)

        # Append the reconstructed document to the output data
        output_data.append(pred_doc)

    # Save the reconstructed JSON file to the specified path
    with open(output_filepath, "w") as f:
        json.dump(output_data, f, indent=4)

    print(f"Complete JSON file saved at: {output_filepath}")


def reconstruct_spans(paragraph, bio_labels):
    """
    Reconstruct spans from predicted BIO labels.
    Args:
      paragraph (list): List of tokens in the paragraph.
      bio_labels (list): Predicted BIO labels for the tokens.
    Returns:
      list: A list of reconstructed spans, each represented as a dictionary.
    """
    spans = []  # Initialize an empty list to store spans
    current_span = None  # Variable to hold the current span being constructed

    for idx, label in enumerate(bio_labels):
        if label.startswith("B-"):
            # If a new span starts, close the previous one (if it exists)
            if current_span:
                spans.append(current_span)
            # Create a new span
            current_span = {
                "name": label[2:],  # Extract the type (e.g., "Claim", "Premise") by removing "B-"
                "start": paragraph[idx]["idx"],  # Start index of the span
                "end": paragraph[idx]["idx"]  # Initialize the end index as the start index
            }
        elif label.startswith("I-") and current_span and current_span["name"] == label[2:]:
            # Extend the current span if it matches the "I-" label
            current_span["end"] = paragraph[idx]["idx"]
        else:
            # Close the current span if the label doesn't match "I-*" or if it's "O"
            if current_span:
                current_span["end"] = paragraph[idx]["idx"]  # Include the first non-I-* or O as the end index
                spans.append(current_span)
                current_span = None

    # Add the last span if it wasn't closed
    if current_span:
        spans.append(current_span)

    return spans

# %% [markdown]
# ### Essay Dataset Pipeline
# This pipeline uses the `aae_*.json datasets`, which focuses on argumentative structures within essays. The model is trained, validated, and tested on this dataset. It demonstrates the model's ability to capture argumentative spans and relationships in natural language texts.

# %%
import json
from torch.utils.data import DataLoader
from pathlib import Path

# Dataset Paths
data_folder = Path("data")
train_file_path = data_folder / "aae_train.json"
validation_file_path = data_folder / "aae_dev.json"
test_file_path = data_folder / "aae_test.json"

# Load the training data for the essay dataset (aae_train.json)
with open(train_file_path, "r") as f:
    train_data = json.load(f)

# Build the vocabulary and BIO labels from the training data
vocab, bio_labels = build_vocab_and_labels(train_data)
print("Vocabulary size:", len(vocab))
print("BIO Labels:", bio_labels)

# Initialize the naive tokenizer using the constructed vocabulary and BIO labels
tokenizer = NaiveTokenizer(vocab, bio_labels)

# Instantiate the dataset and DataLoader for the training set
train_dataset = ArgumentationDataset(train_data, tokenizer)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=tokenizer.collate_fn)

# Load the validation data (aae_dev.json)
with open(validation_file_path, "r") as f:
    dev_data = json.load(f)

# Create a DataLoader for the validation dataset
dev_dataset = ArgumentationDataset(dev_data, tokenizer)
dev_dataloader = DataLoader(dev_dataset, batch_size=64, shuffle=False, collate_fn=tokenizer.collate_fn)

# Instantiate the NaiveBIOModel with appropriate parameters
model = NaiveBIOModel(emb_size=128, vocab_size=len(vocab), bio_size=len(bio_labels), pad_id=tokenizer.word2idx["<pad>"])

# Train the model using the training and validation datasets
train_model(model, train_dataloader, dev_dataloader, epochs=10, device="cpu")

# Load the test data for evaluation (aae_test.json)
with open(test_file_path, "r") as f:
    test_data = json.load(f)

# Generate BIO predictions for the test dataset
predictions = predict_bio(model, tokenizer, test_data, device="cpu")
# Out:
# Vocabulary size: 7528
# BIO Labels: ['B-Claim', 'B-MajorClaim', 'B-Premise', 'I-Claim', 'I-MajorClaim', 'I-Premise', 'O']
# Epoch 1/10, Training Loss: 1.2377, Validation Loss: 1.0624
# Epoch 2/10, Training Loss: 0.9701, Validation Loss: 0.9719
# Epoch 3/10, Training Loss: 0.7951, Validation Loss: 0.8495
# Epoch 4/10, Training Loss: 0.6690, Validation Loss: 0.8334
# Epoch 5/10, Training Loss: 0.5837, Validation Loss: 0.8419
# Epoch 6/10, Training Loss: 0.5050, Validation Loss: 0.8139
# Epoch 7/10, Training Loss: 0.4501, Validation Loss: 0.8273
# Epoch 8/10, Training Loss: 0.4172, Validation Loss: 0.8810
# Epoch 9/10, Training Loss: 0.3856, Validation Loss: 0.8634
# Early stopping: Validation loss did not improve.

# %%
# Save the complete predictions to a JSON file
create_predictions_json(predictions, test_data, "aae_predictions_naive.json", device="cpu")

# !python evaluate.py aae_predictions_naive.json aae_test.json
# Out:
# Complete JSON file saved at: aae_predictions_naive.json
#
#
# ********************** SPANS ***************************
#    STRICT EVALUATION
#     > Argument mining spans (unlabeled)
#       Precision : 0.5684005273225203
#       Recall    : 0.45385944323278926
#       F-score   : 0.4992141273034837
#     > Argument mining spans (labeled)
#       Precision : 0.5021464597526635
#       Recall    : 0.39722480285125195
#       F-score   : 0.43875376756198553
#
#     RELAXED EVALUATION (α = 0.5)
#     > Argument mining spans (unlabeled)
#       Precision : 0.6387572251845088
#       Recall    : 0.5927761954090096
#       F-score   : 0.6047907513686014
#     > Argument mining spans (labeled)
#       Precision : 0.5697982327755062
#       Recall    : 0.5143077550395093
#       F-score   : 0.5319557193539048
#
#
#
# ******************* RELATIONS ***************************
#    STRICT EVALUATION
#     > Argument mining spans (unlabeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#     > Argument mining spans (labeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#
#     RELAXED EVALUATION (α = 0.5)
#     > Argument mining spans (unlabeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#     > Argument mining spans (labeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0

# %% [markdown]
# ### Medical Dataset Pipeline
# This pipeline works with the `abstrct_*.json` datasets, which focuses on argumentative structures within medical abstracts. Similar to the essay dataset, the model is trained, validated, and tested on this dataset. The medical dataset offers unique challenges due to its domain-specific language and structure, enabling a comprehensive evaluation of the model's generalizability.

# %%
import json
from torch.utils.data import DataLoader
from pathlib import Path

# Dataset Paths
data_folder = Path("data")
train_file_path = data_folder / "train_data.json"
validation_file_path = data_folder / "validation_data.json"
test_file_path = data_folder / "test_data.json"

# Load the training data for the medical dataset (abstrct_neoplasm_train.json)
with open(train_file_path, "r") as f:
    train_data = json.load(f)

# Build the vocabulary and BIO labels from the training data
vocab, bio_labels = build_vocab_and_labels(train_data)
print("Vocabulary size:", len(vocab))
print("BIO Labels:", bio_labels)

# Initialize the naive tokenizer using the constructed vocabulary and BIO labels
tokenizer = NaiveTokenizer(vocab, bio_labels)

# Instantiate the dataset and DataLoader for the training set
train_dataset = ArgumentationDataset(train_data, tokenizer)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=tokenizer.collate_fn)

# Load the validation data (abstrct_neoplasm_dev.json)
with open(validation_file_path, "r") as f:
    dev_data = json.load(f)

# Create a DataLoader for the validation dataset
dev_dataset = ArgumentationDataset(dev_data, tokenizer)
dev_dataloader = DataLoader(dev_dataset, batch_size=64, shuffle=False, collate_fn=tokenizer.collate_fn)

# Instantiate the NaiveBIOModel with appropriate parameters
model = NaiveBIOModel(emb_size=128, vocab_size=len(vocab), bio_size=len(bio_labels), pad_id=tokenizer.word2idx["<pad>"])

# Train the model using the training and validation datasets
train_model(model, train_dataloader, dev_dataloader, epochs=8, device="cpu")

# Load the test data for evaluation (abstrct_neoplasm_test.json)
with open(test_file_path, "r") as f:
    test_data = json.load(f)

# Generate BIO predictions for the test dataset
predictions = predict_bio(model, tokenizer, test_data, device="cpu")
# Out:
# Vocabulary size: 1272
# BIO Labels: ['B-Claim', 'B-MajorClaim', 'B-Premise', 'I-Claim', 'I-MajorClaim', 'I-Premise', 'O']
# Epoch 1/8 : Training Loss = 1.9865
# Epoch 1/8 : Validation Loss = 1.8065
# Epoch 2/8 : Training Loss = 1.8275
# Epoch 2/8 : Validation Loss = 1.6035
# Epoch 3/8 : Training Loss = 1.6469
# Epoch 3/8 : Validation Loss = 1.3057
# Epoch 4/8 : Training Loss = 1.3738
# Epoch 4/8 : Validation Loss = 1.1033
# Epoch 5/8 : Training Loss = 1.0816
# Epoch 5/8 : Validation Loss = 1.1936
# Epoch 6/8 : Training Loss = 1.1272
# Epoch 6/8 : Validation Loss = 1.1625
# Epoch 7/8 : Training Loss = 1.1025
# Epoch 7/8 : Validation Loss = 1.0626
# Epoch 8/8 : Training Loss = 0.9630
# Epoch 8/8 : Validation Loss = 1.0427

# %% [markdown]
# We encountered a "division by zero" error because the model fails to predict any B labels. As a result, the predictions consist only of O and mainly
# I-Premise labels, which means no spans can be generated. Since spans are constructed starting with a B label, the absence of such labels leads to an empty spans list. Consequently, when we attempt to evaluate the predictions using `evaluate.py`, the absence of spans results in a division by zero during the computation of evaluation metrics.

# %%
# Save the complete predictions to a JSON file
create_predictions_json(predictions, test_data, "abstrct_predictions.json", device="cpu")

# !python evaluate.py abstrct_predictions.json abstrct_neoplasm_test.json
# Out:
# Complete JSON file saved at: abstrct_predictions.json
# [error] division by zero

# %%
# !python view_data.py abstrct_predictions.json
# Out:
# 0	Imatinib	O
# 1	(	O
# 2	Gleevec	O
# 3	)	O
# 4	,	O
# 5	a	O
# 6	highly	O
# 7	effective	O
# 8	specific	O
# 9	tyrosine	O
# 10	kinase	O
# 11	inhibitor	O
# 12	,	O
# 13	demonstrates	O
# 14	a	O
# 15	better	O
# 16	side	O
# 17	effect	O
# 18	profile	O
# 19	than	O
# 20	interferon-alpha	O
# 21	(	O
# 22	IFN	O
# 23	)	O
# 24	,	O
# 25	which	O
# 26	impairs	O
# 27	patients	O
# 28	'	O
# 29	quality	O
# 30	of	O
# 31	life	O
# 32	(	O
# 33	QoL	O
# 34	)	O
# 35	.	O
# 36	This	O
# 37	phase	O
# 38	III	O
# 39	international	O
# 40	study	O
# 41	evaluated	O
# 42	QoL	O
# 43	outcomes	O
# 44	in	O
# 45	1,106	O
# 46	newly	O
# 47	diagnosed	O
# 48	patients	O
# 49	with	O
# 50	chronic-phase	O
# 51	chronic	O
# 52	myeloid	O
# 53	leukemia	O
# 54	(	O
# 55	CML	O
# 56	)	O
# 57	who	O
# 58	were	O
# 59	randomized	O
# 60	to	O
# 61	receive	O
# 62	either	O
# 63	imatinib	O
# 64	400	O
# 65	mg	O
# 66	daily	O
# 67	or	O
# 68	IFN	O
# 69	up	O
# 70	to	O
# 71	5	O
# 72	MU	O
# 73	/	O
# 74	m	O
# 75	(	O
# 76	2	O
# 77	)	O
# 78	/	O
# 79	d	O
# 80	with	O
# 81	cytarabine	O
# 82	(	O
# 83	Ara-C	O
# 84	)	O
# 85	20	O
# 86	mg	O
# 87	/	O
# 88	m	O
# 89	(	O
# 90	2	O
# 91	)	O
# 92	/	O
# 93	d	O
# 94	added	O
# 95	for	O
# 96	10	O
# 97	days	O
# 98	every	O
# 99	month	O
# 100	(	O
# 101	IFN	O
# 102	+	O
# 103	LDAC	O
# 104	)	O
# 105	.	O
# 106	Crossover	O
# 107	to	O
# 108	the	O
# 109	other	O
# 110	treatment	O
# 111	arm	O
# 112	was	O
# 113	permitted	O
# 114	due	O
# 115	to	O
# 116	a	O
# 117	lack	O
# 118	of	O
# 119	efficacy	O
# 120	or	O
# 121	treatment	O
# 122	intolerance	O
# 123	.	O
# 124	QoL	O
# 125	was	O
# 126	assessed	O
# 127	with	O
# 128	the	O
# 129	Functional	O
# 130	Assessment	O
# 131	of	O
# 132	Cancer	O
# 133	Therapy-Biologic	O
# 134	Response	O
# 135	Modifiers	O
# 136	(	O
# 137	FACT-BRM	O
# 138	)	O
# 139	at	O
# 140	baseline	O
# 141	,	O
# 142	monthly	O
# 143	for	O
# 144	6	O
# 145	months	O
# 146	and	O
# 147	then	O
# 148	at	O
# 149	months	O
# 150	9	O
# 151	,	O
# 152	12	O
# 153	,	O
# 154	and	O
# 155	18	O
# 156	.	O
# 157	The	O
# 158	Trial	O
# 159	Outcome	O
# 160	Index	O
# 161	(	O
# 162	TOI	O
# 163	;	O
# 164	a	O
# 165	composite	O
# 166	endpoint	O
# 167	of	O
# 168	physical	O
# 169	/	O
# 170	functional	O
# 171	/	O
# 172	treatment-specific	O
# 173	subscales	O
# 174	)	O
# 175	was	O
# 176	the	O
# 177	primary	O
# 178	endpoint	O
# 179	.	O
# 180	Secondary	O
# 181	endpoints	O
# 182	measured	O
# 183	were	O
# 184	social	O
# 185	/	O
# 186	family	O
# 187	well-being	O
# 188	(	O
# 189	SFWB	O
# 190	)	O
# 191	and	O
# 192	emotional	O
# 193	well-being	O
# 194	(	O
# 195	EWB	O
# 196	)	O
# 197	.	O
# 198	QoL	O
# 199	was	O
# 200	analyzed	O
# 201	for	O
# 202	the	O
# 203	first	O
# 204	18	O
# 205	months	O
# 206	of	O
# 207	treatment	O
# 208	using	O
# 209	mixed	O
# 210	effects	O
# 211	growth	O
# 212	curve	O
# 213	models	O
# 214	.	O
# 215	The	O
# 216	primary	O
# 217	analyses	O
# 218	were	O
# 219	intention-to-treat	O
# 220	(	O
# 221	ITT	O
# 222	);	O
# 223	secondary	O
# 224	analyses	O
# 225	incorporated	O
# 226	crossover	O
# 227	as	O
# 228	a	O
# 229	time-dependent	O
# 230	covariate	O
# 231	.	O
# 232	A	O
# 233	total	O
# 234	of	O
# 235	1,049	O
# 236	patients	O
# 237	completed	O
# 238	at	O
# 239	least	O
# 240	one	O
# 241	QoL	O
# 242	assessment	O
# 243	.	O
# 244	Two	O
# 245	hundred	O
# 246	sixty-one	O
# 247	patients	O
# 248	(	O
# 249	50	O
# 250	%	I-Premise
# 251	)	I-Premise
# 252	crossed	O
# 253	over	O
# 254	from	I-Premise
# 255	IFN	O
# 256	to	O
# 257	imatinib	O
# 258	and	O
# 259	11	O
# 260	(	O
# 261	2	O
# 262	%	I-Premise
# 263	)	I-Premise
# 264	crossed	I-Premise
# 265	over	I-Premise
# 266	from	I-Premise
# 267	imatinib	I-Premise
# 268	to	I-Premise
# 269	IFN	O
# 270	.	O
# 271	There	O
# 272	was	I-Premise
# 273	a	O
# 274	significant	O
# 275	decline	O
# 276	in	O
# 277	TOI	O
# 278	scores	O
# 279	for	O
# 280	the	O
# 281	IFN	O
# 282	treatment	O
# 283	arm	O
# 284	compared	O
# 285	with	O
# 286	preservation	O
# 287	of	O
# 288	baseline	O
# 289	TOI	O
# 290	scores	O
# 291	in	O
# 292	the	O
# 293	imatinib	O
# 294	arm	O
# 295	(	O
# 296	P	O
# 297	<	O
# 298	.	O
# 299	001	O
# 300	,	O
# 301	ITT	O
# 302	)	O
# 303	.	O
# 304	Mean	O
# 305	social	O
# 306	/	O
# 307	family	O
# 308	and	O
# 309	EWB	O
# 310	scores	O
# 311	were	O
# 312	22.8	O
# 313	and	O
# 314	19.5	O
# 315	,	O
# 316	respectively	O
# 317	,	O
# 318	for	O
# 319	imatinib	O
# 320	and	O
# 321	21.6	O
# 322	and	O
# 323	17.6	O
# 324	,	O
# 325	respectively	O
# 326	,	O
# 327	for	O
# 328	IFN	O
# 329	(	O
# 330	P	O
# 331	<	O
# 332	.	O
# 333	001	O
# 334	,	O
# 335	ITT	O
# 336	)	O
# 337	.	O
# 338	After	O
# 339	crossing	O
# 340	over	O
# 341	from	O
# 342	IFN	O
# 343	to	O
# 344	imatinib	O
# 345	,	O
# 346	patients	O
# 347	experienced	O
# 348	a	O
# 349	significant	O
# 350	(	O
# 351	P	O
# 352	<	O
# 353	.	O
# 354	001	O
# 355	)	O
# 356	increase	O
# 357	in	O
# 358	TOI	O
# 359	scores	O
# 360	.	O
# 361	Imatinib	O
# 362	offers	O
# 363	clear	O
# 364	QoL	O
# 365	advantages	O
# 366	over	O
# 367	IFN	O
# 368	as	O
# 369	first-line	O
# 370	treatment	O
# 371	of	O
# 372	chronic-phase	O
# 373	CML	O
# 374	.	O
# 375	In	O
# 376	addition	O
# 377	,	O
# 378	patients	O
# 379	who	O
# 380	crossed	O
# 381	over	O
# 382	to	O
# 383	imatinib	O
# 384	reported	O
# 385	higher	O
# 386	QoL	O
# 387	than	O
# 388	those	I-Premise
# 389	who	O
# 390	remained	O
# 391	on	O
# 392	IFN	O
# 393	.	O
#
# (338, 360)	Support	(378, 393)
# (304, 337)	Support	(361, 374)
# (271, 303)	Support	(361, 374)
#
# 0	The	O
# 1	standard	O
# 2	treatment	O
# 3	for	O
# 4	patients	O
# 5	with	O
# 6	clinically	O
# 7	resectable	O
# 8	rectal	O
# 9	cancer	O
# 10	is	O
# 11	surgery	O
# 12	.	O
# 13	Postoperative	O
# 14	radiochemotherapy	O
# 15	(	O
# 16	RCT	O
# 17	)	O
# 18	is	O
# 19	recommended	O
# 20	for	O
# 21	advanced	O
# 22	disease	O
# 23	(	O
# 24	pT3	O
# 25	/	O
# 26	4	O
# 27	or	O
# 28	pN	O
# 29	+	O
# 30	)	O
# 31	.	O
# 32	In	O
# 33	recent	O
# 34	years	O
# 35	,	O
# 36	encouraging	O
# 37	results	O
# 38	of	O
# 39	pre-operative	O
# 40	radiotherapy	O
# 41	have	O
# 42	been	O
# 43	reported	O
# 44	.	O
# 45	This	O
# 46	prospective	O
# 47	randomized	O
# 48	phase-III-trial	O
# 49	(	O
# 50	CAO	O
# 51	/	O
# 52	ARO	O
# 53	/	O
# 54	AIO	O
# 55	-	O
# 56	94	O
# 57	)	O
# 58	compares	O
# 59	the	O
# 60	efficacy	O
# 61	of	O
# 62	neoadjuvant	O
# 63	RCT	O
# 64	to	O
# 65	standard	O
# 66	postoperative	O
# 67	RCT	O
# 68	.	O
# 69	We	O
# 70	report	O
# 71	on	O
# 72	the	O
# 73	design	O
# 74	of	O
# 75	the	O
# 76	study	O
# 77	and	O
# 78	first	O
# 79	results	O
# 80	with	O
# 81	regard	O
# 82	to	O
# 83	toxicity	O
# 84	of	O
# 85	RCT	O
# 86	and	O
# 87	postoperative	O
# 88	morbidity	O
# 89	.	O
# 90	Patients	O
# 91	with	O
# 92	locally	O
# 93	advanced	O
# 94	operable	O
# 95	rectal	O
# 96	cancer	O
# 97	(	O
# 98	uT3	O
# 99	/	O
# 100	4	O
# 101	or	O
# 102	uN	O
# 103	+	O
# 104	,	O
# 105	Mason	O
# 106	CS	O
# 107	III	O
# 108	/	O
# 109	IV	O
# 110	)	O
# 111	were	O
# 112	randomly	O
# 113	assigned	O
# 114	to	O
# 115	pre	O
# 116	or	O
# 117	postoperative	O
# 118	RCT	O
# 119	:	O
# 120	A	O
# 121	total	O
# 122	dose	O
# 123	of	O
# 124	50.4	O
# 125	Gy	O
# 126	(	O
# 127	single	O
# 128	dose	O
# 129	1.8	O
# 130	Gy	O
# 131	)	O
# 132	was	I-Premise
# 133	applied	O
# 134	to	O
# 135	the	O
# 136	tumour	I-Premise
# 137	and	O
# 138	the	O
# 139	pelvic	O
# 140	lymph	O
# 141	nodes	O
# 142	.	O
# 143	5	O
# 144	-	O
# 145	FU	O
# 146	(	O
# 147	1000	O
# 148	mg	O
# 149	/	O
# 150	m2	O
# 151	/	O
# 152	d	O
# 153	)	O
# 154	was	O
# 155	administered	O
# 156	concomitantly	O
# 157	in	O
# 158	the	O
# 159	1th	O
# 160	and	O
# 161	5th	O
# 162	week	O
# 163	of	O
# 164	radiation	O
# 165	as	O
# 166	120	O
# 167	h-continuous	O
# 168	infusion	O
# 169	.	O
# 170	Four	O
# 171	additional	O
# 172	cycles	O
# 173	of	O
# 174	5	O
# 175	-	O
# 176	FU-chemotherapy	O
# 177	(	O
# 178	500	O
# 179	mg	O
# 180	/	O
# 181	m2	O
# 182	/	O
# 183	d	O
# 184	,	O
# 185	i	O
# 186	.	O
# 187	v	O
# 188	.	O
# 189	-	O
# 190	bolus	O
# 191	)	O
# 192	were	O
# 193	applied	O
# 194	.	O
# 195	RCT	O
# 196	was	O
# 197	identical	O
# 198	in	O
# 199	both	O
# 200	arms	O
# 201	except	O
# 202	for	O
# 203	a	O
# 204	small-volume	O
# 205	boost	O
# 206	of	O
# 207	5.4	O
# 208	Gy	O
# 209	postoperatively	O
# 210	.	O
# 211	The	O
# 212	time	O
# 213	interval	O
# 214	between	O
# 215	RCT	O
# 216	and	O
# 217	surgery	O
# 218	was	I-Premise
# 219	4-6	O
# 220	weeks	O
# 221	in	O
# 222	both	O
# 223	arms	O
# 224	.	O
# 225	Techniques	O
# 226	of	O
# 227	surgery	O
# 228	were	O
# 229	standardized	O
# 230	and	O
# 231	included	O
# 232	total	O
# 233	mesorectal	O
# 234	excision	O
# 235	.	O
# 236	Primary	O
# 237	endpoints	O
# 238	of	O
# 239	the	O
# 240	study	O
# 241	are	O
# 242	5	O
# 243	-	O
# 244	year	O
# 245	survival	O
# 246	and	O
# 247	local	O
# 248	and	O
# 249	distant	O
# 250	control	O
# 251	.	O
# 252	Secondary	O
# 253	endpoints	O
# 254	include	O
# 255	the	O
# 256	rate	O
# 257	of	O
# 258	curative	O
# 259	(	O
# 260	R0	O
# 261	)	O
# 262	resection	O
# 263	and	O
# 264	sphincter	O
# 265	saving	O
# 266	procedures	O
# 267	,	O
# 268	toxicity	O
# 269	of	O
# 270	RCT	O
# 271	,	O
# 272	surgical	O
# 273	complications	O
# 274	and	O
# 275	quality	O
# 276	of	O
# 277	life	O
# 278	.	O
# 279	As	O
# 280	of	O
# 281	July	O
# 282	2002	O
# 283	,	O
# 284	805	O
# 285	patients	O
# 286	were	O
# 287	randomized	O
# 288	from	O
# 289	26	O
# 290	participating	O
# 291	institutions	O
# 292	.	O
# 293	Acute	O
# 294	toxicity	O
# 295	(	O
# 296	WHO	O
# 297	)	O
# 298	of	O
# 299	RCT	O
# 300	was	O
# 301	low	O
# 302	,	O
# 303	with	O
# 304	less	O
# 305	than	I-Premise
# 306	15	O
# 307	%	I-Premise
# 308	of	I-Premise
# 309	patients	O
# 310	experiencing	O
# 311	grade	O
# 312	3	O
# 313	or	O
# 314	higher	O
# 315	toxicity	O
# 316	:	O
# 317	The	O
# 318	principal	O
# 319	toxicity	O
# 320	was	I-Premise
# 321	diarrhea	O
# 322	,	O
# 323	with	O
# 324	12	O
# 325	%	I-Premise
# 326	in	I-Premise
# 327	the	I-Premise
# 328	postoperative	O
# 329	RCT-arm	O
# 330	and	O
# 331	11	O
# 332	%	I-Premise
# 333	in	I-Premise
# 334	the	I-Premise
# 335	pre-operative	O
# 336	RCT-arm	O
# 337	having	O
# 338	grade	O
# 339	3	O
# 340	-	O
# 341	,	O
# 342	and	O
# 343	1	O
# 344	%	I-Premise
# 345	in	I-Premise
# 346	either	O
# 347	arm	O
# 348	having	O
# 349	grade	O
# 350	4	O
# 351	-	O
# 352	diarrhea	O
# 353	.	O
# 354	Erythema	O
# 355	,	O
# 356	nausea	O
# 357	and	O
# 358	leukopenia	O
# 359	were	O
# 360	the	O
# 361	next	O
# 362	common	O
# 363	toxicities	O
# 364	,	O
# 365	with	O
# 366	less	O
# 367	than	O
# 368	3	O
# 369	%	I-Premise
# 370	of	I-Premise
# 371	patients	O
# 372	in	O
# 373	either	O
# 374	arm	O
# 375	suffering	O
# 376	grade	O
# 377	3	O
# 378	or	O
# 379	greater	O
# 380	leukopenia	O
# 381	or	O
# 382	nausea	O
# 383	.	O
# 384	Postoperative	O
# 385	complication	O
# 386	rates	O
# 387	were	O
# 388	similar	O
# 389	in	O
# 390	both	O
# 391	arms	O
# 392	,	O
# 393	with	O
# 394	12	O
# 395	%	I-Premise
# 396	(	I-Premise
# 397	postop	O
# 398	.	O
# 399	RCT	O
# 400	)	O
# 401	and	O
# 402	12	O
# 403	%	I-Premise
# 404	(	O
# 405	pre-op	O
# 406	.	O
# 407	RCT	O
# 408	)	O
# 409	of	O
# 410	patients	O
# 411	,	O
# 412	respectively	O
# 413	,	O
# 414	suffering	O
# 415	from	O
# 416	anastomotic	O
# 417	leakage	O
# 418	,	O
# 419	3	O
# 420	%	I-Premise
# 421	(	I-Premise
# 422	postop	I-Premise
# 423	.	O
# 424	RCT	O
# 425	)	O
# 426	and	O
# 427	3	O
# 428	%	I-Premise
# 429	(	I-Premise
# 430	pre-op	O
# 431	.	O
# 432	RCT	O
# 433	)	O
# 434	from	O
# 435	postoperative	O
# 436	bleeding	O
# 437	,	O
# 438	and	O
# 439	6	O
# 440	%	I-Premise
# 441	(	I-Premise
# 442	postop	O
# 443	.	O
# 444	RCT	O
# 445	)	O
# 446	and	O
# 447	4	O
# 448	%	I-Premise
# 449	(	O
# 450	pre-op	O
# 451	.	O
# 452	RCT	O
# 453	)	O
# 454	from	O
# 455	delayed	O
# 456	wound	O
# 457	healing	O
# 458	.	O
# 459	The	O
# 460	patient	O
# 461	accrual	O
# 462	to	O
# 463	the	O
# 464	trial	O
# 465	is	O
# 466	satisfactory	O
# 467	.	O
# 468	Neoadjuvant	O
# 469	RCT	O
# 470	is	O
# 471	well	O
# 472	tolerated	O
# 473	and	O
# 474	bears	O
# 475	no	O
# 476	higher	O
# 477	risk	O
# 478	for	O
# 479	postoperative	O
# 480	morbidity	O
# 481	.	O
#
# (293, 316)	Support	(468, 481)
# (317, 353)	Support	(468, 481)
# (354, 383)	Support	(468, 481)
# (384, 458)	Support	(468, 481)
#
# 0	Research	B-Claim
# 1	suggests	O
# 2	that	I-Claim
# 3	stress-reduction	O
# 4	programs	O
# 5	tailored	O
# 6	to	O
# 7	the	O
# 8	cancer	O
# 9	setting	O
# 10	help	O
# 11	patients	O
# 12	cope	O
# 13	with	O
# 14	the	O
# 15	effects	O
# 16	of	O
# 17	treatment	O
# 18	and	O
# 19	improve	O
# 20	their	O
# 21	quality	O
# 22	of	O
# 23	life	O
# 24	.	O
# 25	Yoga	O
# 26	,	O
# 27	an	O
# 28	ancient	O
# 29	Eastern	O
# 30	science	O
# 31	,	O
# 32	incorporates	O
# 33	stress-reduction	O
# 34	techniques	O
# 35	that	O
# 36	include	O
# 37	regulated	O
# 38	breathing	O
# 39	,	O
# 40	visual	O
# 41	imagery	O
# 42	,	O
# 43	and	O
# 44	meditation	O
# 45	as	O
# 46	well	O
# 47	as	O
# 48	various	O
# 49	postures	O
# 50	.	O
# 51	The	O
# 52	authors	O
# 53	examined	O
# 54	the	O
# 55	effects	O
# 56	of	O
# 57	the	O
# 58	Tibetan	O
# 59	yoga	O
# 60	(	O
# 61	TY	O
# 62	)	O
# 63	practices	O
# 64	of	O
# 65	Tsa	O
# 66	lung	O
# 67	and	O
# 68	Trul	O
# 69	khor	O
# 70	,	O
# 71	which	O
# 72	incorporate	O
# 73	controlled	O
# 74	breathing	O
# 75	and	O
# 76	visualization	O
# 77	,	O
# 78	mindfulness	O
# 79	techniques	O
# 80	,	O
# 81	and	O
# 82	low-impact	O
# 83	postures	O
# 84	in	O
# 85	patients	O
# 86	with	O
# 87	lymphoma	O
# 88	.	O
# 89	Thirty-nine	O
# 90	patients	O
# 91	with	O
# 92	lymphoma	O
# 93	who	O
# 94	were	O
# 95	undergoing	O
# 96	treatment	O
# 97	or	O
# 98	who	O
# 99	had	O
# 100	concluded	O
# 101	treatment	O
# 102	within	O
# 103	the	O
# 104	past	O
# 105	12	O
# 106	months	O
# 107	were	O
# 108	assigned	O
# 109	to	O
# 110	a	O
# 111	TY	O
# 112	group	O
# 113	or	O
# 114	to	O
# 115	a	O
# 116	wait-list	O
# 117	control	O
# 118	group	O
# 119	.	O
# 120	Patients	O
# 121	in	O
# 122	the	O
# 123	TY	O
# 124	group	O
# 125	participated	O
# 126	in	O
# 127	7	O
# 128	weekly	O
# 129	yoga	O
# 130	sessions	O
# 131	,	O
# 132	and	O
# 133	patients	O
# 134	in	O
# 135	the	O
# 136	wait-list	O
# 137	control	O
# 138	group	O
# 139	were	O
# 140	free	O
# 141	to	O
# 142	participate	O
# 143	in	O
# 144	the	O
# 145	TY	O
# 146	program	O
# 147	after	O
# 148	the	O
# 149	3	O
# 150	-	O
# 151	month	O
# 152	follow-up	O
# 153	assessment	O
# 154	.	O
# 155	Eighty	O
# 156	nine	O
# 157	percent	O
# 158	of	O
# 159	TY	O
# 160	participants	O
# 161	completed	O
# 162	at	O
# 163	least	O
# 164	2-3	O
# 165	three	O
# 166	yoga	O
# 167	sessions	O
# 168	,	O
# 169	and	O
# 170	58	O
# 171	%	I-Premise
# 172	completed	O
# 173	at	O
# 174	least	O
# 175	5	O
# 176	sessions	O
# 177	.	O
# 178	Patients	O
# 179	in	O
# 180	the	O
# 181	TY	O
# 182	group	O
# 183	reported	O
# 184	significantly	O
# 185	lower	O
# 186	sleep	O
# 187	disturbance	O
# 188	scores	O
# 189	during	O
# 190	follow-up	O
# 191	compared	O
# 192	with	O
# 193	patients	O
# 194	in	O
# 195	the	O
# 196	wait-list	O
# 197	control	O
# 198	group	O
# 199	(	O
# 200	5.8	O
# 201	vs	O
# 202	.	O
# 203	8.1	O
# 204	;	O
# 205	P	O
# 206	<	O
# 207	0.004	O
# 208	)	O
# 209	.	O
# 210	This	O
# 211	included	O
# 212	better	O
# 213	subjective	O
# 214	sleep	O
# 215	quality	O
# 216	(	O
# 217	P	O
# 218	<	O
# 219	0.02	O
# 220	)	O
# 221	,	O
# 222	faster	O
# 223	sleep	O
# 224	latency	O
# 225	(	O
# 226	P	O
# 227	<	O
# 228	0.01	I-Premise
# 229	)	O
# 230	,	I-Premise
# 231	longer	O
# 232	sleep	O
# 233	duration	O
# 234	(	O
# 235	P	I-Premise
# 236	<	I-Premise
# 237	0.03	O
# 238	)	O
# 239	,	I-Premise
# 240	and	O
# 241	less	I-Premise
# 242	use	O
# 243	of	O
# 244	sleep	O
# 245	medications	O
# 246	(	O
# 247	P	O
# 248	<	I-Premise
# 249	0.02	O
# 250	)	O
# 251	.	O
# 252	There	O
# 253	were	O
# 254	no	O
# 255	significant	O
# 256	differences	O
# 257	between	O
# 258	groups	O
# 259	in	O
# 260	terms	O
# 261	of	O
# 262	intrusion	O
# 263	or	O
# 264	avoidance	O
# 265	,	O
# 266	state	O
# 267	anxiety	O
# 268	,	O
# 269	depression	O
# 270	,	O
# 271	or	O
# 272	fatigue	O
# 273	.	O
# 274	The	O
# 275	participation	O
# 276	rates	O
# 277	suggested	O
# 278	that	O
# 279	a	O
# 280	TY	O
# 281	program	O
# 282	is	O
# 283	feasible	O
# 284	for	O
# 285	patients	O
# 286	with	O
# 287	cancer	O
# 288	and	O
# 289	that	O
# 290	such	O
# 291	a	O
# 292	program	O
# 293	significantly	O
# 294	improves	O
# 295	sleep-related	O
# 296	outcomes	O
# 297	.	O
# 298	However	O
# 299	,	O
# 300	there	O
# 301	were	O
# 302	no	O
# 303	significant	O
# 304	differences	O
# 305	between	O
# 306	groups	O
# 307	for	O
# 308	the	O
# 309	other	O
# 310	outcomes	O
# 311	.	O
#
# (252, 273)	Support	(298, 311)
# (210, 251)	Support	(274, 297)
# (178, 209)	Support	(274, 297)
#
# 0	Malnutrition	O
# 1	occurs	O
# 2	frequently	O
# 3	in	O
# 4	patients	O
# 5	with	O
# 6	cancer	O
# 7	of	O
# 8	the	O
# 9	gastrointestinal	O
# 10	(	O
# 11	GI	O
# 12	)	O
# 13	or	O
# 14	head	O
# 15	and	O
# 16	neck	O
# 17	area	O
# 18	and	O
# 19	can	O
# 20	lead	O
# 21	to	O
# 22	negative	O
# 23	outcomes	O
# 24	.	O
# 25	The	O
# 26	aim	O
# 27	of	O
# 28	this	O
# 29	study	O
# 30	is	O
# 31	to	O
# 32	determine	O
# 33	the	O
# 34	impact	O
# 35	of	O
# 36	early	O
# 37	and	O
# 38	intensive	O
# 39	nutrition	O
# 40	intervention	O
# 41	(	O
# 42	NI	O
# 43	)	O
# 44	on	O
# 45	body	O
# 46	weight	O
# 47	,	O
# 48	body	O
# 49	composition	O
# 50	,	O
# 51	nutritional	O
# 52	status	O
# 53	,	O
# 54	global	O
# 55	quality	O
# 56	of	O
# 57	life	O
# 58	(	O
# 59	QoL	O
# 60	)	O
# 61	and	O
# 62	physical	O
# 63	function	O
# 64	compared	O
# 65	to	O
# 66	usual	O
# 67	practice	O
# 68	in	O
# 69	oncology	O
# 70	outpatients	O
# 71	receiving	O
# 72	radiotherapy	O
# 73	to	O
# 74	the	O
# 75	GI	O
# 76	or	O
# 77	head	O
# 78	and	O
# 79	neck	O
# 80	area	O
# 81	.	O
# 82	Outpatients	O
# 83	commencing	O
# 84	at	O
# 85	least	O
# 86	20	O
# 87	fractions	O
# 88	of	O
# 89	radiotherapy	O
# 90	to	O
# 91	the	O
# 92	GI	O
# 93	or	O
# 94	head	O
# 95	and	O
# 96	neck	O
# 97	area	O
# 98	were	O
# 99	randomised	O
# 100	to	O
# 101	receive	O
# 102	intensive	O
# 103	,	O
# 104	individualised	O
# 105	nutrition	O
# 106	counselling	O
# 107	by	O
# 108	a	O
# 109	dietitian	O
# 110	using	O
# 111	a	O
# 112	standard	O
# 113	protocol	O
# 114	and	O
# 115	oral	O
# 116	supplements	O
# 117	if	O
# 118	required	O
# 119	,	O
# 120	or	O
# 121	the	O
# 122	usual	O
# 123	practice	O
# 124	of	O
# 125	the	O
# 126	centre	O
# 127	(	O
# 128	general	O
# 129	advice	O
# 130	and	O
# 131	nutrition	O
# 132	booklet	O
# 133	)	O
# 134	.	O
# 135	Outcome	O
# 136	parameters	O
# 137	were	O
# 138	measured	O
# 139	at	O
# 140	baseline	O
# 141	and	O
# 142	4	O
# 143	,	O
# 144	8	O
# 145	and	O
# 146	12	O
# 147	weeks	O
# 148	after	O
# 149	commencing	O
# 150	radiotherapy	O
# 151	using	O
# 152	valid	O
# 153	and	O
# 154	reliable	O
# 155	tools	O
# 156	.	O
# 157	A	O
# 158	total	O
# 159	of	O
# 160	60	O
# 161	patients	O
# 162	(	O
# 163	51	O
# 164	M	O
# 165	:	O
# 166	9	O
# 167	F	O
# 168	;	O
# 169	mean	O
# 170	age	O
# 171	61.9+	O
# 172	/	O
# 173	-14.0	O
# 174	years	O
# 175	)	O
# 176	were	O
# 177	randomised	O
# 178	to	O
# 179	receive	O
# 180	either	O
# 181	NI	O
# 182	(	O
# 183	n	O
# 184	=	O
# 185	29	O
# 186	)	O
# 187	or	O
# 188	usual	O
# 189	care	O
# 190	(	O
# 191	UC	O
# 192	)	O
# 193	(	O
# 194	n	O
# 195	=	I-Premise
# 196	31	I-Premise
# 197	)	O
# 198	.	O
# 199	The	O
# 200	NI	O
# 201	group	O
# 202	had	O
# 203	statistically	O
# 204	smaller	O
# 205	deteriorations	O
# 206	in	O
# 207	weight	O
# 208	(	O
# 209	P	I-Premise
# 210	<	I-Premise
# 211	0.001	I-Premise
# 212	)	O
# 213	,	I-Premise
# 214	nutritional	O
# 215	status	O
# 216	(	O
# 217	P=	O
# 218	0.020	O
# 219	)	O
# 220	and	O
# 221	global	O
# 222	QoL	O
# 223	(	O
# 224	P=	O
# 225	0.009	O
# 226	)	O
# 227	compared	O
# 228	with	O
# 229	those	I-Premise
# 230	receiving	I-Premise
# 231	UC	O
# 232	.	O
# 233	Clinically	O
# 234	,	O
# 235	but	O
# 236	not	O
# 237	statistically	O
# 238	significant	O
# 239	differences	O
# 240	in	O
# 241	fat-free	O
# 242	mass	O
# 243	were	O
# 244	observed	O
# 245	between	O
# 246	the	O
# 247	groups	O
# 248	(	O
# 249	P=	O
# 250	0.195	O
# 251	)	O
# 252	.	O
# 253	Early	O
# 254	and	O
# 255	intensive	O
# 256	NI	O
# 257	appears	O
# 258	beneficial	O
# 259	in	O
# 260	terms	O
# 261	of	O
# 262	minimising	O
# 263	weight	O
# 264	loss	O
# 265	,	O
# 266	deterioration	O
# 267	in	O
# 268	nutritional	O
# 269	status	O
# 270	,	O
# 271	global	O
# 272	QoL	O
# 273	and	O
# 274	physical	O
# 275	function	O
# 276	in	O
# 277	oncology	O
# 278	outpatients	O
# 279	receiving	O
# 280	radiotherapy	O
# 281	to	O
# 282	the	O
# 283	GI	O
# 284	or	O
# 285	head	O
# 286	and	O
# 287	neck	O
# 288	area	O
# 289	.	O
# 290	Weight	O
# 291	maintenance	O
# 292	in	O
# 293	this	O
# 294	population	O
# 295	leads	O
# 296	to	O
# 297	beneficial	O
# 298	outcomes	O
# 299	and	O
# 300	suggests	O
# 301	that	O
# 302	this	O
# 303	,	O
# 304	rather	O
# 305	than	O
# 306	weight	O
# 307	gain	I-Premise
# 308	,	I-Premise
# 309	may	I-Premise
# 310	be	I-Premise
# 311	a	O
# 312	more	O
# 313	appropriate	O
# 314	aim	O
# 315	of	O
# 316	NI	O
# 317	.	O
#
# (199, 232)	Support	(253, 289)
# (233, 252)	Support	(253, 289)
#
# 0	Metal	O
# 1	stent	O
# 2	placement	O
# 3	and	O
# 4	single	O
# 5	dose	O
# 6	brachytherapy	O
# 7	are	O
# 8	commonly	O
# 9	used	O
# 10	treatment	O
# 11	modalities	O
# 12	for	O
# 13	the	O
# 14	palliation	O
# 15	of	O
# 16	inoperable	O
# 17	oesophageal	O
# 18	carcinoma	O
# 19	.	O
# 20	We	O
# 21	investigated	O
# 22	generic	O
# 23	and	O
# 24	disease-specific	O
# 25	health-related	O
# 26	quality	O
# 27	of	O
# 28	life	O
# 29	(	O
# 30	HRQoL	O
# 31	)	O
# 32	after	O
# 33	these	O
# 34	palliative	O
# 35	treatments	O
# 36	.	O
# 37	Patients	O
# 38	with	O
# 39	dysphagia	O
# 40	from	O
# 41	inoperable	O
# 42	oesophageal	O
# 43	carcinoma	O
# 44	were	O
# 45	randomised	O
# 46	to	O
# 47	placement	O
# 48	of	O
# 49	a	O
# 50	covered	O
# 51	Ultraflex	O
# 52	stent	O
# 53	(	O
# 54	n	O
# 55	=	O
# 56	108	O
# 57	)	O
# 58	or	O
# 59	single	O
# 60	dose	O
# 61	(	O
# 62	12	O
# 63	Gy	O
# 64	)	O
# 65	brachytherapy	O
# 66	(	O
# 67	n	O
# 68	=	I-Premise
# 69	101	O
# 70	)	O
# 71	.	O
# 72	We	O
# 73	obtained	O
# 74	longitudinal	O
# 75	data	O
# 76	on	O
# 77	disease-specific	O
# 78	(	O
# 79	dysphagia	O
# 80	score	O
# 81	,	O
# 82	European	O
# 83	Organisation	O
# 84	for	O
# 85	Research	O
# 86	and	O
# 87	Treatment	O
# 88	of	O
# 89	Cancer	O
# 90	(	O
# 91	EORTC	O
# 92	)	O
# 93	OES	O
# 94	-	O
# 95	23	O
# 96	,	O
# 97	visual	O
# 98	analogue	O
# 99	pain	O
# 100	scale	O
# 101	)	O
# 102	and	O
# 103	generic	O
# 104	(	O
# 105	EORTC	O
# 106	Quality	O
# 107	of	O
# 108	Life-Core	O
# 109	30	O
# 110	Questionnaire	O
# 111	(	O
# 112	QLQ-C	O
# 113	30	O
# 114	)	O
# 115	,	O
# 116	Euroqol	O
# 117	(	O
# 118	EQ	O
# 119	)	O
# 120	-	O
# 121	5D	O
# 122	)	O
# 123	HRQoL	O
# 124	at	O
# 125	monthly	O
# 126	home	O
# 127	visits	O
# 128	by	O
# 129	a	O
# 130	specially-trained	O
# 131	research	O
# 132	nurse	O
# 133	.	O
# 134	We	O
# 135	compared	O
# 136	HRQoL	O
# 137	between	O
# 138	the	O
# 139	two	O
# 140	treatments	O
# 141	and	O
# 142	analysed	O
# 143	changes	O
# 144	in	O
# 145	HRQoL	O
# 146	during	O
# 147	follow-up	O
# 148	.	O
# 149	Dysphagia	O
# 150	improved	O
# 151	more	O
# 152	rapidly	O
# 153	after	O
# 154	stent	O
# 155	placement	O
# 156	than	O
# 157	after	O
# 158	brachytherapy	O
# 159	,	O
# 160	but	O
# 161	long-term	O
# 162	relief	O
# 163	of	O
# 164	dysphagia	O
# 165	was	O
# 166	better	O
# 167	after	O
# 168	brachytherapy	O
# 169	.	O
# 170	For	O
# 171	generic	O
# 172	HRQoL	O
# 173	,	O
# 174	there	O
# 175	was	O
# 176	an	O
# 177	overall	O
# 178	significant	O
# 179	difference	O
# 180	in	O
# 181	favour	O
# 182	of	O
# 183	brachytherapy	O
# 184	on	O
# 185	four	O
# 186	out	O
# 187	of	O
# 188	five	O
# 189	functional	O
# 190	scales	O
# 191	of	O
# 192	the	O
# 193	EORTC	O
# 194	QLQ-C	O
# 195	30	O
# 196	(	O
# 197	role	O
# 198	,	O
# 199	emotional	O
# 200	,	O
# 201	cognitive	O
# 202	and	O
# 203	social	O
# 204	)	O
# 205	(	O
# 206	P	O
# 207	<	I-Premise
# 208	0.05	I-Premise
# 209	)	O
# 210	.	O
# 211	Generic	O
# 212	HRQoL	O
# 213	deteriorated	O
# 214	over	O
# 215	time	O
# 216	on	O
# 217	all	O
# 218	functional	O
# 219	scales	O
# 220	of	O
# 221	the	O
# 222	EORTC	O
# 223	QLQ	O
# 224	C	O
# 225	-	O
# 226	30	O
# 227	and	O
# 228	EQ	O
# 229	-	O
# 230	5D	O
# 231	,	O
# 232	in	O
# 233	particular	O
# 234	physical	O
# 235	and	O
# 236	role	O
# 237	functioning	O
# 238	(	O
# 239	on	O
# 240	average	O
# 241	-	O
# 242	23	O
# 243	and	O
# 244	-	O
# 245	24	O
# 246	on	O
# 247	a	O
# 248	100	O
# 249	points	O
# 250	scale	O
# 251	during	O
# 252	0.5	O
# 253	years	O
# 254	of	O
# 255	follow-up	O
# 256	)	O
# 257	.	O
# 258	This	O
# 259	decline	O
# 260	was	O
# 261	more	O
# 262	pronounced	O
# 263	in	O
# 264	the	O
# 265	stent	O
# 266	group	O
# 267	.	O
# 268	Major	O
# 269	improvements	O
# 270	were	O
# 271	seen	O
# 272	on	O
# 273	the	O
# 274	dysphagia	O
# 275	and	O
# 276	eating	O
# 277	scales	O
# 278	of	O
# 279	the	O
# 280	EORTC	O
# 281	OES	O
# 282	-	O
# 283	23	O
# 284	,	O
# 285	in	O
# 286	contrast	O
# 287	to	O
# 288	other	O
# 289	scales	O
# 290	of	O
# 291	this	O
# 292	disease-specific	O
# 293	measure	O
# 294	,	O
# 295	which	O
# 296	remained	O
# 297	almost	O
# 298	stable	O
# 299	during	O
# 300	follow-up	O
# 301	.	O
# 302	Reported	O
# 303	levels	O
# 304	of	O
# 305	chest	O
# 306	or	O
# 307	abdominal	O
# 308	pain	O
# 309	remained	O
# 310	stable	O
# 311	during	O
# 312	follow-up	O
# 313	in	O
# 314	both	O
# 315	treatment	O
# 316	groups	O
# 317	,	O
# 318	general	O
# 319	pain	I-Premise
# 320	levels	O
# 321	increased	O
# 322	to	O
# 323	a	O
# 324	minor	O
# 325	extent	O
# 326	.	O
# 327	The	O
# 328	effects	O
# 329	of	O
# 330	single	O
# 331	dose	O
# 332	brachytherapy	O
# 333	on	O
# 334	HRQoL	O
# 335	compared	O
# 336	favourably	O
# 337	to	O
# 338	those	O
# 339	of	O
# 340	stent	O
# 341	placement	O
# 342	for	O
# 343	the	O
# 344	palliation	O
# 345	of	O
# 346	oesophageal	O
# 347	cancer	O
# 348	.	O
# 349	Future	O
# 350	studies	O
# 351	on	O
# 352	palliative	O
# 353	care	O
# 354	for	O
# 355	oesophageal	O
# 356	cancer	O
# 357	should	O
# 358	at	O
# 359	least	O
# 360	include	O
# 361	generic	O
# 362	HRQoL	O
# 363	scales	O
# 364	,	O
# 365	since	O
# 366	these	O
# 367	were	O
# 368	more	O
# 369	responsive	O
# 370	in	O
# 371	measuring	O
# 372	patients	O
# 373	'	O
# 374	functioning	O
# 375	and	O
# 376	well-being	O
# 377	during	O
# 378	follow-up	O
# 379	than	O
# 380	disease-specific	O
# 381	HRQoL	O
# 382	scales	O
# 383	.	O
#
# (160, 169)	Partial-Attack	(149, 159)
# (258, 267)	Support	(327, 348)
# (211, 257)	Support	(327, 348)
# (170, 210)	Support	(327, 348)
# (365, 383)	Support	(349, 364)
# (349, 364)	Partial-Attack	(327, 348)
# (149, 159)	Support	(327, 348)
# (268, 301)	Support	(327, 348)
# (302, 317)	Support	(327, 348)
# (318, 326)	Support	(327, 348)
#
# 0	The	O
# 1	objective	O
# 2	of	O
# 3	this	O
# 4	study	O
# 5	was	I-Premise
# 6	to	O
# 7	compare	O
# 8	the	O
# 9	quality	O
# 10	of	O
# 11	life	O
# 12	(	O
# 13	QoL	O
# 14	)	O
# 15	of	O
# 16	ovarian	O
# 17	cancer	O
# 18	patients	O
# 19	treated	O
# 20	with	O
# 21	paclitaxel	O
# 22	/	O
# 23	carboplatin	O
# 24	(	O
# 25	TC	O
# 26	)	O
# 27	versus	O
# 28	paclitaxel	O
# 29	/	O
# 30	cisplatin	O
# 31	(	O
# 32	PT	O
# 33	)	O
# 34	and	O
# 35	to	O
# 36	determine	O
# 37	the	O
# 38	impact	O
# 39	of	O
# 40	treatment	O
# 41	toxicity	O
# 42	on	O
# 43	the	O
# 44	various	O
# 45	QoL	O
# 46	domains	O
# 47	.	O
# 48	In	O
# 49	this	O
# 50	phase	O
# 51	III	O
# 52	trial	O
# 53	,	O
# 54	798	O
# 55	patients	O
# 56	with	O
# 57	ovarian	O
# 58	cancer	O
# 59	stages	O
# 60	IIB-IV	O
# 61	were	O
# 62	randomly	O
# 63	assigned	O
# 64	to	O
# 65	receive	O
# 66	TC	O
# 67	or	O
# 68	PT	O
# 69	.	O
# 70	The	O
# 71	primary	O
# 72	end	O
# 73	point	O
# 74	was	O
# 75	progression-free	O
# 76	survival	O
# 77	;	O
# 78	secondary	O
# 79	end	O
# 80	points	O
# 81	included	O
# 82	toxicity	O
# 83	,	O
# 84	QoL	O
# 85	,	O
# 86	and	O
# 87	response	O
# 88	to	O
# 89	treatment	O
# 90	.	O
# 91	Patients	O
# 92	completed	O
# 93	the	O
# 94	European	O
# 95	Organisation	O
# 96	for	O
# 97	Research	O
# 98	and	O
# 99	Treatment	O
# 100	of	O
# 101	Cancer	O
# 102	QLQ-C	O
# 103	30	O
# 104	before	O
# 105	treatment	O
# 106	,	O
# 107	within	O
# 108	3	O
# 109	days	O
# 110	before	O
# 111	the	O
# 112	second	O
# 113	and	O
# 114	the	O
# 115	fourth	O
# 116	chemotherapy	O
# 117	cycle	O
# 118	,	O
# 119	and	O
# 120	3	O
# 121	weeks	O
# 122	after	O
# 123	completion	O
# 124	of	O
# 125	chemotherapy	O
# 126	.	O
# 127	Previously	O
# 128	reported	O
# 129	data	O
# 130	showed	O
# 131	that	O
# 132	patients	O
# 133	undergoing	O
# 134	TC	O
# 135	or	O
# 136	PT	O
# 137	did	O
# 138	not	O
# 139	differ	O
# 140	in	O
# 141	progression-free	O
# 142	survival	O
# 143	and	O
# 144	overall	O
# 145	survival	O
# 146	.	O
# 147	However	O
# 148	,	O
# 149	the	O
# 150	TC	O
# 151	arm	O
# 152	was	O
# 153	superior	O
# 154	,	O
# 155	indicating	O
# 156	a	O
# 157	better	O
# 158	overall	O
# 159	QoL	O
# 160	compared	O
# 161	with	O
# 162	the	O
# 163	PT	O
# 164	arm	O
# 165	.	O
# 166	Controlling	O
# 167	for	O
# 168	toxicity	O
# 169	and	O
# 170	age	O
# 171	,	O
# 172	a	O
# 173	significant	O
# 174	treatment	O
# 175	by	O
# 176	assessment	O
# 177	time	O
# 178	interaction	O
# 179	was	O
# 180	found	O
# 181	for	O
# 182	four	O
# 183	QoL	O
# 184	functioning	O
# 185	scales	O
# 186	and	O
# 187	three	O
# 188	symptoms	O
# 189	scales	O
# 190	.	O
# 191	Patients	O
# 192	in	O
# 193	the	O
# 194	TC	O
# 195	arm	O
# 196	showed	O
# 197	better	O
# 198	means	O
# 199	scores	O
# 200	after	O
# 201	treatment	O
# 202	on	O
# 203	overall	O
# 204	QoL	O
# 205	(	O
# 206	P	O
# 207	=	I-Premise
# 208	.	O
# 209	012	O
# 210	)	O
# 211	,	O
# 212	physical	O
# 213	functioning	O
# 214	(	O
# 215	P	I-Premise
# 216	=	I-Premise
# 217	.	O
# 218	012	O
# 219	)	O
# 220	,	O
# 221	role	O
# 222	functioning	O
# 223	(	O
# 224	P	I-Premise
# 225	=	I-Premise
# 226	.	O
# 227	005	O
# 228	)	O
# 229	,	O
# 230	and	O
# 231	cognitive	O
# 232	functioning	O
# 233	(	O
# 234	P	I-Premise
# 235	=	I-Premise
# 236	.	O
# 237	024	O
# 238	)	O
# 239	,	O
# 240	compared	O
# 241	with	O
# 242	the	O
# 243	PT	O
# 244	arm	O
# 245	.	O
# 246	Concerning	O
# 247	symptom	O
# 248	experience	O
# 249	,	O
# 250	patients	O
# 251	undergoing	O
# 252	TC	O
# 253	showed	O
# 254	less	O
# 255	nausea	O
# 256	and	O
# 257	vomiting	O
# 258	(	O
# 259	P	O
# 260	<	O
# 261	.	O
# 262	001	O
# 263	)	O
# 264	,	O
# 265	less	O
# 266	appetite	O
# 267	loss	O
# 268	(	O
# 269	P	I-Premise
# 270	<	I-Premise
# 271	.	O
# 272	001	O
# 273	)	O
# 274	,	O
# 275	and	O
# 276	less	O
# 277	fatigue	O
# 278	(	O
# 279	P	I-Premise
# 280	=	I-Premise
# 281	.	O
# 282	033	O
# 283	)	O
# 284	after	O
# 285	completion	O
# 286	of	O
# 287	treatment	O
# 288	compared	O
# 289	with	O
# 290	patients	O
# 291	undergoing	O
# 292	PT	O
# 293	.	O
# 294	The	O
# 295	TC	O
# 296	regimen	O
# 297	achieved	O
# 298	better	O
# 299	QoL	O
# 300	outcomes	O
# 301	compared	O
# 302	with	O
# 303	the	O
# 304	PT	O
# 305	regimen	O
# 306	.	O
# 307	Thus	O
# 308	,	O
# 309	clinicians	O
# 310	may	O
# 311	consider	O
# 312	replacing	O
# 313	cisplatin	O
# 314	with	O
# 315	carboplatin	O
# 316	when	O
# 317	treating	O
# 318	ovarian	O
# 319	cancer	O
# 320	patients	O
# 321	with	O
# 322	chemotherapy	O
# 323	.	O
#
# (294, 306)	Support	(307, 323)
# (246, 293)	Support	(294, 306)
# (191, 245)	Support	(294, 306)
#
# 0	To	O
# 1	evaluate	O
# 2	if	O
# 3	raising	O
# 4	baseline	O
# 5	and	O
# 6	maintaining	O
# 7	hemoglobin	O
# 8	(	O
# 9	Hb	O
# 10	)	O
# 11	levels	O
# 12	with	O
# 13	red	O
# 14	blood	O
# 15	cell	O
# 16	(	O
# 17	RBC	O
# 18	)	O
# 19	transfusion	O
# 20	could	O
# 21	improve	O
# 22	the	O
# 23	outcomes	O
# 24	of	O
# 25	chemotherapy	O
# 26	for	O
# 27	advanced	O
# 28	gastric	O
# 29	cancer	O
# 30	(	O
# 31	AGC	O
# 32	)	O
# 33	.	O
# 34	Patients	O
# 35	were	O
# 36	randomized	O
# 37	to	O
# 38	receive	O
# 39	RBC	O
# 40	transfusion	O
# 41	to	O
# 42	maintain	O
# 43	their	O
# 44	Hb	O
# 45	levels	O
# 46	>	O
# 47	or	O
# 48	=	O
# 49	10	O
# 50	g	O
# 51	/	O
# 52	dl	O
# 53	(	O
# 54	arm	O
# 55	1	O
# 56	)	O
# 57	or	O
# 58	>	O
# 59	or	O
# 60	=	O
# 61	12	O
# 62	(	O
# 63	arm	O
# 64	2	O
# 65	)	O
# 66	before	O
# 67	the	O
# 68	start	O
# 69	of	O
# 70	their	O
# 71	5	O
# 72	-	O
# 73	fluorouracil-based	O
# 74	first-line	O
# 75	chemotherapy	O
# 76	.	O
# 77	Objective	O
# 78	response	O
# 79	,	O
# 80	KPS	O
# 81	and	O
# 82	quality	O
# 83	of	O
# 84	life	O
# 85	(	O
# 86	QOL	O
# 87	)	O
# 88	data	O
# 89	were	O
# 90	measured	O
# 91	.	O
# 92	For	O
# 93	87	O
# 94	patients	O
# 95	enrolled	O
# 96	,	O
# 97	mean	O
# 98	baseline	O
# 99	Hb	O
# 100	was	O
# 101	10.1	O
# 102	g	O
# 103	/	O
# 104	dl	O
# 105	,	O
# 106	and	O
# 107	54	O
# 108	patients	O
# 109	received	O
# 110	RBC	O
# 111	prior	O
# 112	to	O
# 113	chemotherapy	O
# 114	initiation	O
# 115	.	O
# 116	Despite	O
# 117	transfusion	O
# 118	,	O
# 119	we	O
# 120	failed	O
# 121	to	O
# 122	maintain	O
# 123	the	O
# 124	Hb	O
# 125	level	O
# 126	above	O
# 127	the	O
# 128	predefined	O
# 129	target	O
# 130	range	O
# 131	.	O
# 132	Eighteen	O
# 133	patients	O
# 134	experienced	O
# 135	brief	O
# 136	and	O
# 137	reversible	O
# 138	adverse	O
# 139	events	O
# 140	during	O
# 141	transfusion	O
# 142	,	O
# 143	including	O
# 144	two	O
# 145	patients	O
# 146	with	O
# 147	acute	O
# 148	pulmonary	O
# 149	edema	O
# 150	.	O
# 151	KPS	O
# 152	was	O
# 153	improved	O
# 154	from	O
# 155	baseline	O
# 156	to	O
# 157	post-chemotherapy	O
# 158	in	O
# 159	both	O
# 160	arms	O
# 161	.	O
# 162	QOL	O
# 163	data	O
# 164	showed	O
# 165	improvement	O
# 166	in	O
# 167	some	O
# 168	symptom	O
# 169	scores	O
# 170	,	O
# 171	but	O
# 172	there	O
# 173	was	I-Premise
# 174	no	I-Premise
# 175	difference	O
# 176	in	I-Premise
# 177	the	O
# 178	QOL	O
# 179	scores	O
# 180	between	O
# 181	the	O
# 182	two	O
# 183	arms	O
# 184	at	O
# 185	baseline	O
# 186	and	O
# 187	all	O
# 188	four	O
# 189	cycles	O
# 190	of	O
# 191	treatment	O
# 192	.	O
# 193	Similar	O
# 194	response	O
# 195	rates	O
# 196	were	O
# 197	observed	O
# 198	in	O
# 199	both	O
# 200	arms	O
# 201	(	O
# 202	arm	O
# 203	1	O
# 204	,	O
# 205	30	O
# 206	%	I-Premise
# 207	;	I-Premise
# 208	arm	I-Premise
# 209	2	I-Premise
# 210	,	I-Premise
# 211	35	I-Premise
# 212	%	I-Premise
# 213	)	I-Premise
# 214	.	O
# 215	Both	O
# 216	arms	O
# 217	showed	O
# 218	similar	I-Premise
# 219	chemotherapy	O
# 220	duration	O
# 221	(	O
# 222	3.8	O
# 223	and	O
# 224	4.1	O
# 225	months	O
# 226	,	O
# 227	respectively	I-Premise
# 228	)	O
# 229	,	I-Premise
# 230	progression-free	I-Premise
# 231	survival	I-Premise
# 232	(	I-Premise
# 233	4.0	O
# 234	and	O
# 235	4.1	O
# 236	months	O
# 237	)	O
# 238	and	O
# 239	overall	O
# 240	survival	O
# 241	(	O
# 242	9.9	O
# 243	and	O
# 244	9.3	O
# 245	months	O
# 246	)	O
# 247	.	O
# 248	Red	O
# 249	blood	O
# 250	cell	O
# 251	transfusion	O
# 252	achieving	O
# 253	Hb	O
# 254	level	O
# 255	above	O
# 256	10	O
# 257	g	O
# 258	/	O
# 259	dl	O
# 260	might	O
# 261	contribute	O
# 262	to	O
# 263	the	O
# 264	improvement	O
# 265	of	O
# 266	the	O
# 267	KPS	O
# 268	and	O
# 269	QOL	O
# 270	seen	O
# 271	in	O
# 272	patients	O
# 273	with	O
# 274	AGC	O
# 275	.	O
# 276	The	O
# 277	observation	O
# 278	of	O
# 279	equivalent	O
# 280	outcomes	O
# 281	at	O
# 282	the	O
# 283	two	O
# 284	target	O
# 285	Hb	O
# 286	levels	O
# 287	supports	O
# 288	the	O
# 289	feasibility	O
# 290	of	O
# 291	anemia	O
# 292	correction	O
# 293	to	O
# 294	Hb	O
# 295	10	O
# 296	g	O
# 297	/	O
# 298	dl	O
# 299	,	O
# 300	which	O
# 301	merits	O
# 302	further	O
# 303	evaluation	O
# 304	.	O
#
# (171, 192)	Partial-Attack	(162, 170)
# (162, 170)	Support	(248, 275)
# (151, 161)	Support	(248, 275)
# (132, 150)	Support	(248, 275)
# (193, 214)	Support	(276, 304)
# (215, 247)	Support	(276, 304)
#
# 0	This	O
# 1	study	O
# 2	sought	O
# 3	to	O
# 4	continue	O
# 5	research	O
# 6	on	O
# 7	psychosocial	O
# 8	interventions	O
# 9	for	O
# 10	patients	O
# 11	being	O
# 12	treated	O
# 13	with	O
# 14	radiation	O
# 15	therapy	O
# 16	across	O
# 17	multiple	O
# 18	centers	O
# 19	and	O
# 20	to	O
# 21	replicate	O
# 22	positive	O
# 23	findings	O
# 24	of	O
# 25	a	O
# 26	single-center	O
# 27	study	O
# 28	of	O
# 29	patients	O
# 30	being	O
# 31	treated	O
# 32	with	O
# 33	chemotherapy	O
# 34	.	O
# 35	The	O
# 36	primary	O
# 37	objective	O
# 38	of	O
# 39	this	O
# 40	study	O
# 41	was	O
# 42	to	O
# 43	determine	O
# 44	if	O
# 45	a	O
# 46	stress	O
# 47	management	O
# 48	intervention	O
# 49	was	O
# 50	effective	O
# 51	in	O
# 52	improving	O
# 53	quality	O
# 54	of	O
# 55	life	O
# 56	and	O
# 57	decreasing	O
# 58	psychological	O
# 59	distress	O
# 60	in	O
# 61	patients	O
# 62	undergoing	O
# 63	radiotherapy	O
# 64	for	O
# 65	cancer	O
# 66	.	O
# 67	A	O
# 68	total	O
# 69	of	O
# 70	310	O
# 71	patients	O
# 72	about	O
# 73	to	O
# 74	begin	O
# 75	radiotherapy	O
# 76	treatment	O
# 77	were	O
# 78	randomly	O
# 79	assigned	O
# 80	to	O
# 81	receive	O
# 82	usual	O
# 83	care	O
# 84	only	O
# 85	or	O
# 86	self-administered	O
# 87	stress	O
# 88	management	O
# 89	training	O
# 90	.	O
# 91	Quality-of-life	O
# 92	assessments	O
# 93	occurred	O
# 94	at	O
# 95	baseline	O
# 96	and	O
# 97	for	O
# 98	3	O
# 99	weeks	O
# 100	after	O
# 101	the	O
# 102	beginning	O
# 103	of	O
# 104	radiotherapy	O
# 105	treatment	O
# 106	.	O
# 107	Overall	O
# 108	,	O
# 109	patients	O
# 110	assigned	O
# 111	to	O
# 112	receive	O
# 113	stress	O
# 114	management	O
# 115	training	O
# 116	did	O
# 117	not	O
# 118	report	O
# 119	significantly	O
# 120	less	O
# 121	psychological	O
# 122	distress	O
# 123	on	O
# 124	the	O
# 125	Medical	O
# 126	Outcomes	O
# 127	Study	O
# 128	36	O
# 129	-	O
# 130	Item	O
# 131	Short	O
# 132	Form	O
# 133	(	O
# 134	SF	O
# 135	-	O
# 136	36	O
# 137	)	O
# 138	Mental	O
# 139	Component	O
# 140	Summary	O
# 141	Scale	O
# 142	than	O
# 143	did	O
# 144	those	O
# 145	assigned	O
# 146	to	O
# 147	usual	O
# 148	care	O
# 149	.	O
# 150	When	O
# 151	divided	O
# 152	into	O
# 153	subgroups	O
# 154	based	O
# 155	on	O
# 156	the	O
# 157	SF	O
# 158	-	O
# 159	36	O
# 160	Mental	O
# 161	Component	O
# 162	Summary	O
# 163	Scale	O
# 164	scores	O
# 165	immediately	O
# 166	after	O
# 167	their	O
# 168	first	O
# 169	radiotherapy	O
# 170	treatment	O
# 171	,	O
# 172	patients	O
# 173	with	O
# 174	above-average	O
# 175	levels	O
# 176	of	O
# 177	psychological	O
# 178	distress	O
# 179	(	O
# 180	scores	O
# 181	<	O
# 182	or	O
# 183	=	O
# 184	50	O
# 185	)	O
# 186	who	O
# 187	were	O
# 188	randomly	O
# 189	assigned	O
# 190	to	O
# 191	the	O
# 192	intervention	O
# 193	condition	O
# 194	reported	O
# 195	significant	O
# 196	improvement	O
# 197	in	O
# 198	their	O
# 199	distress	O
# 200	compared	O
# 201	with	O
# 202	those	I-Premise
# 203	assigned	I-Premise
# 204	to	I-Premise
# 205	usual	I-Premise
# 206	care	O
# 207	only	O
# 208	on	O
# 209	the	O
# 210	SF	O
# 211	-	O
# 212	36	O
# 213	Mental	O
# 214	Health	O
# 215	Subscale	O
# 216	and	O
# 217	the	O
# 218	Center	O
# 219	for	O
# 220	Epidemiologic	O
# 221	Studies	O
# 222	Depression	O
# 223	Scale	O
# 224	.	O
# 225	This	O
# 226	study	O
# 227	found	O
# 228	that	O
# 229	self-administered	O
# 230	stress	O
# 231	management	O
# 232	training	O
# 233	is	O
# 234	effective	O
# 235	only	O
# 236	in	O
# 237	those	O
# 238	radiotherapy	O
# 239	patients	O
# 240	with	O
# 241	initially	O
# 242	higher	O
# 243	levels	O
# 244	of	O
# 245	psychological	O
# 246	distress	O
# 247	.	O
# 248	Additional	O
# 249	research	O
# 250	should	O
# 251	examine	O
# 252	the	O
# 253	benefits	O
# 254	of	O
# 255	stress	O
# 256	management	O
# 257	training	O
# 258	targeted	O
# 259	specifically	O
# 260	to	O
# 261	patients	O
# 262	experiencing	O
# 263	heightened	O
# 264	distress	O
# 265	.	O
#
# (248, 265)	Partial-Attack	(225, 247)
# (107, 149)	Support	(225, 247)
# (172, 224)	Support	(225, 247)
#
# 0	Debilitating	O
# 1	hot	O
# 2	flushes	O
# 3	and	O
# 4	sleep	O
# 5	dysfunction	O
# 6	often	O
# 7	affect	O
# 8	survivors	O
# 9	of	O
# 10	breast	O
# 11	cancer	O
# 12	,	O
# 13	most	O
# 14	notably	O
# 15	in	O
# 16	those	I-Premise
# 17	taking	O
# 18	anti-oestrogen	O
# 19	medications	O
# 20	.	O
# 21	Conventional	O
# 22	treatments	O
# 23	have	O
# 24	been	O
# 25	only	O
# 26	partially	O
# 27	effective	O
# 28	in	O
# 29	diminishing	O
# 30	these	O
# 31	issues	O
# 32	,	O
# 33	and	O
# 34	some	O
# 35	have	O
# 36	serious	O
# 37	risks	O
# 38	.	O
# 39	We	O
# 40	did	O
# 41	a	O
# 42	pilot	O
# 43	study	O
# 44	to	O
# 45	investigate	O
# 46	our	O
# 47	hypothesis	O
# 48	that	O
# 49	stellate-ganglion	O
# 50	block	O
# 51	can	O
# 52	be	O
# 53	a	O
# 54	safe	O
# 55	and	O
# 56	effective	O
# 57	treatment	O
# 58	for	O
# 59	hot	O
# 60	flushes	O
# 61	and	O
# 62	sleep	O
# 63	dysfunction	O
# 64	in	O
# 65	this	O
# 66	patient	O
# 67	population	O
# 68	.	O
# 69	13	O
# 70	survivors	O
# 71	of	O
# 72	breast	O
# 73	cancer	O
# 74	(	O
# 75	in	O
# 76	remission	O
# 77	)	O
# 78	with	O
# 79	severe	O
# 80	hot	O
# 81	flushes	O
# 82	and	O
# 83	night	O
# 84	awakenings	O
# 85	were	O
# 86	treated	O
# 87	with	O
# 88	stellate-ganglion	O
# 89	block	O
# 90	at	O
# 91	the	O
# 92	anterolateral	O
# 93	aspect	O
# 94	of	O
# 95	the	O
# 96	C6	O
# 97	vertebra	O
# 98	on	O
# 99	the	O
# 100	right	O
# 101	side	O
# 102	under	O
# 103	fluoroscopy	O
# 104	.	O
# 105	Patients	O
# 106	recorded	O
# 107	hot	O
# 108	flushes	O
# 109	in	O
# 110	a	O
# 111	daily	O
# 112	diary	O
# 113	by	O
# 114	use	O
# 115	of	O
# 116	the	O
# 117	Hot-Flash	O
# 118	Score	O
# 119	,	O
# 120	devised	O
# 121	by	O
# 122	Sloan	O
# 123	and	O
# 124	colleagues	O
# 125	,	O
# 126	and	O
# 127	night	O
# 128	awakenings	O
# 129	by	O
# 130	use	O
# 131	of	O
# 132	the	O
# 133	Pittsburgh	O
# 134	Sleep	O
# 135	Quality	O
# 136	Index	O
# 137	.	O
# 138	Both	O
# 139	instruments	O
# 140	were	O
# 141	used	O
# 142	1	O
# 143	week	O
# 144	before	O
# 145	the	O
# 146	procedure	O
# 147	[	O
# 148	A40	O
# 149	]	O
# 150	and	O
# 151	then	O
# 152	weekly	O
# 153	after	O
# 154	the	O
# 155	procedure	O
# 156	for	O
# 157	12	O
# 158	weeks	O
# 159	.	O
# 160	We	O
# 161	used	O
# 162	the	O
# 163	generalised-estimating-equations	O
# 164	method	O
# 165	to	O
# 166	analyse	O
# 167	the	O
# 168	longitudinal	O
# 169	measurements	O
# 170	of	O
# 171	the	O
# 172	number	O
# 173	of	O
# 174	hot	O
# 175	flushes	O
# 176	and	O
# 177	night	O
# 178	awakenings	O
# 179	over	O
# 180	time	O
# 181	.	O
# 182	This	O
# 183	method	O
# 184	is	O
# 185	a	O
# 186	popular	O
# 187	approach	O
# 188	to	O
# 189	analysing	O
# 190	datasets	O
# 191	that	O
# 192	have	O
# 193	repeated	O
# 194	measures	O
# 195	from	O
# 196	the	O
# 197	same	O
# 198	person	O
# 199	,	O
# 200	and	O
# 201	is	O
# 202	robust	O
# 203	because	O
# 204	it	O
# 205	does	O
# 206	not	O
# 207	need	O
# 208	the	O
# 209	complete	O
# 210	distribution	O
# 211	of	O
# 212	the	O
# 213	outcomes	O
# 214	to	O
# 215	be	O
# 216	specified	O
# 217	.	O
# 218	This	O
# 219	trial	O
# 220	is	O
# 221	registered	O
# 222	on	O
# 223	the	O
# 224	International	O
# 225	Standard	O
# 226	Randomised	O
# 227	Controlled	O
# 228	Trial	O
# 229	Number	O
# 230	register	O
# 231	(	O
# 232	ISRCTN	O
# 233	14318565	O
# 234	)	O
# 235	.	O
# 236	There	O
# 237	were	O
# 238	no	O
# 239	adverse	O
# 240	events	O
# 241	resulting	O
# 242	from	O
# 243	the	O
# 244	stellate-ganglion	O
# 245	block	O
# 246	,	O
# 247	although	O
# 248	patients	O
# 249	had	O
# 250	temporary	O
# 251	Horner's	O
# 252	syndrome	O
# 253	indicating	O
# 254	the	O
# 255	effectiveness	O
# 256	of	O
# 257	the	O
# 258	block	O
# 259	.	O
# 260	Five	O
# 261	patients	O
# 262	had	O
# 263	only	O
# 264	one	O
# 265	stellate-ganglion	O
# 266	block	O
# 267	and	O
# 268	eight	O
# 269	had	O
# 270	two	O
# 271	stellate-ganglion	O
# 272	blocks	O
# 273	.	O
# 274	The	O
# 275	total	O
# 276	number	O
# 277	of	O
# 278	hot	O
# 279	flushes	O
# 280	decreased	O
# 281	from	O
# 282	a	O
# 283	mean	O
# 284	of	O
# 285	79.4	O
# 286	(	O
# 287	SD	O
# 288	37.4	O
# 289	)	O
# 290	per	O
# 291	week	O
# 292	before	O
# 293	the	O
# 294	procedure	O
# 295	to	O
# 296	a	O
# 297	mean	O
# 298	of	O
# 299	49.9	O
# 300	(	O
# 301	SD	O
# 302	39.9	O
# 303	)	O
# 304	per	O
# 305	week	O
# 306	during	O
# 307	the	O
# 308	first	O
# 309	2	O
# 310	weeks	O
# 311	after	O
# 312	the	O
# 313	procedure	O
# 314	(	O
# 315	p=	O
# 316	0.0002	O
# 317	)	O
# 318	.	O
# 319	The	O
# 320	total	O
# 321	number	O
# 322	of	O
# 323	hot	O
# 324	flushes	O
# 325	continued	O
# 326	to	O
# 327	decrease	O
# 328	over	O
# 329	the	O
# 330	remaining	O
# 331	follow-up	O
# 332	period	O
# 333	(	O
# 334	weeks	O
# 335	3-12	O
# 336	)	O
# 337	,	O
# 338	and	O
# 339	stabilised	O
# 340	at	O
# 341	a	O
# 342	mean	O
# 343	of	O
# 344	8.1	O
# 345	(	O
# 346	SD	O
# 347	5.6	O
# 348	)	O
# 349	per	O
# 350	week	O
# 351	(	O
# 352	p	O
# 353	<	O
# 354	0.0001	O
# 355	)	O
# 356	.	O
# 357	The	O
# 358	number	O
# 359	of	O
# 360	very	O
# 361	severe	O
# 362	hot	O
# 363	flushes	O
# 364	was	O
# 365	decreased	O
# 366	to	O
# 367	near	O
# 368	zero	O
# 369	by	O
# 370	the	O
# 371	end	O
# 372	of	O
# 373	the	O
# 374	follow-up	O
# 375	period	O
# 376	(	O
# 377	week	O
# 378	12	O
# 379	;	O
# 380	p	O
# 381	<	O
# 382	0.0001	O
# 383	)	O
# 384	.	O
# 385	Night	O
# 386	awakenings	O
# 387	decreased	O
# 388	from	O
# 389	a	O
# 390	mean	O
# 391	of	O
# 392	19.5	O
# 393	(	O
# 394	SD	O
# 395	14.8	O
# 396	)	O
# 397	per	O
# 398	week	O
# 399	before	O
# 400	the	O
# 401	procedure	O
# 402	to	O
# 403	a	O
# 404	mean	O
# 405	of	O
# 406	7.3	O
# 407	(	O
# 408	SD	O
# 409	7.1	O
# 410	)	O
# 411	per	O
# 412	week	O
# 413	during	O
# 414	the	O
# 415	first	O
# 416	2	O
# 417	weeks	O
# 418	after	O
# 419	the	O
# 420	procedure	O
# 421	(	O
# 422	p	O
# 423	<	O
# 424	0.0001	O
# 425	)	O
# 426	.	O
# 427	The	O
# 428	total	O
# 429	number	O
# 430	of	O
# 431	night	O
# 432	awakenings	O
# 433	continued	O
# 434	to	O
# 435	decrease	O
# 436	over	O
# 437	the	O
# 438	remaining	O
# 439	follow-up	O
# 440	period	O
# 441	(	O
# 442	weeks	O
# 443	3-12	O
# 444	)	O
# 445	and	O
# 446	stabilised	O
# 447	at	O
# 448	a	O
# 449	mean	O
# 450	of	O
# 451	1.4	O
# 452	(	O
# 453	SD	O
# 454	1.2	O
# 455	)	O
# 456	per	O
# 457	week	O
# 458	(	O
# 459	p	O
# 460	<	O
# 461	0.0001	O
# 462	)	O
# 463	.	O
# 464	The	O
# 465	findings	O
# 466	of	O
# 467	this	O
# 468	study	O
# 469	suggest	O
# 470	that	O
# 471	stellate-ganglion	O
# 472	block	O
# 473	can	O
# 474	provide	O
# 475	survivors	O
# 476	of	O
# 477	breast	O
# 478	cancer	O
# 479	with	O
# 480	relief	O
# 481	from	O
# 482	hot	O
# 483	flushes	O
# 484	and	O
# 485	sleep	O
# 486	dysfunction	O
# 487	with	O
# 488	few	O
# 489	or	O
# 490	no	O
# 491	side-effects	O
# 492	.	O
# 493	Long-term	O
# 494	relief	O
# 495	of	O
# 496	symptoms	O
# 497	has	O
# 498	the	O
# 499	potential	O
# 500	to	O
# 501	improve	O
# 502	overall	O
# 503	quality	O
# 504	of	O
# 505	life	O
# 506	and	O
# 507	increase	O
# 508	compliance	O
# 509	with	O
# 510	anti-oestrogen	O
# 511	medications	O
# 512	for	O
# 513	breast	O
# 514	cancer	O
# 515	.	O
#
# (274, 318)	Support	(464, 492)
# (319, 356)	Support	(464, 492)
# (357, 384)	Support	(464, 492)
# (385, 426)	Support	(464, 492)
# (427, 463)	Support	(464, 492)
# (464, 492)	Support	(493, 515)
#
# 0	Performance	O
# 1	status	O
# 2	(	O
# 3	PS	O
# 4	)	O
# 5	2	O
# 6	patients	O
# 7	with	O
# 8	non-small	I-Premise
# 9	cell	I-Premise
# 10	lung	I-Premise
# 11	cancer	I-Premise
# 12	(	O
# 13	NSCLC	O
# 14	)	O
# 15	experience	O
# 16	more	O
# 17	toxicity	O
# 18	,	O
# 19	lower	O
# 20	response	O
# 21	rates	I-Premise
# 22	,	I-Premise
# 23	and	O
# 24	shorter	O
# 25	survival	O
# 26	times	O
# 27	than	I-Premise
# 28	healthier	O
# 29	patients	O
# 30	treated	O
# 31	with	O
# 32	standard	O
# 33	chemotherapy	O
# 34	.	O
# 35	Paclitaxel	O
# 36	poliglumex	O
# 37	(	O
# 38	PPX	O
# 39	)	O
# 40	,	O
# 41	a	O
# 42	macromolecule	O
# 43	drug	O
# 44	conjugate	O
# 45	of	O
# 46	paclitaxel	O
# 47	and	O
# 48	polyglutamic	O
# 49	acid	O
# 50	,	O
# 51	reduces	O
# 52	systemic	O
# 53	exposure	O
# 54	to	O
# 55	peak	O
# 56	concentrations	O
# 57	of	O
# 58	free	O
# 59	paclitaxel	O
# 60	and	O
# 61	may	O
# 62	lead	O
# 63	to	O
# 64	increased	O
# 65	concentrations	O
# 66	in	O
# 67	tumors	O
# 68	due	O
# 69	to	O
# 70	enhanced	O
# 71	vascular	O
# 72	permeability	O
# 73	.	O
# 74	Chemotherapy-naive	O
# 75	PS	O
# 76	2	O
# 77	patients	O
# 78	with	O
# 79	advanced	O
# 80	NSCLC	O
# 81	were	O
# 82	randomized	O
# 83	to	O
# 84	receive	O
# 85	carboplatin	O
# 86	(	O
# 87	area	O
# 88	under	O
# 89	the	O
# 90	curve	O
# 91	=	O
# 92	6	O
# 93	)	O
# 94	and	O
# 95	either	O
# 96	PPX	O
# 97	(	O
# 98	210	O
# 99	mg	O
# 100	/	O
# 101	m	O
# 102	/	O
# 103	10	O
# 104	min	O
# 105	without	O
# 106	routine	O
# 107	steroid	O
# 108	premedication	O
# 109	)	O
# 110	or	O
# 111	paclitaxel	O
# 112	(	O
# 113	225	O
# 114	mg	O
# 115	/	O
# 116	m	O
# 117	/	O
# 118	3	O
# 119	h	O
# 120	with	O
# 121	standard	O
# 122	premedication	O
# 123	)	O
# 124	every	O
# 125	3	O
# 126	weeks	O
# 127	.	O
# 128	The	O
# 129	primary	O
# 130	end	O
# 131	point	O
# 132	was	O
# 133	overall	O
# 134	survival	O
# 135	.	O
# 136	A	O
# 137	total	O
# 138	of	O
# 139	400	O
# 140	patients	O
# 141	were	O
# 142	enrolled	O
# 143	.	O
# 144	Alopecia	O
# 145	,	O
# 146	arthralgias	O
# 147	/	O
# 148	myalgias	O
# 149	,	O
# 150	and	O
# 151	cardiac	O
# 152	events	O
# 153	were	O
# 154	significantly	O
# 155	less	O
# 156	frequent	O
# 157	with	O
# 158	PPX	O
# 159	/	O
# 160	carboplatin	O
# 161	,	O
# 162	whereas	O
# 163	grade	O
# 164	>	O
# 165	or	O
# 166	=	O
# 167	3	O
# 168	neutropenia	I-Premise
# 169	and	O
# 170	grade	O
# 171	3	O
# 172	neuropathy	O
# 173	showed	O
# 174	a	O
# 175	trend	O
# 176	of	O
# 177	worsening	O
# 178	.	O
# 179	There	O
# 180	was	O
# 181	no	O
# 182	significant	O
# 183	difference	O
# 184	in	O
# 185	the	O
# 186	incidence	O
# 187	of	O
# 188	hypersensitivity	O
# 189	reactions	O
# 190	despite	O
# 191	the	O
# 192	absence	O
# 193	of	O
# 194	routine	O
# 195	premedication	O
# 196	in	O
# 197	the	O
# 198	PPX	O
# 199	arm	O
# 200	.	O
# 201	Overall	O
# 202	survival	O
# 203	was	O
# 204	similar	I-Premise
# 205	between	O
# 206	treatment	O
# 207	arms	O
# 208	(	O
# 209	hazard	O
# 210	ratio	O
# 211	,	I-Premise
# 212	0.97	I-Premise
# 213	;	I-Premise
# 214	log	O
# 215	rank	O
# 216	p	O
# 217	=	I-Premise
# 218	0.769	O
# 219	)	O
# 220	.	O
# 221	Median	O
# 222	and	O
# 223	1	O
# 224	-	O
# 225	year	O
# 226	survival	O
# 227	rates	O
# 228	were	O
# 229	7.9	O
# 230	months	O
# 231	and	O
# 232	31	O
# 233	%	I-Premise
# 234	,	I-Premise
# 235	for	O
# 236	PPX	O
# 237	versus	O
# 238	8	O
# 239	months	I-Premise
# 240	and	O
# 241	31	O
# 242	%	I-Premise
# 243	for	I-Premise
# 244	paclitaxel	I-Premise
# 245	.	O
# 246	Disease	O
# 247	control	O
# 248	rates	O
# 249	were	O
# 250	64	O
# 251	%	I-Premise
# 252	and	O
# 253	69	O
# 254	%	I-Premise
# 255	for	I-Premise
# 256	PPX	O
# 257	and	O
# 258	paclitaxel	O
# 259	,	O
# 260	respectively	I-Premise
# 261	.	O
# 262	Time	O
# 263	to	O
# 264	progression	O
# 265	was	I-Premise
# 266	similar	I-Premise
# 267	:	I-Premise
# 268	3.9	O
# 269	months	I-Premise
# 270	for	O
# 271	PPX	O
# 272	/	O
# 273	carboplatin	O
# 274	versus	O
# 275	4.6	O
# 276	months	O
# 277	for	O
# 278	paclitaxel	O
# 279	/	O
# 280	carboplatin	O
# 281	(	O
# 282	p	O
# 283	=	O
# 284	0.210	O
# 285	)	O
# 286	.	O
# 287	PPX	O
# 288	/	O
# 289	carboplatin	O
# 290	failed	O
# 291	to	O
# 292	provide	O
# 293	superior	O
# 294	survival	O
# 295	compared	O
# 296	with	O
# 297	paclitaxel	O
# 298	/	O
# 299	carboplatin	O
# 300	in	O
# 301	the	O
# 302	first-line	O
# 303	treatment	O
# 304	of	O
# 305	PS	O
# 306	2	O
# 307	patients	O
# 308	with	O
# 309	NSCLC	O
# 310	,	O
# 311	but	O
# 312	the	O
# 313	results	O
# 314	with	O
# 315	respect	O
# 316	to	O
# 317	progression-free	O
# 318	survival	O
# 319	and	O
# 320	overall	O
# 321	survival	O
# 322	were	O
# 323	comparable	O
# 324	and	O
# 325	the	O
# 326	PPX	O
# 327	regimen	O
# 328	was	O
# 329	more	O
# 330	convenient	O
# 331	.	O
#
# (311, 331)	Partial-Attack	(287, 310)
# (221, 245)	Support	(287, 310)
# (201, 220)	Support	(287, 310)
# (179, 200)	Support	(287, 310)
# (144, 178)	Support	(287, 310)
#
# 0	Persistent	O
# 1	insomnia	O
# 2	is	O
# 3	a	O
# 4	common	O
# 5	complaint	O
# 6	in	O
# 7	cancer	O
# 8	survivors	O
# 9	,	O
# 10	but	O
# 11	is	O
# 12	seldom	O
# 13	satisfactorily	O
# 14	addressed	O
# 15	.	O
# 16	The	O
# 17	adaptation	O
# 18	to	O
# 19	cancer	O
# 20	care	O
# 21	of	O
# 22	a	O
# 23	validated	O
# 24	,	O
# 25	cost-effective	O
# 26	intervention	O
# 27	may	O
# 28	offer	O
# 29	a	O
# 30	practicable	O
# 31	solution	O
# 32	.	O
# 33	The	O
# 34	aim	O
# 35	of	O
# 36	this	O
# 37	study	O
# 38	was	O
# 39	to	O
# 40	investigate	O
# 41	the	O
# 42	clinical	O
# 43	effectiveness	O
# 44	of	O
# 45	protocol-driven	O
# 46	cognitive	O
# 47	behavior	O
# 48	therapy	O
# 49	(	O
# 50	CBT	O
# 51	)	O
# 52	for	O
# 53	insomnia	O
# 54	,	O
# 55	delivered	O
# 56	by	O
# 57	oncology	O
# 58	nurses	O
# 59	.	O
# 60	Randomized	O
# 61	,	O
# 62	controlled	O
# 63	,	O
# 64	pragmatic	O
# 65	,	O
# 66	two-center	O
# 67	trial	O
# 68	of	O
# 69	CBT	O
# 70	versus	O
# 71	treatment	O
# 72	as	O
# 73	usual	O
# 74	(	O
# 75	TAU	O
# 76	)	O
# 77	in	O
# 78	150	O
# 79	patients	O
# 80	(	O
# 81	103	O
# 82	females	O
# 83	;	O
# 84	mean	O
# 85	age	O
# 86	,	O
# 87	61	O
# 88	years	O
# 89	.	O
# 90	)	O
# 91	who	O
# 92	had	O
# 93	completed	O
# 94	active	O
# 95	therapy	O
# 96	for	O
# 97	breast	O
# 98	,	O
# 99	prostate	O
# 100	,	O
# 101	colorectal	O
# 102	,	O
# 103	or	O
# 104	gynecological	O
# 105	cancer	O
# 106	.	O
# 107	The	O
# 108	study	O
# 109	conformed	O
# 110	to	O
# 111	CONSORT	O
# 112	guidelines	O
# 113	.	O
# 114	Primary	O
# 115	outcomes	O
# 116	were	O
# 117	sleep	O
# 118	diary	O
# 119	measures	O
# 120	at	O
# 121	baseline	O
# 122	,	O
# 123	post-treatment	O
# 124	,	O
# 125	and	O
# 126	6	O
# 127	-	O
# 128	month	O
# 129	follow-up	O
# 130	.	O
# 131	Actigraphic	O
# 132	sleep	O
# 133	,	O
# 134	health-related	O
# 135	quality	O
# 136	of	O
# 137	life	O
# 138	(	O
# 139	QOL	O
# 140	)	O
# 141	,	O
# 142	psychopathology	O
# 143	,	O
# 144	and	O
# 145	fatigue	O
# 146	were	O
# 147	secondary	O
# 148	measures	O
# 149	.	O
# 150	CBT	O
# 151	comprised	O
# 152	five	O
# 153	,	O
# 154	small	O
# 155	group	O
# 156	sessions	O
# 157	across	O
# 158	consecutive	O
# 159	weeks	O
# 160	,	O
# 161	after	O
# 162	a	O
# 163	manualized	O
# 164	protocol	O
# 165	.	O
# 166	TAU	O
# 167	represented	O
# 168	normal	O
# 169	clinical	O
# 170	practice	O
# 171	;	O
# 172	the	O
# 173	appropriate	O
# 174	control	O
# 175	for	O
# 176	a	O
# 177	clinical	O
# 178	effectiveness	O
# 179	study	O
# 180	.	O
# 181	CBT	O
# 182	was	O
# 183	associated	O
# 184	with	O
# 185	mean	O
# 186	reductions	O
# 187	in	O
# 188	wakefulness	O
# 189	of	O
# 190	55	O
# 191	minutes	O
# 192	per	O
# 193	night	O
# 194	compared	O
# 195	with	O
# 196	no	O
# 197	change	O
# 198	in	O
# 199	TAU	O
# 200	.	O
# 201	These	O
# 202	outcomes	O
# 203	were	O
# 204	sustained	O
# 205	6	O
# 206	months	O
# 207	after	O
# 208	treatment	O
# 209	.	O
# 210	Standardized	O
# 211	relative	O
# 212	effect	O
# 213	sizes	O
# 214	were	O
# 215	large	O
# 216	for	O
# 217	complaints	O
# 218	of	O
# 219	difficulty	O
# 220	initiating	O
# 221	sleep	O
# 222	,	O
# 223	waking	O
# 224	from	O
# 225	sleep	O
# 226	during	O
# 227	the	O
# 228	night	O
# 229	,	O
# 230	and	O
# 231	for	O
# 232	sleep	O
# 233	efficiency	O
# 234	(	O
# 235	percentage	O
# 236	of	O
# 237	time	O
# 238	in	O
# 239	bed	O
# 240	spent	O
# 241	asleep	O
# 242	)	O
# 243	.	O
# 244	CBT	O
# 245	was	O
# 246	associated	O
# 247	with	O
# 248	moderate	O
# 249	to	O
# 250	large	O
# 251	effect	O
# 252	sizes	O
# 253	for	O
# 254	five	O
# 255	of	O
# 256	seven	O
# 257	QOL	O
# 258	outcomes	O
# 259	,	O
# 260	including	O
# 261	significant	O
# 262	reduction	O
# 263	in	O
# 264	daytime	O
# 265	fatigue	O
# 266	.	O
# 267	There	O
# 268	was	O
# 269	no	O
# 270	significant	O
# 271	interaction	O
# 272	effect	O
# 273	between	O
# 274	any	O
# 275	of	O
# 276	these	O
# 277	outcomes	O
# 278	and	O
# 279	baseline	O
# 280	demographic	O
# 281	,	O
# 282	clinical	O
# 283	,	O
# 284	or	O
# 285	sleep	O
# 286	characteristics	O
# 287	.	O
# 288	CBT	O
# 289	for	O
# 290	insomnia	O
# 291	may	O
# 292	be	O
# 293	both	O
# 294	clinically	O
# 295	effective	O
# 296	and	O
# 297	feasible	O
# 298	to	O
# 299	deliver	O
# 300	in	O
# 301	real	O
# 302	world	O
# 303	practice	O
# 304	.	O
#
# (181, 200)	Support	(288, 304)
# (244, 266)	Support	(288, 304)
# (267, 287)	Support	(288, 304)
#
# 0	The	O
# 1	management	O
# 2	of	O
# 3	recurrent	O
# 4	ovarian	O
# 5	cancer	O
# 6	remains	O
# 7	controversial	O
# 8	.	O
# 9	Single-agent	O
# 10	topotecan	O
# 11	is	O
# 12	an	O
# 13	established	O
# 14	treatment	O
# 15	option	O
# 16	,	O
# 17	and	O
# 18	preliminary	O
# 19	evidence	O
# 20	suggests	O
# 21	improved	O
# 22	tumor	O
# 23	control	O
# 24	by	O
# 25	combining	O
# 26	topotecan	O
# 27	with	O
# 28	etoposide	O
# 29	or	O
# 30	gemcitabine	O
# 31	.	O
# 32	Women	O
# 33	with	O
# 34	relapsed	O
# 35	ovarian	O
# 36	cancer	O
# 37	after	O
# 38	primary	O
# 39	surgery	O
# 40	and	O
# 41	platinum-based	O
# 42	chemotherapy	O
# 43	were	O
# 44	randomly	O
# 45	assigned	O
# 46	to	O
# 47	topotecan	O
# 48	monotherapy	O
# 49	1.25	O
# 50	mg	O
# 51	/	O
# 52	m	O
# 53	(	O
# 54	2	O
# 55	)	O
# 56	/	O
# 57	d	O
# 58	,	O
# 59	topotecan	O
# ...
# 319	:	I-Premise
# 320	0.04-	I-Premise
# 321	2.80	I-Premise
# 322	)	I-Premise
# 323	.	O
# 324	The	O
# 325	survival	O
# 326	results	O
# 327	will	O
# 328	be	O
# 329	published	O
# 330	elsewhere	O
# 331	.	O
# 332	LRH	O
# 333	provided	O
# 334	lower	O
# 335	pain	O
# 336	scores	O
# 337	after	O
# 338	36	O
# 339	h	O
# 340	of	O
# 341	observation	O
# 342	in	O
# 343	this	O
# 344	series	O
# 345	.	O
# 346	The	O
# 347	perioperative	O
# 348	and	O
# 349	serious	O
# 350	postoperative	O
# 351	complications	O
# 352	ratios	O
# 353	were	O
# 354	comparable	O
# 355	between	O
# 356	the	O
# 357	groups	O
# 358	.	O
#
# (290, 323)	Support	(332, 345)
# (269, 289)	Support	(346, 358)
# (229, 257)	Support	(346, 358)
#
# 0	The	O
# 1	CO	O
# 2	.	O
# 3	20	O
# 4	trial	O
# 5	randomized	O
# 6	patients	O
# 7	with	O
# 8	K-RAS	O
# 9	wild-type	O
# 10	,	O
# 11	chemotherapy-refractory	O
# 12	,	O
# 13	metastatic	O
# 14	colorectal	O
# 15	cancer	O
# 16	to	O
# 17	receive	O
# 18	cetuximab	O
# 19	(	O
# 20	CET	O
# 21	)	O
# 22	plus	O
# 23	brivanib	O
# 24	alaninate	O
# 25	(	O
# 26	BRIV	O
# 27	)	O
# 28	or	O
# 29	CET	O
# 30	plus	O
# 31	placebo	O
# 32	(	O
# 33	CET	O
# 34	/	O
# 35	placebo	O
# 36	)	O
# 37	.	O
# 38	Quality	O
# 39	of	O
# 40	life	O
# 41	(	O
# 42	QoL	O
# 43	)	O
# 44	was	O
# 45	assessed	O
# 46	using	O
# 47	the	O
# 48	European	O
# 49	Organization	O
# 50	for	O
# 51	Research	O
# 52	and	O
# 53	Treatment	O
# 54	of	O
# 55	Cancer	O
# 56	Quality	O
# 57	of	O
# 58	Life	O
# 59	Questionnaire	O
# 60	C30	O
# 61	at	O
# 62	baseline	O
# 63	and	O
# 64	at	O
# 65	2	O
# 66	,	O
# 67	4	O
# 68	,	O
# 69	6	O
# 70	,	O
# 71	8	O
# 72	,	O
# 73	12	O
# 74	,	O
# 75	16	O
# 76	,	O
# 77	and	O
# 78	24	O
# 79	weeks	O
# 80	until	O
# 81	disease	O
# 82	progression	O
# 83	.	O
# 84	Predefined	O
# 85	coprimary	O
# 86	QoL	O
# 87	endpoints	O
# 88	were	O
# 89	time	O
# 90	to	O
# 91	deterioration	O
# 92	(	O
# 93	first	O
# 94	worsening	O
# 95	from	O
# 96	baseline	O
# 97	of	O
# 98	≥	O
# 99	10	O
# 100	points	O
# 101	)	O
# 102	on	O
# 103	the	O
# 104	Physical	O
# 105	Function	O
# 106	(	O
# 107	PF	O
# 108	)	O
# 109	and	O
# 110	Global	O
# 111	(	O
# 112	GHS	O
# 113	)	O
# 114	scales	O
# 115	.	O
# 116	Of	O
# 117	750	O
# 118	randomized	O
# 119	patients	O
# 120	,	O
# 121	721	O
# 122	(	O
# 123	358	O
# 124	of	O
# 125	whom	O
# 126	received	O
# 127	CET	O
# 128	/	O
# 129	BRIV	O
# 130	)	O
# 131	were	O
# 132	assessable	O
# 133	for	O
# 134	QoL	O
# 135	.	O
# 136	QoL	O
# 137	compliance	O
# 138	and	O
# 139	baseline	O
# 140	PF	O
# 141	and	O
# 142	GHS	O
# 143	scores	O
# 144	did	O
# 145	not	O
# 146	differ	O
# 147	by	O
# 148	treatment	O
# 149	arm	O
# 150	.	O
# 151	The	O
# 152	median	O
# 153	time	O
# 154	to	O
# 155	deterioration	O
# 156	was	O
# 157	1.6	O
# 158	months	O
# 159	versus	O
# 160	1.1	O
# 161	months	I-Premise
# 162	for	O
# 163	GHS	O
# 164	(	O
# 165	P	I-Premise
# 166	=	I-Premise
# 167	.	O
# 168	02	O
# 169	)	O
# 170	and	O
# 171	5.6	O
# 172	months	O
# 173	versus	O
# 174	1.7	O
# 175	months	O
# 176	for	O
# 177	PF	O
# 178	(	O
# 179	P	I-Premise
# 180	<	I-Premise
# 181	.	O
# 182	0001	O
# 183	)	O
# 184	favoring	O
# 185	CET	O
# 186	/	O
# 187	placebo	O
# 188	.	O
# 189	Secondary	O
# 190	analysis	O
# 191	favored	O
# 192	CET	O
# 193	/	O
# 194	placebo	O
# 195	for	O
# 196	QOL	O
# 197	response	O
# 198	on	O
# 199	the	O
# 200	PF	O
# 201	,	O
# 202	Cognitive	O
# 203	Function	O
# 204	,	O
# 205	Fatigue	O
# 206	,	O
# 207	Nausea	O
# 208	,	O
# 209	Appetite	O
# 210	,	O
# 211	and	O
# 212	Diarrhea	O
# 213	scales	O
# 214	.	O
# 215	A	O
# 216	greater	O
# 217	percentage	O
# 218	of	O
# 219	patients	O
# 220	on	O
# 221	the	O
# 222	CET	O
# 223	/	O
# 224	BRIV	O
# 225	arm	O
# 226	had	O
# 227	PF	O
# 228	worsening	O
# 229	at	O
# 230	6	O
# 231	weeks	O
# 232	(	O
# 233	31	O
# 234	%	I-Premise
# 235	vs	O
# 236	17	O
# 237	%	I-Premise
# 238	)	I-Premise
# 239	.	O
# 240	Clinical	O
# 241	adverse	O
# 242	events	O
# 243	of	O
# 244	≥	O
# 245	grade	O
# 246	3	O
# 247	were	O
# 248	more	O
# 249	common	O
# 250	with	O
# 251	CET	O
# 252	/	O
# 253	BRIV	O
# 254	than	O
# 255	with	O
# 256	CET	O
# 257	/	O
# 258	placebo	O
# 259	,	O
# 260	including	O
# 261	fatigue	O
# 262	(	O
# 263	25	O
# 264	%	I-Premise
# 265	vs	O
# 266	11	O
# 267	%	I-Premise
# 268	)	I-Premise
# 269	,	I-Premise
# 270	hypertension	I-Premise
# 271	,	I-Premise
# 272	rash	I-Premise
# 273	,	I-Premise
# 274	diarrhea	O
# 275	,	I-Premise
# 276	abdominal	O
# 277	pain	I-Premise
# 278	,	I-Premise
# 279	dehydration	O
# 280	,	O
# 281	and	O
# 282	anorexia	O
# 283	.	O
# 284	Compared	O
# 285	with	O
# 286	CET	O
# 287	/	O
# 288	placebo	O
# 289	,	O
# 290	the	O
# 291	combination	O
# 292	of	O
# 293	CET	O
# 294	/	O
# 295	BRIV	O
# 296	worsened	O
# 297	time	O
# 298	to	O
# 299	QoL	O
# 300	deterioration	O
# 301	for	O
# 302	patients	O
# 303	with	O
# 304	K-RAS	O
# 305	wild-type	O
# 306	,	O
# 307	chemotherapy-refractory	O
# 308	,	O
# 309	metastatic	O
# 310	colorectal	O
# 311	cancer	O
# 312	on	O
# 313	the	O
# 314	PF	O
# 315	and	O
# 316	GHS	O
# 317	scales	O
# 318	of	O
# 319	European	O
# 320	Organization	O
# 321	for	O
# 322	Research	O
# 323	and	O
# 324	Treatment	O
# 325	of	O
# 326	Cancer	O
# 327	Quality	O
# 328	of	O
# 329	Life	O
# 330	Questionnaire	O
# 331	C30	O
# 332	.	O
# 333	This	O
# 334	result	O
# 335	may	O
# 336	be	O
# 337	due	O
# 338	to	O
# 339	higher	O
# 340	rates	O
# 341	of	O
# 342	fatigue	O
# 343	and	O
# 344	gastrointestinal	O
# 345	adverse	O
# 346	events	O
# 347	.	O
#
# (151, 188)	Support	(284, 332)
# (189, 214)	Support	(284, 332)
# (333, 347)	Partial-Attack	(284, 332)
# (240, 283)	Support	(333, 347)
#
# 0	Surgical	O
# 1	resection	O
# 2	enhances	O
# 3	long-term	I-Premise
# 4	survival	I-Premise
# 5	after	I-Premise
# 6	lung	I-Premise
# 7	cancer	I-Premise
# 8	,	I-Premise
# 9	but	I-Premise
# 10	survivors	O
# 11	face	O
# 12	functional	O
# 13	deficits	O
# 14	and	O
# 15	report	O
# 16	on	O
# 17	poor	O
# 18	quality	O
# 19	of	O
# 20	life	O
# 21	long	O
# 22	time	O
# 23	after	O
# 24	surgery	O
# 25	.	O
# 26	This	O
# 27	study	O
# 28	evaluated	O
# 29	short	O
# 30	and	O
# 31	long-term	O
# 32	effects	O
# 33	of	O
# 34	supervised	O
# 35	group	O
# 36	exercise	O
# 37	training	O
# 38	on	O
# 39	health-related	O
# 40	quality	O
# 41	of	O
# 42	life	O
# 43	and	O
# 44	physical	O
# 45	performance	O
# 46	in	O
# 47	patients	O
# 48	,	O
# 49	who	O
# 50	were	O
# 51	radically	O
# 52	operated	O
# 53	for	O
# 54	lung	O
# 55	cancer	O
# 56	.	O
# 57	A	O
# 58	randomized	O
# 59	,	O
# 60	assessor-blinded	O
# 61	,	O
# 62	controlled	O
# 63	trial	O
# 64	was	O
# 65	performed	O
# 66	on	O
# 67	78	O
# 68	patients	O
# 69	undergoing	O
# 70	lung	O
# 71	cancer	O
# 72	surgery	O
# 73	.	O
# 74	The	O
# 75	intervention	O
# 76	group	O
# 77	(	O
# 78	IG	O
# 79	,	O
# 80	n	O
# 81	=	I-Premise
# 82	41	O
# 83	)	O
# 84	participated	O
# 85	in	O
# 86	supervised	O
# 87	out-patient	O
# 88	exercise	O
# 89	training	O
# 90	sessions	O
# 91	,	O
# 92	one	O
# 93	hour	O
# 94	once	O
# 95	a	O
# 96	week	O
# 97	for	O
# 98	ten	O
# 99	weeks	O
# 100	.	O
# 101	The	O
# 102	sessions	O
# 103	were	O
# 104	based	O
# 105	on	O
# 106	aerobic	O
# 107	exercises	O
# 108	with	O
# 109	target	O
# 110	intensity	O
# 111	of	O
# 112	60-80	O
# 113	%	O
# 114	of	O
# 115	work	O
# 116	capacity	O
# 117	,	O
# 118	resistance	O
# 119	training	O
# 120	and	O
# 121	dyspnoea	O
# 122	management	O
# 123	.	O
# 124	The	O
# 125	control	O
# 126	group	O
# 127	(	O
# 128	CG	O
# 129	,	O
# 130	n	O
# 131	=	I-Premise
# 132	37	O
# 133	)	O
# 134	received	O
# 135	one	O
# 136	individual	O
# 137	instruction	O
# 138	in	O
# 139	exercise	O
# 140	training	O
# 141	.	O
# 142	Measurements	O
# 143	consisted	O
# 144	of	O
# 145	:	O
# 146	health-related	O
# 147	quality	O
# 148	of	O
# 149	life	O
# 150	(	O
# 151	SF36	O
# 152	)	O
# 153	,	O
# 154	six	O
# 155	minute	O
# 156	walk	O
# 157	test	O
# 158	(	O
# 159	6MWT	O
# 160	)	O
# 161	and	O
# 162	lung	O
# 163	function	O
# 164	(	O
# 165	spirometry	O
# 166	)	O
# 167	,	O
# 168	assessed	O
# 169	three	O
# 170	weeks	O
# 171	after	O
# 172	surgery	O
# 173	and	O
# 174	after	O
# 175	four	O
# 176	and	O
# 177	twelve	O
# 178	months	O
# 179	.	O
# 180	Both	O
# 181	groups	O
# 182	were	O
# 183	comparable	O
# 184	at	O
# 185	baseline	O
# 186	on	O
# 187	demographic	O
# 188	characteristic	O
# 189	and	O
# 190	outcome	O
# 191	values	O
# 192	.	O
# 193	We	O
# 194	found	O
# 195	a	O
# 196	statistically	O
# 197	significant	O
# 198	effect	O
# 199	after	O
# 200	four	O
# 201	months	O
# 202	in	O
# 203	the	O
# 204	bodily	O
# 205	pain	O
# 206	domain	O
# 207	of	O
# 208	SF36	O
# 209	,	O
# 210	with	O
# 211	an	O
# 212	estimated	O
# 213	mean	O
# 214	difference	O
# 215	(	O
# 216	EMD	O
# 217	)	O
# 218	of	O
# 219	15.3	O
# 220	(	O
# 221	95	O
# 222	%	I-Premise
# 223	CI	I-Premise
# 224	:	I-Premise
# 225	4	I-Premise
# 226	to	I-Premise
# 227	26.6	O
# 228	,	I-Premise
# 229	p=	I-Premise
# 230	0.01	I-Premise
# 231	)	I-Premise
# 232	and	O
# 233	a	O
# 234	trend	O
# 235	in	O
# 236	favour	O
# 237	of	O
# 238	the	O
# 239	intervention	O
# 240	for	O
# 241	role	O
# 242	physical	O
# 243	functioning	O
# 244	(	O
# 245	EMD	O
# 246	12.04	O
# 247	,	O
# 248	95	O
# 249	%	I-Premise
# 250	CI	I-Premise
# 251	:	I-Premise
# 252	-	I-Premise
# 253	1	I-Premise
# 254	to	I-Premise
# 255	25.1	O
# 256	,	I-Premise
# 257	p=	I-Premise
# 258	0.07	O
# 259	)	O
# 260	and	O
# 261	physical	O
# 262	component	O
# 263	summary	O
# 264	(	O
# 265	EMD	O
# 266	3.76	O
# 267	,	O
# 268	95	O
# 269	%	I-Premise
# 270	CI	I-Premise
# 271	:	I-Premise
# 272	-0.1	I-Premise
# 273	to	I-Premise
# 274	7.6	O
# 275	,	I-Premise
# 276	p=	I-Premise
# 277	0.06	O
# 278	)	O
# 279	.	O
# 280	At	O
# 281	12	O
# 282	months	O
# 283	,	O
# 284	the	O
# 285	tendency	O
# 286	was	I-Premise
# 287	reversed	O
# 288	,	O
# 289	with	O
# 290	the	O
# 291	CG	O
# 292	presenting	O
# 293	overall	O
# 294	slightly	O
# 295	better	O
# 296	measures	O
# 297	.	O
# 298	We	O
# 299	found	O
# 300	no	O
# 301	effect	O
# 302	of	O
# 303	the	O
# 304	intervention	O
# 305	on	O
# 306	6MWT	O
# 307	or	O
# 308	lung	O
# 309	volumes	O
# 310	at	O
# 311	any	O
# 312	time-point	O
# 313	.	O
# 314	Supervised	O
# 315	compared	O
# 316	to	O
# 317	unsupervised	O
# 318	exercise	O
# 319	training	O
# 320	resulted	O
# 321	in	O
# 322	no	O
# 323	improvement	O
# 324	in	O
# 325	health-related	O
# 326	quality	O
# 327	of	O
# 328	life	O
# 329	,	O
# 330	except	O
# 331	for	O
# 332	the	O
# 333	bodily	O
# 334	pain	O
# 335	domain	O
# 336	,	O
# 337	four	O
# 338	months	O
# 339	after	O
# 340	lung	O
# 341	cancer	O
# 342	surgery	I-Premise
# 343	.	O
# 344	No	O
# 345	effects	O
# 346	of	O
# 347	the	O
# 348	intervention	O
# 349	were	O
# 350	found	O
# 351	for	O
# 352	any	O
# 353	outcome	O
# 354	after	O
# 355	one	O
# 356	year	O
# 357	.	O
#
# (330, 343)	Partial-Attack	(314, 329)
# (298, 313)	Support	(344, 357)
# (314, 329)	Support	(344, 357)
# (280, 297)	Attack	(193, 279)
# (193, 279)	Attack	(344, 357)
#
# 0	To	O
# 1	compare	O
# 2	two	O
# 3	cisplatin	O
# 4	based	O
# 5	chemotherapy	O
# 6	schedules	O
# 7	in	O
# 8	patients	O
# 9	with	O
# 10	advanced	O
# 11	non-small-cell	O
# 12	lung	O
# 13	cancer	O
# 14	(	O
# 15	NSCLC	O
# 16	)	O
# 17	.	O
# 18	A	O
# 19	total	O
# 20	of	O
# 21	332	O
# 22	patients	O
# 23	with	O
# 24	advanced	O
# 25	NSCLC	O
# 26	were	O
# 27	randomized	O
# 28	to	O
# 29	receive	O
# 30	cisplatin	O
# 31	80	O
# 32	mg	O
# 33	/	O
# 34	m2	O
# 35	on	O
# 36	day	O
# 37	1	O
# 38	either	O
# 39	in	O
# 40	combination	O
# 41	with	O
# 42	teniposide	O
# 43	100	O
# 44	mg	O
# 45	/	O
# 46	m2	O
# 47	on	O
# 48	days	O
# 49	1	O
# 50	,	O
# 51	3	O
# 52	,	O
# 53	and	O
# 54	5	O
# 55	(	O
# 56	arm	O
# 57	A	O
# 58	)	O
# 59	or	O
# 60	paclitaxel	O
# 61	175	O
# 62	mg	O
# 63	/	O
# 64	m2	O
# 65	by	O
# 66	3	O
# 67	-	O
# 68	hour	O
# 69	infusion	O
# 70	on	O
# 71	day	O
# 72	1	O
# 73	(	O
# 74	arm	O
# 75	B	O
# 76	);	O
# 77	cycles	O
# 78	were	O
# 79	repeated	O
# 80	every	O
# 81	3	O
# 82	weeks	O
# 83	.	O
# 84	Fifteen	O
# 85	patients	O
# 86	were	O
# 87	ineligible	O
# 88	;	O
# 89	patient	O
# 90	characteristics	O
# 91	were	O
# 92	well	O
# 93	balanced	O
# 94	between	O
# 95	the	O
# 96	two	O
# 97	arms	O
# 98	:	O
# 99	71	O
# 100	%	I-Premise
# 101	were	O
# 102	male	O
# 103	,	O
# 104	71	O
# 105	%	I-Premise
# 106	had	I-Premise
# 107	less	I-Premise
# 108	than	I-Premise
# 109	5	I-Premise
# 110	%	I-Premise
# 111	weight	I-Premise
# 112	loss	I-Premise
# 113	,	I-Premise
# 114	89	I-Premise
# 115	%	I-Premise
# 116	had	I-Premise
# 117	a	I-Premise
# 118	World	I-Premise
# 119	Health	O
# 120	Organization	I-Premise
# 121	(	O
# 122	WHO	O
# 123	)	O
# 124	performance	I-Premise
# 125	status	O
# 126	of	O
# 127	0	I-Premise
# 128	to	O
# 129	1	O
# 130	,	O
# 131	51	O
# 132	%	I-Premise
# 133	had	I-Premise
# 134	adenocarcinoma	O
# 135	,	I-Premise
# 136	and	O
# 137	61	O
# 138	%	I-Premise
# 139	had	I-Premise
# 140	stage	I-Premise
# 141	IV	I-Premise
# 142	disease	I-Premise
# 143	.	O
# 144	Hematologic	O
# 145	toxicity	O
# 146	was	I-Premise
# 147	significantly	I-Premise
# 148	more	O
# 149	severe	O
# 150	in	O
# 151	arm	O
# 152	A	O
# 153	(	O
# 154	leukopenia	O
# 155	,	O
# 156	neutropenia	O
# 157	,	O
# 158	and	O
# 159	thrombocytopenia	O
# 160	grade	O
# 161	3	O
# 162	or	O
# 163	4	O
# 164	:	O
# 165	66	O
# 166	%	I-Premise
# 167	v	I-Premise
# 168	19	I-Premise
# 169	%	I-Premise
# 170	,	I-Premise
# 171	83	I-Premise
# 172	%	I-Premise
# 173	v	I-Premise
# 174	55	I-Premise
# 175	%	I-Premise
# 176	,	I-Premise
# 177	36	I-Premise
# 178	%	I-Premise
# 179	v	I-Premise
# 180	2	I-Premise
# 181	%	I-Premise
# 182	in	I-Premise
# 183	arms	I-Premise
# 184	A	I-Premise
# 185	and	I-Premise
# 186	B	I-Premise
# 187	,	I-Premise
# 188	respectively	I-Premise
# 189	)	I-Premise
# 190	,	I-Premise
# 191	which	I-Premise
# 192	resulted	I-Premise
# 193	in	I-Premise
# 194	more	I-Premise
# 195	febrile	O
# 196	neutropenia	I-Premise
# 197	(	I-Premise
# 198	27	I-Premise
# 199	%	I-Premise
# 200	v	I-Premise
# 201	3	I-Premise
# 202	%	I-Premise
# 203	in	I-Premise
# 204	arms	I-Premise
# 205	A	I-Premise
# 206	and	O
# 207	B	I-Premise
# 208	,	I-Premise
# 209	respectively	I-Premise
# 210	)	I-Premise
# 211	,	I-Premise
# 212	dose	I-Premise
# 213	reductions	I-Premise
# 214	,	I-Premise
# 215	and	I-Premise
# 216	treatment	O
# 217	delays	O
# 218	.	O
# 219	There	O
# 220	were	O
# 221	a	O
# 222	total	O
# 223	of	O
# 224	nine	O
# 225	toxic	O
# 226	deaths	O
# 227	,	O
# 228	six	O
# 229	due	O
# 230	to	O
# 231	neutropenic	O
# 232	sepsis	O
# 233	:	O
# 234	five	O
# 235	in	O
# 236	arm	O
# 237	A	O
# 238	and	O
# 239	one	O
# 240	in	O
# 241	arm	O
# 242	B	O
# 243	.	O
# 244	In	O
# 245	contrast	O
# 246	,	O
# 247	arthralgia	O
# 248	/	O
# 249	myalgia	O
# 250	(	O
# 251	grade	O
# 252	2	O
# 253	or	O
# 254	3	O
# 255	,	O
# 256	4	O
# 257	%	I-Premise
# 258	v	O
# 259	17	O
# 260	%	I-Premise
# 261	)	I-Premise
# 262	,	I-Premise
# 263	peripheral	I-Premise
# 264	neurotoxicity	I-Premise
# 265	(	I-Premise
# 266	grade	I-Premise
# 267	2	I-Premise
# 268	or	I-Premise
# 269	3	O
# 270	,	I-Premise
# 271	6	I-Premise
# 272	%	I-Premise
# 273	v	I-Premise
# 274	29	O
# 275	%	I-Premise
# 276	)	I-Premise
# 277	,	I-Premise
# 278	and	I-Premise
# 279	hypersensitivity	I-Premise
# 280	reactions	O
# 281	(	O
# 282	1	O
# 283	%	I-Premise
# 284	v	I-Premise
# 285	7	I-Premise
# 286	%	I-Premise
# 287	,	I-Premise
# 288	all	I-Premise
# 289	grades	I-Premise
# 290	)	I-Premise
# 291	were	O
# 292	significantly	O
# 293	more	O
# 294	frequent	O
# 295	in	O
# 296	arm	O
# 297	B	O
# 298	.	O
# 299	The	O
# 300	frequency	O
# 301	and	O
# 302	severity	O
# 303	of	O
# 304	other	O
# 305	toxicities	O
# 306	were	O
# 307	comparable	O
# 308	between	O
# 309	the	O
# 310	two	O
# 311	arms	O
# 312	.	O
# 313	Responses	O
# 314	were	O
# 315	one	O
# 316	complete	O
# 317	and	O
# 318	44	O
# 319	partial	O
# 320	on	O
# 321	arm	O
# 322	A	O
# 323	(	O
# 324	28	O
# 325	%	I-Premise
# 326	)	O
# 327	and	O
# 328	two	O
# 329	complete	O
# 330	and	O
# 331	61	O
# 332	partial	O
# 333	(	O
# 334	41	O
# 335	%	I-Premise
# 336	)	I-Premise
# 337	on	O
# 338	arm	O
# 339	B	O
# 340	(	O
# 341	P	I-Premise
# 342	=	I-Premise
# 343	.	O
# 344	018	O
# 345	)	O
# 346	.	O
# 347	There	O
# 348	was	O
# 349	no	O
# 350	significant	O
# 351	difference	O
# 352	in	O
# 353	survival	I-Premise
# 354	,	O
# 355	with	I-Premise
# 356	median	O
# 357	and	O
# 358	1	O
# 359	-	O
# 360	year	O
# 361	survivals	O
# 362	9.9	O
# 363	versus	O
# 364	9.7	O
# 365	months	O
# 366	and	O
# 367	41	O
# 368	%	I-Premise
# 369	versus	I-Premise
# 370	43	I-Premise
# 371	%	I-Premise
# 372	,	I-Premise
# 373	respectively	I-Premise
# 374	in	I-Premise
# 375	arm	I-Premise
# 376	A	I-Premise
# 377	and	O
# 378	B	O
# 379	.	O
# 380	Progression-free	O
# 381	survival	O
# 382	was	I-Premise
# 383	4.9	O
# 384	and	O
# 385	5.4	O
# 386	months	O
# 387	in	O
# 388	arm	O
# 389	A	O
# 390	and	O
# 391	B	O
# 392	,	O
# 393	respectively	O
# 394	.	O
# 395	Selected	O
# 396	centers	O
# 397	participated	O
# 398	in	O
# 399	a	O
# 400	quality-of-life	O
# 401	(	O
# 402	QoL	O
# 403	)	O
# 404	assessment	O
# 405	,	O
# 406	which	O
# 407	was	I-Premise
# 408	performed	O
# 409	by	O
# 410	the	O
# 411	European	O
# 412	Organization	O
# 413	for	O
# 414	Research	O
# 415	and	O
# 416	Treatment	O
# 417	of	O
# 418	Cancer	O
# 419	(	O
# 420	EORTC	O
# 421	)	O
# 422	QLQ-C	O
# 423	30	O
# 424	and	O
# 425	LC	O
# 426	-	O
# 427	13	O
# 428	administered	O
# 429	at	O
# 430	baseline	O
# 431	and	O
# 432	every	O
# 433	6	O
# 434	weeks	O
# 435	thereafter	O
# 436	.	O
# 437	Arm	O
# 438	B	O
# 439	achieved	O
# 440	a	O
# 441	better	O
# 442	score	O
# 443	at	O
# 444	week	O
# 445	6	O
# 446	for	O
# 447	emotional	O
# 448	,	O
# 449	cognitive	O
# 450	and	O
# 451	social	O
# 452	functioning	O
# 453	,	O
# 454	global	O
# 455	health	O
# 456	status	O
# 457	,	O
# 458	fatigue	O
# 459	,	O
# 460	and	O
# 461	appetite	O
# 462	loss	O
# 463	,	O
# 464	which	O
# 465	was	I-Premise
# 466	lost	O
# 467	at	O
# 468	12	O
# 469	weeks	O
# 470	.	O
# 471	In	O
# 472	conclusion	O
# 473	,	O
# 474	arm	O
# 475	B	O
# 476	appears	O
# 477	superior	O
# 478	to	O
# 479	arm	O
# 480	A	O
# 481	with	O
# 482	regard	O
# 483	to	O
# 484	response	O
# 485	rate	O
# 486	,	O
# 487	side	O
# 488	effects	O
# 489	,	O
# 490	and	O
# 491	QoL	O
# 492	.	O
# 493	Although	O
# 494	survival	O
# 495	was	O
# 496	not	O
# 497	improved	I-Premise
# 498	,	I-Premise
# 499	arm	I-Premise
# 500	B	I-Premise
# 501	offers	O
# 502	a	O
# 503	better	O
# 504	palliation	O
# 505	for	O
# 506	advanced	O
# 507	NSCLC	O
# 508	patients	O
# 509	than	O
# 510	arm	O
# 511	A	O
# 512	.	O
#
# (493, 498)	Partial-Attack	(499, 512)
# (437, 470)	Support	(471, 492)
# (380, 394)	Support	(493, 498)
# (347, 379)	Support	(493, 498)
# (313, 346)	Support	(471, 492)
# (219, 243)	Support	(299, 312)
# (244, 298)	Partial-Attack	(299, 312)
# (144, 218)	Partial-Attack	(299, 312)
#
# --------------------------------------------------------------------------------
#
#     num tokens     = 8423
#     num parags     = 72
#     num documents  = 24
