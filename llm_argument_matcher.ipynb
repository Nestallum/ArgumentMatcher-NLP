# %% [markdown]
# # 📂 **Project: Automatic Argumentation Analysis with LLM**
#
# In this notebook, we explore an advanced approach to **argument mining** by leveraging a **Large Language Model (LLM)**. Unlike the other implementation, which relied on a naive argument matcher, we now use a state-of-the-art model to enhance the quality and accuracy of our argumentation analysis.
#
# This approach integrates **transformers** and **pre-trained models** from the [Huggingface Transformers library](https://huggingface.co), bringing the power of cutting-edge NLP techniques to the task of argument mining. The provided code demonstrates how to fine-tune a **Roberta-based model** for **Named Entity Recognition (NER)** tasks, specifically designed for identifying argument components such as claims or premises.
#
# This project showcases a more sophisticated LLM-based solution, offering insights into the integration of **transformers**, **datasets**, and **tokenizers** within a machine learning pipeline. It serves as a stepping stone for exploring more robust and scalable solutions for **argumentation analysis**.
#
# Authors: **Nassim Lattab** and **Mohamed Azzaoui**.
#
# ---

# %% [markdown]
# ### Install Packages and Load Environment Variables
#
# As explained in the notebook, you need to install all the required packages listed in `requirements.txt`. If you have already completed this step, there is no need to run the cell below again.

# %%
# Install all the necessary packages
# %pip install -r requirements.txt

# %% [markdown]
# This cell loads environment variables, and retrieves the Hugging Face API token for authentication.

# %%
# Import necessary libraries
import os
from dotenv import load_dotenv

# Load the .env file from the current directory
load_dotenv()

# Retrieve the Hugging Face token from environment variables
mytoken = os.environ.get('HUGGINGFACEHUB_API_TOKEN')

# Check if the token was successfully loaded
if mytoken:
    print("Token loaded successfully.")
else:
    print("Error: No token found. Make sure it is defined in the .env file.")
# Out:
# Token loaded successfully.

# %% [markdown]
# ### Check CUDA Availability
#
# This cell checks if CUDA (GPU support) is available on the system and prints the name of the GPU if available.

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.5.1+cu118
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3070

# %% [markdown]
# ### Preprocessing data
# This cell preprocesses the data by extracting tokens and tags, also splitting long paragraphs into smaller chunks.

# %%
def build_data(data, tag2idx):
    """
    Prepares the data by extracting tokens and their associated tags.

    Args:
        data (list): List of documents with token dictionaries.
        tag2idx (dict): Mapping of tags to their corresponding indices.
        max_length (int): Maximum number of tokens per chunk.

    Returns:
        tuple: Two lists, one with tokens and the other with tags.
    """
    parags = []
    tags = []

    for doc in data:
        for parag in doc['tokens']:
            # Process the paragraph directly if within the max length
            parag_tokens = [token['str'] for token in parag]
            parag_tags = [tag2idx.get(token['arg']) for token in parag]
            
            parags.append(parag_tokens)
            tags.append(parag_tags)
            
    return parags, tags

# %% [markdown]
# ### Dataset and Data Preparation
# This cell defines utility functions and a custom PyTorch `Dataset` class for handling tokenized data and aligning tags. It also includes padding logic for batching during training.

# %%
from torch.utils.data import Dataset

def align_tags_with_tokens(subtokens, tag_seq):
    """
    Aligns word-level tags with their corresponding subword tokens.
    Args:
        subtokens (list): List of subword tokens.
        tag_seq (list): List of tags corresponding to the original words.
    Returns:
        list: List of tags replicated to match subwords.
    """
    tag_id = 0
    exp_tags = []

    for subtoken in subtokens:
        # Increment tag index for new words (indicated by subword prefix 'Ġ')
        if subtoken.startswith('Ġ'):
            tag_id += 1
        exp_tags.append(tag_seq[tag_id])

    return exp_tags


class NerDataSet(Dataset):
    """
    Custom PyTorch Dataset for NER tasks.
    Wraps token and tag sequences, tokenizes inputs, and handles padding.
    """

    def __init__(self, tokens, tags, tokenizer, pad_tag_id, max_length=512):
        self.xsentences = []
        self.ytags = []

        # Tokenize sentences and align tags
        for sentence, tag_seq in zip(tokens, tags):
            subwords = tokenizer.tokenize(' '.join(sentence))
            exp_tags = align_tags_with_tokens(subwords, tag_seq)
            if(len(subwords) > max_length):
                continue
            self.xsentences.append(tokenizer.convert_tokens_to_ids(subwords))
            self.ytags.append(exp_tags)

        self.pad_tag_id = pad_tag_id
        self.pad_tok_id = tokenizer.pad_token_id
        
    def __len__(self):
        return len(self.xsentences)

    def __getitem__(self, idx):
        return self.xsentences[idx], self.ytags[idx]

    def pad_batch(self, itemlist):
        """
        Pads sequences in a batch to the maximum sequence length.
        Args:
            itemlist (list): List of (tokenized sentence, tag sequence) tuples.
        Returns:
            tuple: Padded token and tag tensors.
        """
        xbatch = [x for x, _ in itemlist]
        ybatch = [y for _, y in itemlist]
        maxseq = max(len(x) for x in xbatch)

        # Pad token and tag sequences to match max length
        xbatch = torch.LongTensor([x + [self.pad_tok_id] * (maxseq - len(x)) for x in xbatch])
        ybatch = torch.LongTensor([y + [self.pad_tag_id] * (maxseq - len(y)) for y in ybatch])

        return xbatch, ybatch

# %% [markdown]
# ### Roberta NER Tagger Model
# This cell defines the `RobertaTagger` class for fine-tuning a pre-trained Roberta model for Named Entity Recognition (NER). It includes training, validation, and prediction functionalities.

# %%
import torch.nn as nn
from transformers import RobertaModel
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau  # Scheduler

class RobertaTagger (nn.Module):
    """
    A NER tagger fine tuning the Roberta model
    """
    def __init__(self,output_vocab_size,output_pad_id):
          super().__init__()
          self.output_pad_id     = output_pad_id
          self.output_vocab_size = output_vocab_size

    def allocate_params(self,device):
          self.llm           = RobertaModel.from_pretrained("FacebookAI/roberta-base",device_map=device)
          self.classifier    = nn.Linear(self.llm.config.hidden_size, self.output_vocab_size,device=device)

    def forward(self,X):
        representations = self.llm(X)
        tag_logits = self.classifier(representations.last_hidden_state)
        return tag_logits


    def __call__(self, X, attention_mask=None, device=None):
        """
        An interface for prediction
        Args:
          X   (tensor) : tokens ids in batches
          attention_mask (tensor, optional): attention mask (batch_size, seq_len).
          device (str) : a compute device
        Returns:
          Y (tensor)   : predicted tags ids in batches with same shape as X
        """
        X = X.to(device)
        if attention_mask is not None:
            attention_mask = attention_mask.to(device)

        logits = self.forward(X)
        Y = torch.argmax(logits, dim=-1)

        return Y


    def fine_tune(self, train_loader, val_loader, device, lr=0.00005, epochs=2, patience=3):
        """
        Fine-tune the model on training data with early stopping and a learning rate scheduler.
        """
        self.allocate_params(device)
        
        cross_entropy = nn.CrossEntropyLoss(ignore_index=self.output_pad_id)
        optimizer     = optim.AdamW(self.parameters(), lr=lr)
        
        # Scheduler to reduce learning rate when validation loss plateaus
        scheduler = ReduceLROnPlateau(optimizer, 'min', patience=1, factor=0.1, verbose=True)

        best_val_loss     = float('inf')  # To track best validation loss
        epochs_no_improve = 0  # To count the number of epochs with no improvement

        for epoch in range(epochs):
            self.train()  # Set model to training mode
            train_loss = 0

            # Training step
            for xbatch, ybatch in train_loader:
                xbatch = xbatch.to(device)
                ybatch = ybatch.to(device)

                tag_logits = self.forward(xbatch)
                batch, seq = ybatch.shape
                loss       = cross_entropy(tag_logits.reshape(batch * seq, -1), ybatch.reshape(batch * seq))

                # Backward pass
                loss.backward()
                train_loss += loss.item()

                # Update and reset gradients
                optimizer.step()
                optimizer.zero_grad()

            # Average training loss for the epoch
            train_loss /= len(train_loader)

            # Validation step
            val_loss = self.validate(val_loader, device, cross_entropy)
            scheduler.step(val_loss)  # Adjust learning rate based on validation loss

            print(f"Epoch {epoch+1}/{epochs}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

            # Early Stopping check
            if val_loss < best_val_loss:
                best_val_loss     = val_loss
                epochs_no_improve = 0  # Reset counter

            else:
                epochs_no_improve += 1

            if epochs_no_improve >= patience:
                print(f"Early stopping triggered after {epoch} epochs")
                break

    def validate(self, val_loader, device, loss_fn):
        """
        Evaluate the model on validation data.
        """
        self.eval()  # Set model to evaluation mode
        val_loss = 0

        with torch.no_grad():
            for xbatch, ybatch in val_loader:
                xbatch = xbatch.to(device)
                ybatch = ybatch.to(device)

                tag_logits = self.forward(xbatch)
                batch, seq = ybatch.shape
                loss       = loss_fn(tag_logits.reshape(batch * seq, -1), ybatch.reshape(batch * seq))
                val_loss += loss.item()

        # Validation loss
        val_loss/= len(val_loader)
        return val_loss

# %% [markdown]
# ### Reconstruct Word-Level Labels
# This function reconstructs word-level labels from subword token predictions, ensuring alignment with the original text.

# %%
def reconstruct_labels(subwords, labels):
    """
    Reconstructs word-level labels from subword labels.
    Args:
        subwords (list): List of subword tokens.
        labels (list): List of predicted labels for subwords.
    Returns:
        list: Reconstructed labels aligned with the original words.
    """
    word_labels = []
    tag_id = 0

    # Handle the first subword if it does not start with 'Ġ' (continuation of a word)
    if(not(subwords[0].startswith('Ġ'))):
        word_labels.append(labels[tag_id])
        tag_id += 1
        subwords = subwords[1:]

    # Process the remaining subwords
    for subword in subwords:
        if(subword.startswith('Ġ')): # Indicates the start of a new word
            word_labels.append(labels[tag_id])
        tag_id += 1

    return word_labels

# %% [markdown]
# ### Predict Labels for Words in Paragraphs
# This function predicts word-level labels for paragraphs by leveraging a trained model and tokenizer. It ensures that the labels align correctly with the original text structure.

# %%
def predict_labels(paragraphs, model, tokenizer, idx2tag, device, max_length=512):
    """
    Predicts the labels for a list of paragraphs (each paragraph is a list of words).
    Handles subword tokenization, processes sequences without truncation, and splits long sequences after encoding.
    Args:
        paragraphs (list of list of str): List of paragraphs, each paragraph is a list of words.
        model (RobertaTagger): Trained model for label prediction.
        tokenizer (AutoTokenizer): Tokenizer used to convert words into tokens.
        idx2tag (dict): Dictionary to map label indices to text labels.
        device (torch.device): Computation device (CPU/GPU).
        max_length (int): Maximum number of tokens allowed per sequence.
    Returns:
        list of list of str: List of actual labels for each word in each paragraph.
    """
    model.eval()
    predictions = []

    for paragraph in paragraphs:
        # Full tokenization without truncation
        encoding = tokenizer.encode_plus(
            ' '.join(paragraph),
            truncation=False,  # No truncation, so we don't lose any data
            padding=True,
            return_tensors="pt",
            return_attention_mask=True
        )

        input_ids = encoding['input_ids'][0]  # Remove batch dimension
        attention_mask = encoding['attention_mask'][0]

        # Split into manageable chunks of max_length
        chunks = [
            (input_ids[i:i + max_length], attention_mask[i:i + max_length])
            for i in range(0, input_ids.size(0), max_length)
        ]

        chunk_predictions = []
        for chunk_input_ids, chunk_attention_mask in chunks:
            # Add batch dimension to the chunks
            chunk_input_ids = chunk_input_ids.unsqueeze(0).to(device)
            chunk_attention_mask = chunk_attention_mask.unsqueeze(0).to(device)

            # Get predictions for the chunk
            with torch.no_grad():
                predicted_indices = model(chunk_input_ids, chunk_attention_mask)

            chunk_predictions.extend(predicted_indices.cpu().tolist()[0])

        # Map predictions back to subwords
        subtokens = tokenizer.convert_ids_to_tokens(input_ids.tolist())
        word_labels_indices = reconstruct_labels(subtokens, chunk_predictions)

        # Convert indices to actual labels
        word_labels = [idx2tag[idx] for idx in word_labels_indices]

        predictions.append(word_labels)

    return predictions


# def predict_labels(paragraphs, model, tokenizer, idx2tag, device):
#     """
#     Predicts the labels for a list of paragraphs (each paragraph is a list of words).
#     Args:
#         paragraphs (list of list of str): List of paragraphs, each paragraph is a list of words.
#         model (RobertaTagger): Trained model for label prediction.
#         tokenizer (AutoTokenizer): Tokenizer used to convert words into tokens.
#         idx2tag (dict): Dictionary to map label indices to text labels.
#         device (torch.device): Computation device (CPU/GPU).
#         max_length (int): Maximum number of tokens allowed.
#     Returns:
#         list of list of str: List of actual labels for each word in each paragraph.
#     """
#     model.eval()
#     predictions = []

#     for paragraph in paragraphs:
#         # Full tokenization with attention mask
#         for paragraph in paragraphs:
#             subwords = tokenizer.tokenize(' '.join(paragraph))
#             print(f"Original tokens: {len(paragraph)}, Subwords: {len(subwords)}")

#         encoding = tokenizer.encode_plus(
#             ' '.join(paragraph),
#             truncation=True,  # Ensure tokenization respects max_length
#             padding=True,
#             return_tensors="pt",
#             return_attention_mask=True
#         )

#         input_ids = encoding['input_ids']
#         print(f"Encoded input IDs length: {input_ids.size(1)}")

#         input_ids      = encoding['input_ids'] # Truncate to max_length
#         attention_mask = encoding['attention_mask']  # Truncate mask to align

#         # Pass through the model
#         with torch.no_grad():
#             predicted_indices = model(input_ids.to(device), attention_mask.to(device))

#         # Convert indices to text labels
#         predicted_labels = [
#             [idx2tag[idx] for idx in seq] for seq in predicted_indices.tolist()
#         ]

#         # Reconstruct labels by word
#         subtokens = tokenizer.convert_ids_to_tokens(input_ids[0].cpu().tolist())
#         word_labels = reconstruct_labels(subtokens, predicted_labels[0])
#         predictions.append(word_labels)
    
#     return predictions

# %% [markdown]
# ### JSON Reconstruction from Predictions
# This cell defines functions to reconstruct a JSON file from model predictions while preserving the original structure of the input data. Predicted BIO labels are processed for each token and used to rebuild spans.

# %%
import json

def create_predictions_json(predictions, test_data, output_filepath):
    """
    Reconstructs a JSON file from model predictions while preserving the original structure.
    Predictions are processed for each token in each paragraph and grouped into their respective documents.
    Args:
        predictions (list): List of predicted BIO labels, flattened across all paragraphs.
        test_data (list): Original test data in JSON format.
        output_filepath (str): Filepath where the reconstructed JSON will be saved.
    Returns:
        None: The JSON file is saved to the specified location.
    """
    # Flatten predictions
    flat_predictions = [label for sublist in predictions for label in sublist]
    pred_index = 0  # Index to track the current position in flat_predictions

    output_data = []

    for doc in test_data:
        # Initialize a new document structure for predictions
        pred_doc = {"tokens": [], "spans": [], "rels": doc["rels"]}  # Keep the original relations

        for paragraph in doc["tokens"]:
            # Reconstruct tokens with predicted BIO labels
            reconstructed_paragraph = []
            bio_labels = []  # Collect BIO labels for span reconstruction
            for token in paragraph:
                # Assign the next predicted label from flat_predictions
                token["arg"] = flat_predictions[pred_index]
                bio_labels.append(flat_predictions[pred_index])
                pred_index += 1
                reconstructed_paragraph.append(token)

            pred_doc["tokens"].append(reconstructed_paragraph)

            # Reconstruct spans based on predicted BIO labels
            spans = reconstruct_spans(reconstructed_paragraph, bio_labels)
            if spans:  # Add spans if any were found
                pred_doc["spans"].extend(spans)

        # Append the reconstructed document to the output data
        output_data.append(pred_doc)

    # Save the reconstructed JSON file to the specified path
    with open(output_filepath, "w") as f:
        json.dump(output_data, f, indent=4)

    print(f"Complete JSON file saved at: {output_filepath}")

def reconstruct_spans(paragraph, bio_labels):
    """
    Reconstruct spans from predicted BIO labels.
    Args:
      paragraph (list): List of tokens in the paragraph.
      bio_labels (list): Predicted BIO labels for the tokens.
    Returns:
      list: A list of reconstructed spans, each represented as a dictionary.
    """
    spans = []
    current_span = None

    for idx, label in enumerate(bio_labels):
        if label.startswith("B-"):
            # If a new span starts, close the previous one (if it exists)
            if current_span:
                spans.append(current_span)
            # Create a new span
            current_span = {
                "name": label[2:],  # Extract the name (e.g., "Claim", "Premise") by removing "B-"
                "start": paragraph[idx]["idx"],  # Start index of the span
                "end": paragraph[idx]["idx"]  # Initialize the end index as the start index
            }
        elif label.startswith("I-") and current_span and current_span["name"] == label[2:]:
            # Extend the current span if it matches the "I-" label
            current_span["end"] = paragraph[idx]["idx"]
        else:
            # Close the current span if the label doesn't match "I-*" or if it's "O"
            if current_span:
                current_span["end"] = paragraph[idx]["idx"]  # Include the first non-I-* or O as the end index
                spans.append(current_span)
                current_span = None

    # Add the last span if it wasn't closed
    if current_span:
        spans.append(current_span)

    return spans

# %% [markdown]
# ### Essay Dataset Pipeline - Data Preparation, Model Initialization, and Training
# This pipeline uses the `aae_*.json datasets`, which focuses on argumentative structures within essays. The model is trained, validated, and tested on this dataset. It demonstrates the model's ability to capture argumentative spans and relationships in natural language texts.
#
# The cell handles the following tasks:
# 1. Load and preprocess training and validation data.
# 2. Initialize the tokenizer and datasets for the essay dataset.
# 3. Set up the model and train it using a fine-tuning process.
# 4. Generate predictions on test data.

# %%
import json
from transformers import AutoTokenizer
import torch
from torch.utils.data import DataLoader
from pathlib import Path

# Define the tag mappings
tag2idx = {"O": 0, "B-Claim": 1, "B-MajorClaim": 2, "B-Premise": 3, "I-Claim": 4, "I-MajorClaim": 5, "I-Premise": 6}
idx2tag = {v: k for k, v in tag2idx.items()}

# Dataset Paths
data_folder = Path("data")
train_file_path = data_folder / "aae_train.json"
validation_file_path = data_folder / "aae_dev.json"
test_file_path = data_folder / "aae_test.json"

# Load training data and preprocess
with open(train_file_path, "r") as f:
    train_data = json.load(f)
sentences, tags = build_data(train_data, tag2idx)

# Load validation data and preprocess
with open(validation_file_path, "r") as f:
    dev_data = json.load(f)
dev_sentences, dev_tags = build_data(dev_data, tag2idx)

# Initialize tokenizer and datasets
tokenizer = AutoTokenizer.from_pretrained("FacebookAI/roberta-base")
train_set = NerDataSet(sentences, tags, tokenizer, len(tag2idx))
dev_set = NerDataSet(dev_sentences, dev_tags, tokenizer, len(tag2idx))

# Set up DataLoaders for batching
dataloader = DataLoader(train_set, batch_size=16, shuffle=True, collate_fn=train_set.pad_batch)
dev_dataloader = DataLoader(dev_set, batch_size=32, shuffle=False, collate_fn=dev_set.pad_batch)

# Set computation device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device used for training: {device}")
if device.type == "cuda":
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")

# Initialize and fine-tune the NER model
ner_model = RobertaTagger(output_vocab_size=len(idx2tag) + 1, output_pad_id=len(idx2tag))
ner_model.fine_tune(dataloader, dev_dataloader, device, epochs=6)

# Load test data and generate predictions
with open(test_file_path, "r") as f:
    test_data = json.load(f)
sentences, _ = build_data(test_data, tag2idx)

predictions = predict_labels(
    paragraphs=sentences,
    model=ner_model,
    tokenizer=tokenizer,
    idx2tag=idx2tag,
    device=device
)
# Out:
# Device used for training: cuda
# GPU Name: NVIDIA GeForce RTX 3070
# Some weights of RobertaModel were not initialized from the model checkpoint at FacebookAI/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/6, Training Loss: 0.9360, Validation Loss: 0.6339
# Epoch 2/6, Training Loss: 0.5372, Validation Loss: 0.5520
# Epoch 3/6, Training Loss: 0.3783, Validation Loss: 0.4908
# Epoch 4/6, Training Loss: 0.2659, Validation Loss: 0.5465
# Epoch 5/6, Training Loss: 0.1656, Validation Loss: 0.5664
# Epoch 6/6, Training Loss: 0.0894, Validation Loss: 0.5445
# Early stopping triggered after 5 epochs

# %% [markdown]
# ### Save Predictions and Evaluate Model
# This cell saves the predicted labels into a JSON file and evaluates the model's performance using a predefined evaluation script.

# %%
create_predictions_json(predictions, test_data, "aae_predictions_llm.json")

# Evaluate the predictions against the test dataset
# !python evaluate.py aae_predictions_llm.json aae_test.json
# Out:
# Complete JSON file saved at: aae_predictions_llm.json
#
#
# ********************** SPANS ***************************
#    STRICT EVALUATION
#     > Argument mining spans (unlabeled)
#       Precision : 0.7450240240218107
#       Recall    : 0.7699594000622003
#       F-score   : 0.7555197241169669
#     > Argument mining spans (labeled)
#       Precision : 0.6678192895858273
#       Recall    : 0.689371945407862
#       F-score   : 0.6768506469467651
#
#     RELAXED EVALUATION (α = 0.5)
#     > Argument mining spans (unlabeled)
#       Precision : 0.777481394508183
#       Recall    : 0.8956024985140908
#       F-score   : 0.8298550531967501
#     > Argument mining spans (labeled)
#       Precision : 0.7013360652167573
#       Recall    : 0.7925492975180652
#       F-score   : 0.7421477442445348
#
#
#
# ******************* RELATIONS ***************************
#    STRICT EVALUATION
#     > Argument mining spans (unlabeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#     > Argument mining spans (labeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#
#     RELAXED EVALUATION (α = 0.5)
#     > Argument mining spans (unlabeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#     > Argument mining spans (labeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0

# %% [markdown]
# ### Medical Dataset Pipeline - Data Preparation, Model Initialization, and Training
# This pipeline works with the `abstrct_*.json` datasets, which focuses on argumentative structures within medical abstracts. Similar to the essay dataset, the model is trained, validated, and tested on this dataset. The medical dataset offers unique challenges due to its domain-specific language and structure, enabling a comprehensive evaluation of the model's generalizability.

# %%
import json
import os
import torch
from torch.utils.data import DataLoader
from transformers import AutoTokenizer
from pathlib import Path

# Define the tag mappings
tag2idx = {"O": 0, "B-Claim": 1, "B-MajorClaim": 2, "B-Premise": 3, "I-Claim": 4, "I-MajorClaim": 5, "I-Premise": 6}
idx2tag = {v: k for k, v in tag2idx.items()}

# Dataset Paths
data_folder = Path("data")
train_file_path = data_folder / "train_data.json"
validation_file_path = data_folder / "validation_data.json"
test_file_path = data_folder / "test_data.json"

# Load training data and preprocess
with open(train_file_path, "r") as f:
    train_data = json.load(f)
sentences, tags = build_data(train_data, tag2idx)

# Load validation data and preprocess
with open(validation_file_path, "r") as f:
    dev_data = json.load(f)
dev_sentences, dev_tags = build_data(dev_data, tag2idx)

# Initialize tokenizer and datasets
tokenizer = AutoTokenizer.from_pretrained("FacebookAI/roberta-base")
train_set = NerDataSet(sentences, tags, tokenizer, len(tag2idx))
dev_set = NerDataSet(dev_sentences, dev_tags, tokenizer, len(tag2idx))

# Set up DataLoaders for batching
dataloader = DataLoader(train_set, batch_size=4, shuffle=True, collate_fn=train_set.pad_batch)
dev_dataloader = DataLoader(dev_set, batch_size=8, shuffle=False, collate_fn=dev_set.pad_batch)

# Set computation device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device used for training: {device}")
if device.type == "cuda":
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")

# Initialize and fine-tune the NER model
ner_model = RobertaTagger(output_vocab_size=len(idx2tag) + 1, output_pad_id=len(idx2tag))
ner_model.fine_tune(dataloader, dev_dataloader, device, epochs=6)


# Load test data and generate predictions
with open(test_file_path, "r") as f:
    test_data = json.load(f)

sentences, _ = build_data(test_data, tag2idx)

predictions = predict_labels(
    paragraphs=sentences,
    model=ner_model,
    tokenizer=tokenizer,
    idx2tag=idx2tag,
    device=device
)

# Nombre total de tokens dans les données d'entrée
total_tokens_input = len([token for tokens in sentences for token in tokens])

# Nombre total de prédictions générées
total_tokens_predicted = sum(len(pred) for pred in predictions)

# Vérification
assert total_tokens_input == total_tokens_predicted, (
    f"Mismatch between input tokens ({total_tokens_input}) "
    f"and predictions ({total_tokens_predicted})!"
)

print(f"Total input tokens: {total_tokens_input}")
print(f"Total predicted tokens: {total_tokens_predicted}")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (755 > 512). Running this sequence through the model will result in indexing errors
# Device used for training: cuda
# GPU Name: NVIDIA GeForce RTX 3070
# Some weights of RobertaModel were not initialized from the model checkpoint at FacebookAI/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/6, Training Loss: 1.0019, Validation Loss: 0.4881
# Epoch 2/6, Training Loss: 0.4935, Validation Loss: 0.2955
# Epoch 3/6, Training Loss: 0.3326, Validation Loss: 0.2864
# Epoch 4/6, Training Loss: 0.2424, Validation Loss: 0.2668
# Epoch 5/6, Training Loss: 0.2117, Validation Loss: 0.4000
# Epoch 6/6, Training Loss: 0.1027, Validation Loss: 0.4090
# Total input tokens: 8423
# Total predicted tokens: 8423

# %% [markdown]
# ### Save Predictions and Evaluate Model

# %%
create_predictions_json(predictions, test_data, "abstrct_neoplasm_predictions_llm.json")
# !python view_data.py abstrct_neoplasm_predictions_llm.json
# Out:
# Complete JSON file saved at: abstrct_neoplasm_predictions_llm.json
# 0	Imatinib	O
# 1	(	I-MajorClaim
# 2	Gleevec	I-MajorClaim
# 3	)	I-MajorClaim
# 4	,	I-MajorClaim
# 5	a	I-MajorClaim
# 6	highly	I-MajorClaim
# 7	effective	I-MajorClaim
# 8	specific	I-MajorClaim
# 9	tyrosine	I-MajorClaim
# 10	kinase	I-MajorClaim
# 11	inhibitor	I-MajorClaim
# 12	,	I-MajorClaim
# 13	demonstrates	I-MajorClaim
# 14	a	I-MajorClaim
# 15	better	I-MajorClaim
# 16	side	I-MajorClaim
# 17	effect	I-MajorClaim
# 18	profile	I-MajorClaim
# 19	than	I-MajorClaim
# 20	interferon-alpha	I-MajorClaim
# 21	(	I-MajorClaim
# 22	IFN	I-MajorClaim
# 23	)	I-MajorClaim
# 24	,	I-MajorClaim
# 25	which	I-MajorClaim
# 26	impairs	I-MajorClaim
# 27	patients	I-MajorClaim
# 28	'	I-MajorClaim
# 29	quality	I-MajorClaim
# 30	of	I-MajorClaim
# 31	life	I-MajorClaim
# 32	(	I-MajorClaim
# 33	QoL	I-MajorClaim
# 34	)	I-MajorClaim
# 35	.	O
# 36	This	O
# 37	phase	O
# 38	III	O
# 39	international	O
# 40	study	O
# 41	evaluated	O
# 42	QoL	O
# 43	outcomes	O
# 44	in	O
# 45	1,106	O
# 46	newly	O
# 47	diagnosed	O
# 48	patients	O
# 49	with	O
# 50	chronic-phase	O
# 51	chronic	O
# 52	myeloid	O
# 53	leukemia	O
# 54	(	O
# 55	CML	O
# 56	)	O
# 57	who	O
# 58	were	O
# 59	randomized	O
# 60	to	O
# 61	receive	O
# 62	either	O
# 63	imatinib	O
# 64	400	O
# 65	mg	O
# 66	daily	O
# 67	or	O
# 68	IFN	O
# 69	up	O
# 70	to	O
# 71	5	O
# 72	MU	O
# 73	/	O
# 74	m	O
# 75	(	O
# 76	2	O
# 77	)	O
# 78	/	O
# 79	d	O
# 80	with	O
# 81	cytarabine	O
# 82	(	O
# 83	Ara-C	O
# 84	)	O
# 85	20	O
# 86	mg	O
# 87	/	O
# 88	m	O
# 89	(	O
# 90	2	O
# 91	)	O
# 92	/	O
# 93	d	O
# 94	added	O
# 95	for	O
# 96	10	O
# 97	days	O
# 98	every	O
# 99	month	O
# 100	(	O
# 101	IFN	O
# 102	+	O
# 103	LDAC	O
# 104	)	O
# 105	.	O
# 106	Crossover	O
# 107	to	O
# 108	the	O
# 109	other	O
# 110	treatment	O
# 111	arm	O
# 112	was	O
# 113	permitted	O
# 114	due	O
# 115	to	O
# 116	a	O
# 117	lack	O
# 118	of	O
# 119	efficacy	O
# 120	or	O
# 121	treatment	O
# 122	intolerance	O
# 123	.	O
# 124	QoL	O
# 125	was	O
# 126	assessed	O
# 127	with	O
# 128	the	O
# 129	Functional	O
# 130	Assessment	O
# 131	of	O
# 132	Cancer	O
# 133	Therapy-Biologic	O
# 134	Response	O
# 135	Modifiers	O
# 136	(	O
# 137	FACT-BRM	O
# 138	)	O
# 139	at	O
# 140	baseline	O
# 141	,	O
# 142	monthly	O
# 143	for	O
# 144	6	O
# 145	months	O
# 146	and	O
# 147	then	O
# 148	at	O
# 149	months	O
# 150	9	O
# 151	,	O
# 152	12	O
# 153	,	O
# 154	and	O
# 155	18	O
# 156	.	O
# 157	The	O
# 158	Trial	O
# 159	Outcome	O
# 160	Index	O
# 161	(	O
# 162	TOI	O
# 163	;	O
# 164	a	O
# 165	composite	O
# 166	endpoint	O
# 167	of	O
# 168	physical	O
# 169	/	O
# 170	functional	O
# 171	/	O
# 172	treatment-specific	O
# 173	subscales	O
# 174	)	O
# 175	was	O
# 176	the	O
# 177	primary	O
# 178	endpoint	O
# 179	.	O
# 180	Secondary	O
# 181	endpoints	O
# 182	measured	O
# 183	were	O
# 184	social	O
# 185	/	O
# 186	family	O
# 187	well-being	O
# 188	(	O
# 189	SFWB	O
# 190	)	O
# 191	and	O
# 192	emotional	O
# 193	well-being	O
# 194	(	O
# 195	EWB	O
# 196	)	O
# 197	.	O
# 198	QoL	O
# 199	was	O
# 200	analyzed	O
# 201	for	O
# 202	the	O
# 203	first	O
# 204	18	O
# 205	months	O
# 206	of	O
# 207	treatment	O
# 208	using	O
# 209	mixed	O
# 210	effects	O
# 211	growth	O
# 212	curve	O
# 213	models	O
# 214	.	O
# 215	The	O
# 216	primary	O
# 217	analyses	O
# 218	were	O
# 219	intention-to-treat	O
# 220	(	O
# 221	ITT	O
# 222	);	O
# 223	secondary	O
# 224	analyses	O
# 225	incorporated	O
# 226	crossover	O
# 227	as	O
# 228	a	O
# 229	time-dependent	O
# 230	covariate	O
# 231	.	O
# 232	A	O
# 233	total	O
# 234	of	O
# 235	1,049	O
# 236	patients	O
# 237	completed	O
# 238	at	O
# 239	least	O
# 240	one	O
# 241	QoL	O
# 242	assessment	O
# 243	.	O
# 244	Two	B-Premise
# 245	hundred	O
# 246	sixty-one	O
# 247	patients	O
# 248	(	O
# 249	50	O
# 250	%	O
# 251	)	O
# 252	crossed	O
# 253	over	O
# 254	from	O
# 255	IFN	O
# 256	to	O
# 257	imatinib	O
# 258	and	O
# 259	11	O
# 260	(	O
# 261	2	O
# 262	%	I-Premise
# 263	)	I-Premise
# 264	crossed	I-Premise
# 265	over	I-Premise
# 266	from	I-Premise
# 267	imatinib	I-Premise
# 268	to	I-Premise
# 269	IFN	I-Premise
# 270	.	O
# 271	There	B-Premise
# 272	was	I-Premise
# 273	a	I-Premise
# 274	significant	I-Premise
# 275	decline	I-Premise
# 276	in	I-Premise
# 277	TOI	I-Premise
# 278	scores	I-Premise
# 279	for	I-Premise
# 280	the	I-Premise
# 281	IFN	I-Premise
# 282	treatment	I-Premise
# 283	arm	I-Premise
# 284	compared	I-Premise
# 285	with	I-Premise
# 286	preservation	I-Premise
# 287	of	I-Premise
# 288	baseline	I-Premise
# 289	TOI	I-Premise
# 290	scores	I-Premise
# 291	in	I-Premise
# 292	the	I-Premise
# 293	imatinib	I-Premise
# 294	arm	I-Premise
# 295	(	I-Premise
# 296	P	I-Premise
# 297	<	I-Premise
# 298	.	I-Premise
# 299	001	I-Premise
# 300	,	I-Premise
# 301	ITT	I-Premise
# 302	)	I-Premise
# 303	.	O
# 304	Mean	B-Premise
# 305	social	I-Premise
# 306	/	I-Premise
# 307	family	I-Premise
# 308	and	I-Premise
# 309	EWB	I-Premise
# 310	scores	I-Premise
# 311	were	I-Premise
# 312	22.8	I-Premise
# 313	and	I-Premise
# 314	19.5	I-Premise
# 315	,	I-Premise
# 316	respectively	I-Premise
# 317	,	I-Premise
# 318	for	I-Premise
# 319	imatinib	I-Premise
# 320	and	I-Premise
# 321	21.6	I-Premise
# 322	and	I-Premise
# 323	17.6	I-Premise
# 324	,	I-Premise
# 325	respectively	I-Premise
# 326	,	I-Premise
# 327	for	I-Premise
# 328	IFN	I-Premise
# 329	(	I-Premise
# 330	P	I-Premise
# 331	<	I-Premise
# 332	.	I-Premise
# 333	001	I-Premise
# 334	,	I-Premise
# 335	ITT	I-Premise
# 336	)	I-Premise
# 337	.	O
# 338	After	B-Premise
# 339	crossing	I-Premise
# 340	over	I-Premise
# 341	from	I-Premise
# 342	IFN	I-Premise
# 343	to	I-Premise
# 344	imatinib	I-Premise
# 345	,	I-Premise
# 346	patients	I-Premise
# 347	experienced	I-Premise
# 348	a	I-Premise
# 349	significant	I-Premise
# 350	(	I-Premise
# 351	P	I-Premise
# 352	<	I-Premise
# 353	.	I-Premise
# 354	001	I-Premise
# 355	)	I-Premise
# 356	increase	I-Premise
# 357	in	I-Premise
# 358	TOI	I-Premise
# 359	scores	I-Premise
# 360	.	O
# 361	Imatinib	B-Claim
# 362	offers	I-Claim
# 363	clear	I-Claim
# 364	QoL	I-Claim
# 365	advantages	I-Claim
# 366	over	I-Claim
# 367	IFN	I-Claim
# 368	as	I-Claim
# 369	first-line	I-Claim
# 370	treatment	I-Claim
# 371	of	I-Claim
# 372	chronic-phase	I-Claim
# 373	CML	I-Claim
# 374	.	O
# 375	In	B-Claim
# 376	addition	O
# 377	,	O
# 378	patients	I-Claim
# 379	who	I-Claim
# 380	crossed	I-Claim
# 381	over	I-Claim
# 382	to	I-Claim
# 383	imatinib	I-Claim
# 384	reported	I-Claim
# 385	higher	I-Claim
# 386	QoL	I-Claim
# 387	than	I-Claim
# 388	those	I-Claim
# 389	who	O
# 390	remained	O
# 391	on	O
# 392	IFN	O
# 393	.	O
#
# (338, 360)	Support	(378, 393)
# (304, 337)	Support	(361, 374)
# (271, 303)	Support	(361, 374)
#
# 0	The	O
# 1	standard	O
# 2	treatment	O
# 3	for	O
# 4	patients	O
# 5	with	O
# 6	clinically	O
# 7	resectable	O
# 8	rectal	O
# 9	cancer	O
# 10	is	O
# 11	surgery	O
# 12	.	O
# 13	Postoperative	O
# 14	radiochemotherapy	O
# 15	(	O
# 16	RCT	O
# 17	)	O
# 18	is	O
# 19	recommended	O
# 20	for	O
# 21	advanced	O
# 22	disease	O
# 23	(	O
# 24	pT3	O
# 25	/	O
# 26	4	O
# 27	or	O
# 28	pN	O
# 29	+	O
# 30	)	O
# 31	.	O
# 32	In	O
# 33	recent	O
# 34	years	O
# 35	,	O
# 36	encouraging	O
# 37	results	O
# 38	of	O
# 39	pre-operative	O
# 40	radiotherapy	O
# 41	have	O
# 42	been	O
# 43	reported	O
# 44	.	O
# 45	This	O
# 46	prospective	O
# 47	randomized	O
# 48	phase-III-trial	O
# 49	(	O
# 50	CAO	O
# 51	/	O
# 52	ARO	O
# 53	/	O
# 54	AIO	O
# 55	-	O
# 56	94	O
# 57	)	O
# 58	compares	O
# 59	the	O
# 60	efficacy	O
# 61	of	O
# 62	neoadjuvant	O
# 63	RCT	O
# 64	to	O
# 65	standard	O
# 66	postoperative	O
# 67	RCT	O
# 68	.	O
# 69	We	O
# 70	report	O
# 71	on	O
# 72	the	O
# 73	design	O
# 74	of	O
# 75	the	O
# 76	study	O
# 77	and	O
# 78	first	O
# 79	results	O
# 80	with	O
# 81	regard	O
# 82	to	O
# 83	toxicity	O
# 84	of	O
# 85	RCT	O
# 86	and	O
# 87	postoperative	O
# 88	morbidity	O
# 89	.	O
# 90	Patients	O
# 91	with	O
# 92	locally	O
# 93	advanced	O
# 94	operable	O
# 95	rectal	O
# 96	cancer	O
# 97	(	O
# 98	uT3	O
# 99	/	O
# 100	4	O
# 101	or	O
# 102	uN	O
# 103	+	O
# 104	,	O
# 105	Mason	O
# 106	CS	O
# 107	III	O
# 108	/	O
# 109	IV	O
# 110	)	O
# 111	were	O
# 112	randomly	O
# 113	assigned	O
# 114	to	O
# 115	pre	O
# 116	or	O
# 117	postoperative	O
# 118	RCT	O
# 119	:	O
# 120	A	O
# 121	total	O
# 122	dose	O
# 123	of	O
# 124	50.4	O
# 125	Gy	O
# 126	(	O
# 127	single	O
# 128	dose	O
# 129	1.8	O
# 130	Gy	O
# 131	)	O
# 132	was	O
# 133	applied	O
# 134	to	O
# 135	the	O
# 136	tumour	O
# 137	and	O
# 138	the	O
# 139	pelvic	O
# 140	lymph	O
# 141	nodes	O
# 142	.	O
# 143	5	O
# 144	-	O
# 145	FU	O
# 146	(	O
# 147	1000	O
# 148	mg	O
# 149	/	O
# 150	m2	O
# 151	/	O
# 152	d	O
# 153	)	O
# 154	was	O
# 155	administered	O
# 156	concomitantly	O
# 157	in	O
# 158	the	O
# 159	1th	O
# 160	and	O
# 161	5th	O
# 162	week	O
# 163	of	O
# 164	radiation	O
# 165	as	O
# 166	120	O
# 167	h-continuous	O
# 168	infusion	O
# 169	.	O
# 170	Four	O
# 171	additional	O
# 172	cycles	O
# 173	of	O
# 174	5	O
# 175	-	O
# 176	FU-chemotherapy	O
# 177	(	O
# 178	500	O
# 179	mg	O
# 180	/	O
# 181	m2	O
# 182	/	O
# 183	d	O
# 184	,	O
# 185	i	O
# 186	.	O
# 187	v	O
# 188	.	O
# 189	-	O
# 190	bolus	O
# 191	)	O
# 192	were	O
# 193	applied	O
# 194	.	O
# 195	RCT	B-Premise
# 196	was	I-Premise
# 197	identical	I-Premise
# 198	in	I-Premise
# 199	both	I-Premise
# 200	arms	I-Premise
# 201	except	I-Premise
# 202	for	I-Premise
# 203	a	I-Premise
# 204	small-volume	I-Premise
# 205	boost	I-Premise
# 206	of	I-Premise
# 207	5.4	I-Premise
# 208	Gy	I-Premise
# 209	postoperatively	I-Premise
# 210	.	O
# 211	The	O
# 212	time	O
# 213	interval	I-Premise
# 214	between	I-Premise
# 215	RCT	I-Premise
# 216	and	I-Premise
# 217	surgery	I-Premise
# 218	was	I-Premise
# 219	4-6	I-Premise
# 220	weeks	I-Premise
# 221	in	I-Premise
# 222	both	I-Premise
# 223	arms	I-Premise
# 224	.	O
# 225	Techniques	O
# 226	of	O
# 227	surgery	O
# 228	were	O
# 229	standardized	O
# 230	and	O
# 231	included	O
# 232	total	O
# 233	mesorectal	O
# 234	excision	O
# 235	.	O
# 236	Primary	O
# 237	endpoints	O
# 238	of	O
# 239	the	O
# 240	study	O
# 241	are	O
# 242	5	O
# 243	-	O
# 244	year	O
# 245	survival	O
# 246	and	O
# 247	local	O
# 248	and	O
# 249	distant	O
# 250	control	O
# 251	.	O
# 252	Secondary	O
# 253	endpoints	O
# 254	include	O
# 255	the	O
# 256	rate	O
# 257	of	O
# 258	curative	O
# 259	(	O
# 260	R0	O
# 261	)	O
# 262	resection	O
# 263	and	O
# 264	sphincter	O
# 265	saving	O
# 266	procedures	O
# 267	,	O
# 268	toxicity	O
# 269	of	O
# 270	RCT	O
# 271	,	O
# 272	surgical	O
# 273	complications	O
# 274	and	O
# 275	quality	O
# 276	of	O
# 277	life	O
# 278	.	O
# 279	As	O
# 280	of	O
# 281	July	O
# 282	2002	O
# 283	,	O
# 284	805	O
# 285	patients	O
# 286	were	O
# 287	randomized	O
# 288	from	O
# 289	26	O
# 290	participating	O
# 291	institutions	O
# 292	.	O
# 293	Acute	B-Premise
# 294	toxicity	I-Premise
# 295	(	I-Premise
# 296	WHO	I-Premise
# 297	)	I-Premise
# 298	of	I-Premise
# 299	RCT	I-Premise
# 300	was	I-Premise
# 301	low	I-Premise
# 302	,	I-Premise
# 303	with	I-Premise
# 304	less	I-Premise
# 305	than	I-Premise
# 306	15	I-Premise
# 307	%	I-Premise
# 308	of	I-Premise
# 309	patients	I-Premise
# 310	experiencing	I-Premise
# 311	grade	I-Premise
# 312	3	I-Premise
# 313	or	I-Premise
# 314	higher	I-Premise
# 315	toxicity	I-Premise
# 316	:	O
# 317	The	B-Premise
# 318	principal	I-Premise
# 319	toxicity	I-Premise
# 320	was	I-Premise
# 321	diarrhea	I-Premise
# 322	,	I-Premise
# 323	with	I-Premise
# 324	12	I-Premise
# 325	%	I-Premise
# 326	in	I-Premise
# 327	the	I-Premise
# 328	postoperative	I-Premise
# 329	RCT-arm	I-Premise
# 330	and	I-Premise
# 331	11	I-Premise
# 332	%	I-Premise
# 333	in	I-Premise
# 334	the	I-Premise
# 335	pre-operative	I-Premise
# 336	RCT-arm	I-Premise
# 337	having	I-Premise
# 338	grade	I-Premise
# 339	3	I-Premise
# 340	-	I-Premise
# 341	,	I-Premise
# 342	and	I-Premise
# 343	1	I-Premise
# 344	%	I-Premise
# 345	in	I-Premise
# 346	either	I-Premise
# 347	arm	I-Premise
# 348	having	I-Premise
# 349	grade	I-Premise
# 350	4	I-Premise
# 351	-	I-Premise
# 352	diarrhea	I-Premise
# 353	.	O
# 354	Erythema	B-Premise
# 355	,	I-Premise
# 356	nausea	I-Premise
# 357	and	I-Premise
# 358	leukopenia	I-Premise
# 359	were	I-Premise
# 360	the	I-Premise
# 361	next	I-Premise
# 362	common	I-Premise
# 363	toxicities	I-Premise
# 364	,	I-Premise
# 365	with	I-Premise
# 366	less	I-Premise
# 367	than	I-Premise
# 368	3	I-Premise
# 369	%	I-Premise
# 370	of	I-Premise
# 371	patients	I-Premise
# 372	in	I-Premise
# 373	either	I-Premise
# 374	arm	I-Premise
# 375	suffering	I-Premise
# 376	grade	I-Premise
# 377	3	I-Premise
# 378	or	I-Premise
# 379	greater	I-Premise
# 380	leukopenia	I-Premise
# 381	or	I-Premise
# 382	nausea	I-Premise
# 383	.	O
# 384	Postoperative	B-Premise
# 385	complication	I-Premise
# 386	rates	I-Premise
# 387	were	I-Premise
# 388	similar	I-Premise
# 389	in	I-Premise
# 390	both	I-Premise
# 391	arms	I-Premise
# 392	,	I-Premise
# 393	with	I-Premise
# 394	12	I-Premise
# 395	%	I-Premise
# 396	(	I-Premise
# 397	postop	I-Premise
# 398	.	I-Premise
# 399	RCT	I-Premise
# 400	)	I-Premise
# 401	and	I-Premise
# 402	12	I-Premise
# 403	%	I-Premise
# 404	(	I-Premise
# 405	pre-op	O
# 406	.	O
# 407	RCT	I-Premise
# 408	)	I-Premise
# 409	of	I-Premise
# 410	patients	I-Premise
# 411	,	I-Premise
# 412	respectively	I-Premise
# 413	,	I-Premise
# 414	suffering	I-Premise
# 415	from	I-Premise
# 416	anastomotic	I-Premise
# 417	leakage	I-Premise
# 418	,	I-Premise
# 419	3	I-Premise
# 420	%	I-Premise
# 421	(	I-Premise
# 422	postop	I-Premise
# 423	.	O
# 424	RCT	I-Premise
# 425	)	I-Premise
# 426	and	I-Premise
# 427	3	I-Premise
# 428	%	I-Premise
# 429	(	I-Premise
# 430	pre-op	I-Premise
# 431	.	O
# 432	RCT	I-Premise
# 433	)	I-Premise
# 434	from	I-Premise
# 435	postoperative	I-Premise
# 436	bleeding	I-Premise
# 437	,	I-Premise
# 438	and	I-Premise
# 439	6	I-Premise
# 440	%	I-Premise
# 441	(	I-Premise
# 442	postop	I-Premise
# 443	.	O
# 444	RCT	I-Premise
# 445	)	I-Premise
# 446	and	I-Premise
# 447	4	I-Premise
# 448	%	I-Premise
# 449	(	I-Premise
# 450	pre-op	I-Premise
# 451	.	O
# 452	RCT	I-Premise
# 453	)	I-Premise
# 454	from	I-Premise
# 455	delayed	I-Premise
# 456	wound	O
# 457	healing	I-Premise
# 458	.	O
# 459	The	B-Claim
# 460	patient	O
# 461	accrual	I-Claim
# 462	to	I-Claim
# 463	the	I-Claim
# 464	trial	I-Claim
# 465	is	I-Claim
# 466	satisfactory	I-Claim
# 467	.	O
# 468	Neoadjuvant	B-Claim
# 469	RCT	I-Claim
# 470	is	I-Claim
# 471	well	I-Claim
# 472	tolerated	I-Claim
# 473	and	I-Claim
# 474	bears	I-Claim
# 475	no	I-Claim
# 476	higher	I-Claim
# 477	risk	I-Claim
# 478	for	I-Claim
# 479	postoperative	I-Claim
# 480	morbidity	I-Claim
# 481	.	O
#
# (293, 316)	Support	(468, 481)
# (317, 353)	Support	(468, 481)
# (354, 383)	Support	(468, 481)
# (384, 458)	Support	(468, 481)
#
# 0	Research	O
# 1	suggests	I-MajorClaim
# 2	that	I-MajorClaim
# 3	stress-reduction	I-Claim
# 4	programs	I-Claim
# 5	tailored	I-Claim
# 6	to	I-Claim
# 7	the	I-Claim
# 8	cancer	I-Claim
# 9	setting	I-Claim
# 10	help	I-Claim
# 11	patients	I-Claim
# 12	cope	I-Claim
# 13	with	I-Claim
# 14	the	I-Claim
# 15	effects	I-Claim
# 16	of	I-Claim
# 17	treatment	I-Claim
# 18	and	I-Claim
# 19	improve	I-Claim
# 20	their	I-Claim
# 21	quality	I-Claim
# 22	of	I-Claim
# 23	life	I-Claim
# 24	.	O
# 25	Yoga	O
# 26	,	O
# 27	an	O
# 28	ancient	O
# 29	Eastern	O
# 30	science	O
# 31	,	O
# 32	incorporates	O
# 33	stress-reduction	O
# 34	techniques	O
# 35	that	O
# 36	include	O
# 37	regulated	O
# 38	breathing	O
# 39	,	O
# 40	visual	O
# 41	imagery	O
# 42	,	O
# 43	and	O
# 44	meditation	O
# 45	as	O
# 46	well	O
# 47	as	O
# 48	various	O
# 49	postures	O
# 50	.	O
# 51	The	O
# 52	authors	O
# 53	examined	O
# 54	the	O
# 55	effects	O
# 56	of	O
# 57	the	O
# 58	Tibetan	O
# 59	yoga	O
# 60	(	O
# 61	TY	O
# 62	)	O
# 63	practices	O
# 64	of	O
# 65	Tsa	O
# 66	lung	O
# 67	and	O
# 68	Trul	O
# 69	khor	O
# 70	,	O
# 71	which	O
# 72	incorporate	O
# 73	controlled	O
# 74	breathing	O
# 75	and	O
# 76	visualization	O
# 77	,	O
# 78	mindfulness	O
# 79	techniques	O
# 80	,	O
# 81	and	O
# 82	low-impact	O
# 83	postures	O
# 84	in	O
# 85	patients	O
# 86	with	O
# 87	lymphoma	O
# 88	.	O
# 89	Thirty-nine	O
# 90	patients	O
# 91	with	O
# 92	lymphoma	O
# 93	who	O
# 94	were	O
# 95	undergoing	O
# 96	treatment	O
# 97	or	O
# 98	who	O
# 99	had	O
# 100	concluded	O
# 101	treatment	O
# 102	within	O
# 103	the	O
# 104	past	O
# 105	12	O
# 106	months	O
# 107	were	O
# 108	assigned	O
# 109	to	O
# 110	a	O
# 111	TY	O
# 112	group	O
# 113	or	O
# 114	to	O
# 115	a	O
# 116	wait-list	O
# 117	control	O
# 118	group	O
# 119	.	O
# 120	Patients	O
# 121	in	O
# 122	the	O
# 123	TY	O
# 124	group	O
# 125	participated	O
# 126	in	O
# 127	7	O
# 128	weekly	O
# 129	yoga	O
# 130	sessions	O
# 131	,	O
# 132	and	O
# 133	patients	O
# 134	in	O
# 135	the	O
# 136	wait-list	O
# 137	control	O
# 138	group	O
# 139	were	O
# 140	free	O
# 141	to	O
# 142	participate	O
# 143	in	O
# 144	the	O
# 145	TY	O
# 146	program	O
# 147	after	O
# 148	the	O
# 149	3	O
# 150	-	O
# 151	month	O
# 152	follow-up	O
# 153	assessment	O
# 154	.	O
# 155	Eighty	B-Premise
# 156	nine	O
# 157	percent	O
# 158	of	O
# 159	TY	O
# 160	participants	O
# 161	completed	O
# 162	at	O
# 163	least	O
# 164	2-3	O
# 165	three	O
# 166	yoga	O
# 167	sessions	O
# 168	,	O
# 169	and	O
# 170	58	O
# 171	%	O
# 172	completed	O
# 173	at	O
# 174	least	O
# 175	5	O
# 176	sessions	O
# 177	.	O
# 178	Patients	B-Premise
# 179	in	I-Premise
# 180	the	I-Premise
# 181	TY	I-Premise
# 182	group	I-Premise
# 183	reported	I-Premise
# 184	significantly	I-Premise
# 185	lower	I-Premise
# 186	sleep	I-Premise
# 187	disturbance	I-Premise
# 188	scores	I-Premise
# 189	during	I-Premise
# 190	follow-up	I-Premise
# 191	compared	I-Premise
# 192	with	I-Premise
# 193	patients	I-Premise
# 194	in	I-Premise
# 195	the	I-Premise
# 196	wait-list	I-Premise
# 197	control	I-Premise
# 198	group	I-Premise
# 199	(	I-Premise
# 200	5.8	I-Premise
# 201	vs	I-Premise
# 202	.	I-Premise
# 203	8.1	I-Premise
# 204	;	I-Premise
# 205	P	I-Premise
# 206	<	I-Premise
# 207	0.004	I-Premise
# 208	)	I-Premise
# 209	.	O
# 210	This	B-Premise
# 211	included	I-Premise
# 212	better	I-Premise
# 213	subjective	I-Premise
# 214	sleep	I-Premise
# 215	quality	I-Premise
# 216	(	I-Premise
# 217	P	I-Premise
# 218	<	I-Premise
# 219	0.02	I-Premise
# 220	)	I-Premise
# 221	,	I-Premise
# 222	faster	I-Premise
# 223	sleep	I-Premise
# 224	latency	I-Premise
# 225	(	I-Premise
# 226	P	I-Premise
# 227	<	I-Premise
# 228	0.01	I-Premise
# 229	)	I-Premise
# 230	,	I-Premise
# 231	longer	I-Premise
# 232	sleep	I-Premise
# 233	duration	I-Premise
# 234	(	I-Premise
# 235	P	I-Premise
# 236	<	I-Premise
# 237	0.03	I-Premise
# 238	)	I-Premise
# 239	,	I-Premise
# 240	and	I-Premise
# 241	less	I-Premise
# 242	use	I-Premise
# 243	of	I-Premise
# 244	sleep	I-Premise
# 245	medications	I-Premise
# 246	(	I-Premise
# 247	P	I-Premise
# 248	<	I-Premise
# 249	0.02	I-Premise
# 250	)	I-Premise
# 251	.	O
# 252	There	B-Premise
# 253	were	I-Premise
# 254	no	I-Premise
# 255	significant	I-Premise
# 256	differences	I-Premise
# 257	between	I-Premise
# 258	groups	I-Premise
# 259	in	I-Premise
# 260	terms	I-Premise
# 261	of	I-Premise
# 262	intrusion	I-Premise
# 263	or	I-Premise
# 264	avoidance	I-Premise
# 265	,	I-Premise
# 266	state	I-Premise
# 267	anxiety	I-Premise
# 268	,	I-Premise
# 269	depression	I-Premise
# 270	,	I-Premise
# 271	or	I-Premise
# 272	fatigue	I-Premise
# 273	.	O
# 274	The	B-Claim
# 275	participation	I-Claim
# 276	rates	I-Claim
# 277	suggested	I-Claim
# 278	that	I-Claim
# 279	a	I-Claim
# 280	TY	I-Claim
# 281	program	I-Claim
# 282	is	I-Claim
# 283	feasible	I-Claim
# 284	for	I-Claim
# 285	patients	I-Claim
# 286	with	I-Claim
# 287	cancer	I-Claim
# 288	and	I-Claim
# 289	that	I-Claim
# 290	such	I-Claim
# 291	a	I-Claim
# 292	program	I-Claim
# 293	significantly	I-Claim
# 294	improves	I-Claim
# 295	sleep-related	I-Claim
# 296	outcomes	I-Claim
# 297	.	O
# 298	However	B-Premise
# 299	,	O
# 300	there	B-Premise
# 301	were	I-Premise
# 302	no	I-Premise
# 303	significant	I-Premise
# 304	differences	I-Premise
# 305	between	I-Premise
# 306	groups	I-Premise
# 307	for	I-Premise
# 308	the	I-Premise
# 309	other	I-Premise
# 310	outcomes	I-Premise
# 311	.	O
#
# (252, 273)	Support	(298, 311)
# (210, 251)	Support	(274, 297)
# (178, 209)	Support	(274, 297)
#
# 0	Malnutrition	O
# 1	occurs	I-MajorClaim
# 2	frequently	I-MajorClaim
# 3	in	I-MajorClaim
# 4	patients	I-MajorClaim
# 5	with	I-MajorClaim
# 6	cancer	I-MajorClaim
# 7	of	I-MajorClaim
# 8	the	I-MajorClaim
# 9	gastrointestinal	I-MajorClaim
# 10	(	I-MajorClaim
# 11	GI	I-MajorClaim
# 12	)	I-MajorClaim
# 13	or	I-MajorClaim
# 14	head	I-MajorClaim
# 15	and	I-MajorClaim
# 16	neck	I-MajorClaim
# 17	area	I-MajorClaim
# 18	and	I-MajorClaim
# 19	can	I-MajorClaim
# 20	lead	I-MajorClaim
# 21	to	I-MajorClaim
# 22	negative	I-MajorClaim
# 23	outcomes	I-MajorClaim
# 24	.	O
# 25	The	O
# 26	aim	O
# 27	of	O
# 28	this	O
# 29	study	O
# 30	is	O
# 31	to	O
# 32	determine	O
# 33	the	O
# 34	impact	O
# 35	of	O
# 36	early	O
# 37	and	O
# 38	intensive	O
# 39	nutrition	O
# 40	intervention	O
# 41	(	O
# 42	NI	O
# 43	)	O
# 44	on	O
# 45	body	O
# 46	weight	O
# 47	,	O
# 48	body	O
# 49	composition	O
# 50	,	O
# 51	nutritional	O
# 52	status	O
# 53	,	O
# 54	global	O
# 55	quality	O
# 56	of	O
# 57	life	O
# 58	(	O
# 59	QoL	O
# 60	)	O
# 61	and	O
# 62	physical	O
# 63	function	O
# 64	compared	O
# 65	to	O
# 66	usual	O
# 67	practice	O
# 68	in	O
# 69	oncology	O
# 70	outpatients	O
# 71	receiving	O
# 72	radiotherapy	O
# 73	to	O
# 74	the	O
# 75	GI	O
# 76	or	O
# 77	head	O
# 78	and	O
# 79	neck	O
# 80	area	O
# 81	.	O
# 82	Outpatients	O
# 83	commencing	O
# 84	at	O
# 85	least	O
# 86	20	O
# 87	fractions	O
# 88	of	O
# 89	radiotherapy	O
# 90	to	O
# 91	the	O
# 92	GI	O
# 93	or	O
# 94	head	O
# 95	and	O
# 96	neck	O
# 97	area	O
# 98	were	O
# 99	randomised	O
# 100	to	O
# 101	receive	O
# 102	intensive	O
# 103	,	O
# 104	individualised	O
# 105	nutrition	O
# 106	counselling	O
# 107	by	O
# 108	a	O
# 109	dietitian	O
# 110	using	O
# 111	a	O
# 112	standard	O
# 113	protocol	O
# 114	and	O
# 115	oral	O
# 116	supplements	O
# 117	if	O
# 118	required	O
# 119	,	O
# 120	or	O
# 121	the	O
# 122	usual	O
# 123	practice	O
# 124	of	O
# 125	the	O
# 126	centre	O
# 127	(	O
# 128	general	O
# 129	advice	O
# 130	and	O
# 131	nutrition	O
# 132	booklet	O
# 133	)	O
# 134	.	O
# 135	Outcome	O
# 136	parameters	O
# 137	were	O
# 138	measured	O
# 139	at	O
# 140	baseline	O
# 141	and	O
# 142	4	O
# 143	,	O
# 144	8	O
# 145	and	O
# 146	12	O
# 147	weeks	O
# 148	after	O
# 149	commencing	O
# 150	radiotherapy	O
# 151	using	O
# 152	valid	O
# 153	and	O
# 154	reliable	O
# 155	tools	O
# 156	.	O
# 157	A	O
# 158	total	O
# 159	of	O
# 160	60	O
# 161	patients	O
# 162	(	O
# 163	51	O
# 164	M	O
# 165	:	O
# 166	9	O
# 167	F	O
# 168	;	O
# 169	mean	O
# 170	age	O
# 171	61.9+	O
# 172	/	O
# 173	-14.0	O
# 174	years	O
# 175	)	O
# 176	were	O
# 177	randomised	O
# 178	to	O
# 179	receive	O
# 180	either	O
# 181	NI	O
# 182	(	O
# 183	n	O
# 184	=	O
# 185	29	O
# 186	)	O
# 187	or	O
# 188	usual	O
# 189	care	O
# 190	(	O
# 191	UC	O
# 192	)	O
# 193	(	O
# 194	n	O
# 195	=	O
# 196	31	O
# 197	)	O
# 198	.	O
# 199	The	B-Premise
# 200	NI	I-Premise
# 201	group	I-Premise
# 202	had	I-Premise
# 203	statistically	I-Premise
# 204	smaller	I-Premise
# 205	deteriorations	I-Premise
# 206	in	I-Premise
# 207	weight	I-Premise
# 208	(	I-Premise
# 209	P	I-Premise
# 210	<	I-Premise
# 211	0.001	I-Premise
# 212	)	I-Premise
# 213	,	I-Premise
# 214	nutritional	I-Premise
# 215	status	I-Premise
# 216	(	I-Premise
# 217	P=	I-Premise
# 218	0.020	I-Premise
# 219	)	I-Premise
# 220	and	I-Premise
# 221	global	I-Premise
# 222	QoL	I-Premise
# 223	(	I-Premise
# 224	P=	I-Premise
# 225	0.009	I-Premise
# 226	)	I-Premise
# 227	compared	I-Premise
# 228	with	I-Premise
# 229	those	I-Premise
# 230	receiving	I-Premise
# 231	UC	I-Premise
# 232	.	O
# 233	Clinically	B-Premise
# 234	,	I-Premise
# 235	but	I-Premise
# 236	not	I-Premise
# 237	statistically	I-Premise
# 238	significant	I-Premise
# 239	differences	I-Premise
# 240	in	I-Premise
# 241	fat-free	I-Premise
# 242	mass	I-Premise
# 243	were	I-Premise
# 244	observed	I-Premise
# 245	between	I-Premise
# 246	the	I-Premise
# 247	groups	I-Premise
# 248	(	I-Premise
# 249	P=	I-Premise
# 250	0.195	I-Premise
# 251	)	I-Premise
# 252	.	O
# 253	Early	B-Claim
# 254	and	I-Claim
# 255	intensive	I-Claim
# 256	NI	I-Claim
# 257	appears	I-Claim
# 258	beneficial	I-Claim
# 259	in	I-Claim
# 260	terms	I-Claim
# 261	of	I-Claim
# 262	minimising	I-Claim
# 263	weight	I-Claim
# 264	loss	I-Claim
# 265	,	I-Claim
# 266	deterioration	I-Claim
# 267	in	I-Claim
# 268	nutritional	I-Claim
# 269	status	I-Claim
# 270	,	I-Claim
# 271	global	I-Claim
# 272	QoL	I-Claim
# 273	and	I-Claim
# 274	physical	I-Claim
# 275	function	I-Claim
# 276	in	I-Claim
# 277	oncology	I-Claim
# 278	outpatients	I-Claim
# 279	receiving	I-Claim
# 280	radiotherapy	I-Claim
# 281	to	I-Claim
# 282	the	I-Claim
# 283	GI	I-Claim
# 284	or	I-Claim
# 285	head	I-Claim
# 286	and	I-Claim
# 287	neck	I-Claim
# 288	area	I-Claim
# 289	.	O
# 290	Weight	B-Claim
# 291	maintenance	I-Claim
# 292	in	I-Claim
# 293	this	I-Claim
# 294	population	I-Claim
# 295	leads	I-Claim
# 296	to	I-Claim
# 297	beneficial	I-Claim
# 298	outcomes	I-Claim
# 299	and	I-Claim
# 300	suggests	I-Claim
# 301	that	I-Claim
# 302	this	I-Claim
# 303	,	I-Claim
# 304	rather	I-Claim
# 305	than	I-Claim
# 306	weight	I-Claim
# 307	gain	I-Claim
# 308	,	I-Claim
# 309	may	I-Claim
# 310	be	I-Claim
# 311	a	I-Claim
# 312	more	I-Claim
# 313	appropriate	I-Claim
# 314	aim	I-Claim
# 315	of	I-Claim
# 316	NI	I-Claim
# 317	.	O
#
# (199, 232)	Support	(253, 289)
# (233, 252)	Support	(253, 289)
#
# 0	Metal	O
# 1	stent	O
# 2	placement	O
# 3	and	O
# 4	single	O
# 5	dose	O
# 6	brachytherapy	O
# 7	are	O
# 8	commonly	O
# 9	used	O
# 10	treatment	O
# 11	modalities	O
# 12	for	O
# 13	the	O
# 14	palliation	O
# 15	of	O
# 16	inoperable	O
# 17	oesophageal	O
# 18	carcinoma	O
# 19	.	O
# 20	We	O
# 21	investigated	O
# 22	generic	O
# 23	and	O
# 24	disease-specific	O
# 25	health-related	O
# 26	quality	O
# 27	of	O
# 28	life	O
# 29	(	O
# 30	HRQoL	O
# 31	)	O
# 32	after	O
# 33	these	O
# 34	palliative	O
# 35	treatments	O
# 36	.	O
# 37	Patients	O
# 38	with	O
# 39	dysphagia	O
# 40	from	O
# 41	inoperable	O
# 42	oesophageal	O
# 43	carcinoma	O
# 44	were	O
# 45	randomised	O
# 46	to	O
# 47	placement	O
# 48	of	O
# 49	a	O
# 50	covered	O
# 51	Ultraflex	O
# 52	stent	O
# 53	(	O
# 54	n	O
# 55	=	O
# 56	108	O
# 57	)	O
# 58	or	O
# 59	single	O
# 60	dose	O
# 61	(	O
# 62	12	O
# 63	Gy	O
# 64	)	O
# 65	brachytherapy	O
# 66	(	O
# 67	n	O
# 68	=	O
# 69	101	O
# 70	)	O
# 71	.	O
# 72	We	O
# 73	obtained	O
# 74	longitudinal	O
# 75	data	O
# 76	on	O
# 77	disease-specific	O
# 78	(	O
# 79	dysphagia	O
# 80	score	O
# 81	,	O
# 82	European	O
# 83	Organisation	O
# 84	for	O
# 85	Research	O
# 86	and	O
# 87	Treatment	O
# 88	of	O
# 89	Cancer	O
# 90	(	O
# 91	EORTC	O
# 92	)	O
# 93	OES	O
# 94	-	O
# 95	23	O
# 96	,	O
# 97	visual	O
# 98	analogue	O
# 99	pain	O
# 100	scale	O
# 101	)	O
# 102	and	O
# 103	generic	O
# 104	(	O
# 105	EORTC	O
# 106	Quality	O
# 107	of	O
# 108	Life-Core	O
# 109	30	O
# 110	Questionnaire	O
# 111	(	O
# 112	QLQ-C	O
# 113	30	O
# 114	)	O
# 115	,	O
# 116	Euroqol	O
# 117	(	O
# 118	EQ	O
# 119	)	O
# 120	-	O
# 121	5D	O
# 122	)	O
# 123	HRQoL	O
# 124	at	O
# 125	monthly	O
# 126	home	O
# 127	visits	O
# 128	by	O
# 129	a	O
# 130	specially-trained	O
# 131	research	O
# 132	nurse	O
# 133	.	O
# 134	We	O
# 135	compared	O
# 136	HRQoL	O
# 137	between	O
# 138	the	O
# 139	two	O
# 140	treatments	O
# 141	and	O
# 142	analysed	O
# 143	changes	O
# 144	in	O
# 145	HRQoL	O
# 146	during	O
# 147	follow-up	O
# 148	.	O
# 149	Dysphagia	B-Premise
# 150	improved	I-Premise
# 151	more	I-Premise
# 152	rapidly	I-Premise
# 153	after	I-Premise
# 154	stent	I-Premise
# 155	placement	I-Premise
# 156	than	I-Premise
# 157	after	I-Premise
# 158	brachytherapy	I-Premise
# 159	,	O
# 160	but	B-Premise
# 161	long-term	I-Premise
# 162	relief	I-Premise
# 163	of	I-Premise
# 164	dysphagia	I-Premise
# 165	was	I-Premise
# 166	better	I-Premise
# 167	after	I-Premise
# 168	brachytherapy	I-Premise
# 169	.	O
# 170	For	B-Premise
# 171	generic	I-Premise
# 172	HRQoL	I-Premise
# 173	,	I-Premise
# 174	there	I-Premise
# 175	was	I-Premise
# 176	an	I-Premise
# 177	overall	I-Premise
# 178	significant	I-Premise
# 179	difference	I-Premise
# 180	in	I-Premise
# 181	favour	I-Premise
# 182	of	I-Premise
# 183	brachytherapy	I-Premise
# 184	on	I-Premise
# 185	four	I-Premise
# 186	out	I-Premise
# 187	of	I-Premise
# 188	five	I-Premise
# 189	functional	I-Premise
# 190	scales	I-Premise
# 191	of	I-Premise
# 192	the	I-Premise
# 193	EORTC	I-Premise
# 194	QLQ-C	I-Premise
# 195	30	I-Premise
# 196	(	I-Premise
# 197	role	I-Premise
# 198	,	I-Premise
# 199	emotional	I-Premise
# 200	,	I-Premise
# 201	cognitive	I-Premise
# 202	and	I-Premise
# 203	social	I-Premise
# 204	)	I-Premise
# 205	(	I-Premise
# 206	P	I-Premise
# 207	<	I-Premise
# 208	0.05	I-Premise
# 209	)	I-Premise
# 210	.	O
# 211	Generic	B-Premise
# 212	HRQoL	I-Premise
# 213	deteriorated	I-Premise
# 214	over	I-Premise
# 215	time	I-Premise
# 216	on	I-Premise
# 217	all	I-Premise
# 218	functional	I-Premise
# 219	scales	I-Premise
# 220	of	I-Premise
# 221	the	I-Premise
# 222	EORTC	I-Premise
# 223	QLQ	I-Premise
# 224	C	I-Premise
# 225	-	I-Premise
# 226	30	I-Premise
# 227	and	I-Premise
# 228	EQ	I-Premise
# 229	-	I-Premise
# 230	5D	I-Premise
# 231	,	I-Premise
# 232	in	I-Premise
# 233	particular	I-Premise
# 234	physical	I-Premise
# 235	and	I-Premise
# 236	role	I-Premise
# 237	functioning	I-Premise
# 238	(	I-Premise
# 239	on	I-Premise
# 240	average	I-Premise
# 241	-	I-Premise
# 242	23	I-Premise
# 243	and	I-Premise
# 244	-	I-Premise
# 245	24	I-Premise
# 246	on	I-Premise
# 247	a	I-Premise
# 248	100	I-Premise
# 249	points	I-Premise
# 250	scale	I-Premise
# 251	during	I-Premise
# 252	0.5	I-Premise
# 253	years	I-Premise
# 254	of	I-Premise
# 255	follow-up	I-Premise
# 256	)	I-Premise
# 257	.	O
# 258	This	B-Premise
# 259	decline	I-Premise
# 260	was	I-Premise
# 261	more	I-Premise
# 262	pronounced	I-Premise
# 263	in	I-Premise
# 264	the	I-Premise
# 265	stent	I-Premise
# 266	group	I-Premise
# 267	.	O
# 268	Major	B-Premise
# 269	improvements	I-Premise
# 270	were	I-Premise
# 271	seen	I-Premise
# 272	on	I-Premise
# 273	the	I-Premise
# 274	dysphagia	I-Premise
# 275	and	I-Premise
# 276	eating	I-Premise
# 277	scales	I-Premise
# 278	of	I-Premise
# 279	the	I-Premise
# 280	EORTC	I-Premise
# 281	OES	I-Premise
# 282	-	I-Premise
# 283	23	I-Premise
# 284	,	I-Premise
# 285	in	I-Premise
# 286	contrast	I-Premise
# 287	to	I-Premise
# 288	other	I-Premise
# 289	scales	I-Premise
# 290	of	I-Premise
# 291	this	I-Premise
# 292	disease-specific	I-Premise
# 293	measure	I-Premise
# 294	,	I-Premise
# 295	which	I-Premise
# 296	remained	I-Premise
# 297	almost	I-Premise
# 298	stable	I-Premise
# 299	during	I-Premise
# 300	follow-up	I-Premise
# 301	.	O
# 302	Reported	B-Premise
# 303	levels	I-Premise
# 304	of	I-Premise
# 305	chest	I-Premise
# 306	or	I-Premise
# 307	abdominal	I-Premise
# 308	pain	I-Premise
# 309	remained	I-Premise
# 310	stable	I-Premise
# 311	during	I-Premise
# 312	follow-up	I-Premise
# 313	in	I-Premise
# 314	both	I-Premise
# 315	treatment	I-Premise
# 316	groups	I-Premise
# 317	,	I-Premise
# 318	general	I-Premise
# 319	pain	I-Premise
# 320	levels	I-Premise
# 321	increased	I-Premise
# 322	to	I-Premise
# 323	a	I-Premise
# 324	minor	I-Premise
# 325	extent	I-Premise
# 326	.	O
# 327	The	B-Claim
# 328	effects	I-Claim
# 329	of	I-Claim
# 330	single	I-Claim
# 331	dose	I-Claim
# 332	brachytherapy	I-Claim
# 333	on	I-Claim
# 334	HRQoL	I-Claim
# 335	compared	I-Claim
# 336	favourably	I-Claim
# 337	to	I-Claim
# 338	those	I-Claim
# 339	of	I-Claim
# 340	stent	I-Claim
# 341	placement	I-Claim
# 342	for	I-Claim
# 343	the	I-Claim
# 344	palliation	I-Claim
# 345	of	I-Claim
# 346	oesophageal	I-Claim
# 347	cancer	I-Claim
# 348	.	O
# 349	Future	B-Claim
# 350	studies	I-Claim
# 351	on	I-Claim
# 352	palliative	I-Claim
# 353	care	I-Claim
# 354	for	I-Claim
# 355	oesophageal	I-Claim
# 356	cancer	I-Claim
# 357	should	I-Claim
# 358	at	I-Claim
# 359	least	I-Claim
# 360	include	I-Claim
# 361	generic	I-Claim
# 362	HRQoL	I-Claim
# 363	scales	I-Claim
# 364	,	O
# 365	since	I-Claim
# 366	these	I-Claim
# 367	were	I-Claim
# 368	more	O
# 369	responsive	I-Claim
# 370	in	I-Claim
# 371	measuring	I-Claim
# 372	patients	I-Claim
# 373	'	I-Claim
# 374	functioning	I-Claim
# 375	and	I-Claim
# 376	well-being	I-Claim
# 377	during	I-Claim
# 378	follow-up	I-Claim
# 379	than	I-Claim
# 380	disease-specific	I-Claim
# 381	HRQoL	I-Claim
# 382	scales	I-Claim
# 383	.	O
#
# (160, 169)	Partial-Attack	(149, 159)
# (258, 267)	Support	(327, 348)
# (211, 257)	Support	(327, 348)
# (170, 210)	Support	(327, 348)
# (365, 383)	Support	(349, 364)
# (349, 364)	Partial-Attack	(327, 348)
# (149, 159)	Support	(327, 348)
# (268, 301)	Support	(327, 348)
# (302, 317)	Support	(327, 348)
# (318, 326)	Support	(327, 348)
#
# 0	The	O
# 1	objective	O
# 2	of	O
# 3	this	O
# 4	study	O
# 5	was	O
# 6	to	O
# 7	compare	O
# 8	the	O
# 9	quality	O
# 10	of	O
# 11	life	O
# 12	(	O
# 13	QoL	O
# 14	)	O
# 15	of	O
# 16	ovarian	O
# 17	cancer	O
# 18	patients	O
# 19	treated	O
# 20	with	O
# 21	paclitaxel	O
# 22	/	O
# 23	carboplatin	O
# 24	(	O
# 25	TC	O
# 26	)	O
# 27	versus	O
# 28	paclitaxel	O
# 29	/	O
# 30	cisplatin	O
# 31	(	O
# 32	PT	O
# 33	)	O
# 34	and	O
# 35	to	O
# 36	determine	O
# 37	the	O
# 38	impact	O
# 39	of	O
# 40	treatment	O
# 41	toxicity	O
# 42	on	O
# 43	the	O
# 44	various	O
# 45	QoL	O
# 46	domains	O
# 47	.	O
# 48	In	O
# 49	this	O
# 50	phase	O
# 51	III	O
# 52	trial	O
# 53	,	O
# 54	798	O
# 55	patients	O
# 56	with	O
# 57	ovarian	O
# 58	cancer	O
# 59	stages	O
# 60	IIB-IV	O
# 61	were	O
# 62	randomly	O
# 63	assigned	O
# 64	to	O
# 65	receive	O
# 66	TC	O
# 67	or	O
# 68	PT	O
# 69	.	O
# 70	The	O
# 71	primary	O
# 72	end	O
# 73	point	O
# 74	was	O
# 75	progression-free	O
# 76	survival	O
# 77	;	O
# 78	secondary	O
# 79	end	O
# 80	points	O
# 81	included	O
# 82	toxicity	O
# 83	,	O
# 84	QoL	O
# 85	,	O
# 86	and	O
# 87	response	O
# 88	to	O
# 89	treatment	O
# 90	.	O
# 91	Patients	O
# 92	completed	O
# 93	the	O
# 94	European	O
# 95	Organisation	O
# 96	for	O
# 97	Research	O
# 98	and	O
# 99	Treatment	O
# 100	of	O
# 101	Cancer	O
# 102	QLQ-C	O
# 103	30	O
# 104	before	O
# 105	treatment	O
# 106	,	O
# 107	within	O
# 108	3	O
# 109	days	O
# 110	before	O
# 111	the	O
# 112	second	O
# 113	and	O
# 114	the	O
# 115	fourth	O
# 116	chemotherapy	O
# 117	cycle	O
# 118	,	O
# 119	and	O
# 120	3	O
# 121	weeks	O
# 122	after	O
# 123	completion	O
# 124	of	O
# 125	chemotherapy	O
# 126	.	O
# 127	Previously	B-Premise
# 128	reported	O
# 129	data	O
# 130	showed	O
# 131	that	O
# 132	patients	I-Premise
# 133	undergoing	I-Premise
# 134	TC	I-Premise
# 135	or	I-Premise
# 136	PT	I-Premise
# 137	did	I-Premise
# 138	not	O
# 139	differ	O
# 140	in	I-Premise
# 141	progression-free	I-Premise
# 142	survival	I-Premise
# 143	and	I-Premise
# 144	overall	I-Premise
# 145	survival	I-Premise
# 146	.	O
# 147	However	B-Premise
# 148	,	O
# 149	the	B-Premise
# 150	TC	I-Premise
# 151	arm	I-Premise
# 152	was	I-Premise
# 153	superior	I-Premise
# 154	,	I-Premise
# 155	indicating	I-Premise
# 156	a	I-Premise
# 157	better	I-Premise
# 158	overall	I-Premise
# 159	QoL	I-Premise
# 160	compared	I-Premise
# 161	with	I-Premise
# 162	the	I-Premise
# 163	PT	I-Premise
# 164	arm	I-Premise
# 165	.	O
# 166	Controlling	B-Premise
# 167	for	I-Premise
# 168	toxicity	I-Premise
# 169	and	I-Premise
# 170	age	I-Premise
# 171	,	I-Premise
# 172	a	I-Premise
# 173	significant	I-Premise
# 174	treatment	I-Premise
# 175	by	I-Premise
# 176	assessment	I-Premise
# 177	time	I-Premise
# 178	interaction	I-Premise
# 179	was	I-Premise
# 180	found	I-Premise
# 181	for	I-Premise
# 182	four	I-Premise
# 183	QoL	I-Premise
# 184	functioning	I-Premise
# 185	scales	I-Premise
# 186	and	I-Premise
# 187	three	I-Premise
# 188	symptoms	I-Premise
# 189	scales	I-Premise
# 190	.	O
# 191	Patients	B-Premise
# 192	in	I-Premise
# 193	the	I-Premise
# 194	TC	I-Premise
# 195	arm	I-Premise
# 196	showed	I-Premise
# 197	better	I-Premise
# 198	means	I-Premise
# 199	scores	I-Premise
# 200	after	I-Premise
# 201	treatment	I-Premise
# 202	on	I-Premise
# 203	overall	I-Premise
# 204	QoL	I-Premise
# 205	(	I-Premise
# 206	P	I-Premise
# 207	=	I-Premise
# 208	.	I-Premise
# 209	012	I-Premise
# 210	)	I-Premise
# 211	,	I-Premise
# 212	physical	I-Premise
# 213	functioning	I-Premise
# 214	(	I-Premise
# 215	P	I-Premise
# 216	=	I-Premise
# 217	.	I-Premise
# 218	012	I-Premise
# 219	)	I-Premise
# 220	,	I-Premise
# 221	role	I-Premise
# 222	functioning	I-Premise
# 223	(	I-Premise
# 224	P	I-Premise
# 225	=	I-Premise
# 226	.	I-Premise
# 227	005	I-Premise
# 228	)	I-Premise
# 229	,	I-Premise
# 230	and	I-Premise
# 231	cognitive	I-Premise
# 232	functioning	I-Premise
# 233	(	I-Premise
# 234	P	I-Premise
# 235	=	I-Premise
# 236	.	I-Premise
# 237	024	I-Premise
# 238	)	I-Premise
# 239	,	I-Premise
# 240	compared	I-Premise
# 241	with	I-Premise
# 242	the	I-Premise
# 243	PT	I-Premise
# 244	arm	I-Premise
# 245	.	O
# 246	Concerning	B-Premise
# 247	symptom	I-Premise
# 248	experience	I-Premise
# 249	,	I-Premise
# 250	patients	I-Premise
# 251	undergoing	I-Premise
# 252	TC	I-Premise
# 253	showed	I-Premise
# 254	less	I-Premise
# 255	nausea	I-Premise
# 256	and	I-Premise
# 257	vomiting	I-Premise
# 258	(	I-Premise
# 259	P	I-Premise
# 260	<	I-Premise
# 261	.	I-Premise
# 262	001	I-Premise
# 263	)	I-Premise
# 264	,	I-Premise
# 265	less	I-Premise
# 266	appetite	I-Premise
# 267	loss	I-Premise
# 268	(	I-Premise
# 269	P	I-Premise
# 270	<	I-Premise
# 271	.	I-Premise
# 272	001	I-Premise
# 273	)	I-Premise
# 274	,	I-Premise
# 275	and	I-Premise
# 276	less	I-Premise
# 277	fatigue	I-Premise
# 278	(	I-Premise
# 279	P	I-Premise
# 280	=	I-Premise
# 281	.	I-Premise
# 282	033	I-Premise
# 283	)	I-Premise
# 284	after	I-Premise
# 285	completion	I-Premise
# 286	of	I-Premise
# 287	treatment	I-Premise
# 288	compared	I-Premise
# 289	with	I-Premise
# 290	patients	I-Premise
# 291	undergoing	I-Premise
# 292	PT	I-Premise
# 293	.	O
# 294	The	B-Claim
# 295	TC	I-Claim
# 296	regimen	I-Claim
# 297	achieved	I-Claim
# 298	better	I-Claim
# 299	QoL	I-Claim
# 300	outcomes	I-Claim
# 301	compared	I-Claim
# 302	with	I-Claim
# 303	the	I-Claim
# 304	PT	I-Claim
# 305	regimen	I-Claim
# 306	.	O
# 307	Thus	B-Claim
# 308	,	I-Claim
# 309	clinicians	I-Claim
# 310	may	I-Claim
# 311	consider	I-Claim
# 312	replacing	I-Claim
# 313	cisplatin	I-Claim
# 314	with	I-Claim
# 315	carboplatin	I-Claim
# 316	when	I-Claim
# 317	treating	I-Claim
# 318	ovarian	I-Claim
# 319	cancer	I-Claim
# 320	patients	I-Claim
# 321	with	I-Claim
# 322	chemotherapy	I-Claim
# 323	.	O
#
# (294, 306)	Support	(307, 323)
# (246, 293)	Support	(294, 306)
# (191, 245)	Support	(294, 306)
#
# 0	To	O
# 1	evaluate	O
# 2	if	O
# 3	raising	O
# 4	baseline	O
# 5	and	O
# 6	maintaining	O
# 7	hemoglobin	O
# 8	(	O
# 9	Hb	O
# 10	)	O
# 11	levels	O
# 12	with	O
# 13	red	O
# 14	blood	O
# 15	cell	O
# 16	(	O
# 17	RBC	O
# 18	)	O
# 19	transfusion	O
# 20	could	O
# 21	improve	O
# 22	the	O
# 23	outcomes	O
# 24	of	O
# 25	chemotherapy	O
# 26	for	O
# 27	advanced	O
# 28	gastric	O
# 29	cancer	O
# 30	(	O
# 31	AGC	O
# 32	)	O
# 33	.	O
# 34	Patients	O
# 35	were	O
# 36	randomized	O
# 37	to	O
# 38	receive	O
# 39	RBC	O
# 40	transfusion	O
# 41	to	O
# 42	maintain	O
# 43	their	O
# 44	Hb	O
# 45	levels	O
# 46	>	O
# 47	or	O
# 48	=	O
# 49	10	O
# 50	g	O
# 51	/	O
# 52	dl	O
# 53	(	O
# 54	arm	O
# 55	1	O
# 56	)	O
# 57	or	O
# 58	>	O
# 59	or	O
# 60	=	O
# 61	12	O
# 62	(	O
# 63	arm	O
# 64	2	O
# 65	)	O
# 66	before	O
# 67	the	O
# 68	start	O
# 69	of	O
# 70	their	O
# 71	5	O
# 72	-	O
# 73	fluorouracil-based	O
# 74	first-line	O
# 75	chemotherapy	O
# 76	.	O
# 77	Objective	O
# 78	response	O
# 79	,	O
# 80	KPS	O
# 81	and	O
# 82	quality	O
# 83	of	O
# 84	life	O
# 85	(	O
# 86	QOL	O
# 87	)	O
# 88	data	O
# 89	were	O
# 90	measured	O
# 91	.	O
# 92	For	O
# 93	87	O
# 94	patients	O
# 95	enrolled	O
# 96	,	O
# 97	mean	O
# 98	baseline	O
# 99	Hb	O
# 100	was	O
# 101	10.1	O
# 102	g	O
# 103	/	O
# 104	dl	O
# 105	,	O
# 106	and	O
# 107	54	O
# 108	patients	O
# 109	received	O
# 110	RBC	O
# 111	prior	O
# 112	to	O
# 113	chemotherapy	O
# 114	initiation	O
# 115	.	O
# 116	Despite	O
# 117	transfusion	O
# 118	,	O
# 119	we	O
# 120	failed	O
# 121	to	O
# 122	maintain	O
# 123	the	O
# 124	Hb	O
# 125	level	O
# 126	above	O
# 127	the	O
# 128	predefined	O
# 129	target	O
# 130	range	O
# 131	.	O
# 132	Eighteen	O
# 133	patients	O
# 134	experienced	O
# 135	brief	O
# 136	and	O
# 137	reversible	O
# 138	adverse	O
# 139	events	O
# 140	during	O
# 141	transfusion	O
# 142	,	O
# 143	including	O
# 144	two	O
# 145	patients	O
# 146	with	O
# 147	acute	O
# 148	pulmonary	O
# 149	edema	O
# 150	.	O
# 151	KPS	B-Premise
# 152	was	I-Premise
# 153	improved	I-Premise
# 154	from	I-Premise
# 155	baseline	I-Premise
# 156	to	I-Premise
# 157	post-chemotherapy	I-Premise
# 158	in	I-Premise
# 159	both	I-Premise
# 160	arms	I-Premise
# 161	.	O
# 162	QOL	B-Premise
# 163	data	I-Premise
# 164	showed	I-Premise
# 165	improvement	I-Premise
# 166	in	I-Premise
# 167	some	I-Premise
# 168	symptom	I-Premise
# 169	scores	I-Premise
# 170	,	O
# 171	but	B-Premise
# 172	there	I-Premise
# 173	was	I-Premise
# 174	no	I-Premise
# 175	difference	I-Premise
# 176	in	I-Premise
# 177	the	I-Premise
# 178	QOL	I-Premise
# 179	scores	I-Premise
# 180	between	I-Premise
# 181	the	I-Premise
# 182	two	I-Premise
# 183	arms	I-Premise
# 184	at	I-Premise
# 185	baseline	I-Premise
# 186	and	I-Premise
# 187	all	I-Premise
# 188	four	I-Premise
# 189	cycles	I-Premise
# 190	of	I-Premise
# 191	treatment	I-Premise
# 192	.	O
# 193	Similar	B-Premise
# 194	response	I-Premise
# 195	rates	I-Premise
# 196	were	I-Premise
# 197	observed	I-Premise
# 198	in	I-Premise
# 199	both	I-Premise
# 200	arms	I-Premise
# 201	(	I-Premise
# 202	arm	I-Premise
# 203	1	I-Premise
# 204	,	I-Premise
# 205	30	I-Premise
# 206	%	I-Premise
# 207	;	I-Premise
# 208	arm	I-Premise
# 209	2	I-Premise
# 210	,	I-Premise
# 211	35	I-Premise
# 212	%	I-Premise
# 213	)	I-Premise
# 214	.	O
# 215	Both	B-Premise
# 216	arms	I-Premise
# 217	showed	I-Premise
# 218	similar	I-Premise
# 219	chemotherapy	I-Premise
# 220	duration	I-Premise
# 221	(	I-Premise
# 222	3.8	I-Premise
# 223	and	I-Premise
# 224	4.1	I-Premise
# 225	months	I-Premise
# 226	,	I-Premise
# 227	respectively	I-Premise
# 228	)	I-Premise
# 229	,	I-Premise
# 230	progression-free	I-Premise
# 231	survival	I-Premise
# 232	(	I-Premise
# 233	4.0	I-Premise
# 234	and	I-Premise
# 235	4.1	I-Premise
# 236	months	I-Premise
# 237	)	I-Premise
# 238	and	I-Premise
# 239	overall	I-Premise
# 240	survival	I-Premise
# 241	(	I-Premise
# 242	9.9	I-Premise
# 243	and	I-Premise
# 244	9.3	I-Premise
# 245	months	I-Premise
# 246	)	I-Premise
# 247	.	O
# 248	Red	B-Claim
# 249	blood	I-Claim
# 250	cell	I-Claim
# 251	transfusion	I-Claim
# 252	achieving	I-Claim
# 253	Hb	I-Claim
# 254	level	I-Claim
# 255	above	I-Claim
# 256	10	I-Claim
# 257	g	I-Claim
# 258	/	I-Claim
# 259	dl	I-Claim
# 260	might	I-Claim
# 261	contribute	I-Claim
# 262	to	I-Claim
# 263	the	I-Claim
# 264	improvement	I-Claim
# 265	of	I-Claim
# 266	the	I-Claim
# 267	KPS	I-Claim
# 268	and	I-Claim
# 269	QOL	I-Claim
# 270	seen	I-Claim
# 271	in	I-Claim
# 272	patients	I-Claim
# 273	with	I-Claim
# 274	AGC	I-Claim
# 275	.	O
# 276	The	B-Claim
# 277	observation	I-Claim
# 278	of	I-Claim
# 279	equivalent	I-Claim
# 280	outcomes	I-Claim
# 281	at	I-Claim
# 282	the	I-Claim
# 283	two	I-Claim
# 284	target	I-Claim
# 285	Hb	I-Claim
# 286	levels	I-Claim
# 287	supports	I-Claim
# 288	the	I-Claim
# 289	feasibility	I-Claim
# 290	of	I-Claim
# 291	anemia	I-Claim
# 292	correction	I-Claim
# 293	to	I-Claim
# 294	Hb	I-Claim
# 295	10	I-Claim
# 296	g	I-Claim
# 297	/	I-Claim
# 298	dl	I-Claim
# 299	,	I-Claim
# 300	which	I-Claim
# 301	merits	I-Claim
# 302	further	I-Claim
# 303	evaluation	I-Claim
# 304	.	O
#
# (171, 192)	Partial-Attack	(162, 170)
# (162, 170)	Support	(248, 275)
# (151, 161)	Support	(248, 275)
# (132, 150)	Support	(248, 275)
# (193, 214)	Support	(276, 304)
# (215, 247)	Support	(276, 304)
#
# 0	This	O
# 1	study	O
# 2	sought	O
# 3	to	O
# 4	continue	O
# 5	research	O
# 6	on	O
# 7	psychosocial	O
# 8	interventions	O
# 9	for	O
# 10	patients	O
# 11	being	O
# 12	treated	O
# 13	with	O
# 14	radiation	O
# 15	therapy	O
# 16	across	O
# 17	multiple	O
# 18	centers	O
# 19	and	O
# 20	to	O
# 21	replicate	O
# 22	positive	O
# 23	findings	O
# 24	of	O
# 25	a	O
# 26	single-center	O
# 27	study	O
# 28	of	O
# 29	patients	O
# 30	being	O
# 31	treated	O
# 32	with	O
# 33	chemotherapy	O
# 34	.	O
# 35	The	O
# 36	primary	O
# 37	objective	O
# 38	of	O
# 39	this	O
# 40	study	O
# 41	was	O
# 42	to	O
# 43	determine	O
# 44	if	O
# 45	a	O
# 46	stress	O
# 47	management	O
# 48	intervention	O
# 49	was	O
# 50	effective	O
# 51	in	O
# 52	improving	O
# 53	quality	O
# 54	of	O
# 55	life	O
# 56	and	O
# 57	decreasing	O
# 58	psychological	O
# 59	distress	O
# 60	in	O
# 61	patients	O
# 62	undergoing	O
# 63	radiotherapy	O
# 64	for	O
# 65	cancer	O
# 66	.	O
# 67	A	O
# 68	total	O
# 69	of	O
# 70	310	O
# 71	patients	O
# 72	about	O
# 73	to	O
# 74	begin	O
# 75	radiotherapy	O
# 76	treatment	O
# 77	were	O
# 78	randomly	O
# 79	assigned	O
# 80	to	O
# 81	receive	O
# 82	usual	O
# 83	care	O
# 84	only	O
# 85	or	O
# 86	self-administered	O
# 87	stress	O
# 88	management	O
# 89	training	O
# 90	.	O
# 91	Quality-of-life	O
# 92	assessments	O
# 93	occurred	O
# 94	at	O
# 95	baseline	O
# 96	and	O
# 97	for	O
# 98	3	O
# 99	weeks	O
# 100	after	O
# 101	the	O
# 102	beginning	O
# 103	of	O
# 104	radiotherapy	O
# 105	treatment	O
# 106	.	O
# 107	Overall	B-Premise
# 108	,	O
# 109	patients	I-Premise
# 110	assigned	I-Premise
# 111	to	I-Premise
# 112	receive	I-Premise
# 113	stress	I-Premise
# 114	management	I-Premise
# 115	training	I-Premise
# 116	did	I-Premise
# 117	not	I-Premise
# 118	report	I-Premise
# 119	significantly	I-Premise
# 120	less	I-Premise
# 121	psychological	I-Premise
# 122	distress	I-Premise
# 123	on	I-Premise
# 124	the	I-Premise
# 125	Medical	I-Premise
# 126	Outcomes	I-Premise
# 127	Study	I-Premise
# 128	36	I-Premise
# 129	-	I-Premise
# 130	Item	I-Premise
# 131	Short	I-Premise
# 132	Form	I-Premise
# 133	(	I-Premise
# 134	SF	I-Premise
# 135	-	I-Premise
# 136	36	I-Premise
# 137	)	I-Premise
# 138	Mental	I-Premise
# 139	Component	I-Premise
# 140	Summary	I-Premise
# 141	Scale	I-Premise
# 142	than	I-Premise
# 143	did	I-Premise
# 144	those	I-Premise
# 145	assigned	I-Premise
# 146	to	I-Premise
# 147	usual	I-Premise
# 148	care	I-Premise
# 149	.	O
# 150	When	B-Premise
# 151	divided	I-Premise
# 152	into	I-Premise
# 153	subgroups	I-Premise
# 154	based	I-Premise
# 155	on	I-Premise
# 156	the	I-Premise
# 157	SF	I-Premise
# 158	-	I-Premise
# 159	36	I-Premise
# 160	Mental	I-Premise
# 161	Component	I-Premise
# 162	Summary	I-Premise
# 163	Scale	I-Premise
# 164	scores	I-Premise
# 165	immediately	I-Premise
# 166	after	I-Premise
# 167	their	I-Premise
# 168	first	I-Premise
# 169	radiotherapy	I-Premise
# 170	treatment	I-Premise
# 171	,	I-Premise
# 172	patients	I-Premise
# 173	with	I-Premise
# 174	above-average	I-Premise
# 175	levels	I-Premise
# 176	of	I-Premise
# 177	psychological	I-Premise
# 178	distress	I-Premise
# 179	(	I-Premise
# 180	scores	I-Premise
# 181	<	I-Premise
# 182	or	I-Premise
# 183	=	I-Premise
# 184	50	I-Premise
# 185	)	I-Premise
# 186	who	I-Premise
# 187	were	I-Premise
# 188	randomly	I-Premise
# 189	assigned	I-Premise
# 190	to	I-Premise
# 191	the	I-Premise
# 192	intervention	I-Premise
# 193	condition	I-Premise
# 194	reported	I-Premise
# 195	significant	I-Premise
# 196	improvement	I-Premise
# 197	in	I-Premise
# 198	their	I-Premise
# 199	distress	I-Premise
# 200	compared	I-Premise
# 201	with	I-Premise
# 202	those	I-Premise
# 203	assigned	I-Premise
# 204	to	I-Premise
# 205	usual	I-Premise
# 206	care	I-Premise
# 207	only	I-Premise
# 208	on	I-Premise
# 209	the	I-Premise
# 210	SF	I-Premise
# 211	-	I-Premise
# 212	36	I-Premise
# 213	Mental	I-Premise
# 214	Health	I-Premise
# 215	Subscale	I-Premise
# 216	and	I-Premise
# 217	the	I-Premise
# 218	Center	I-Premise
# 219	for	I-Premise
# 220	Epidemiologic	I-Premise
# 221	Studies	I-Premise
# 222	Depression	I-Premise
# 223	Scale	I-Premise
# 224	.	O
# 225	This	B-Claim
# 226	study	I-Claim
# 227	found	I-Claim
# 228	that	I-Claim
# 229	self-administered	I-Claim
# 230	stress	I-Claim
# 231	management	I-Claim
# 232	training	I-Claim
# 233	is	I-Claim
# 234	effective	I-Claim
# 235	only	I-Claim
# 236	in	I-Claim
# 237	those	I-Claim
# 238	radiotherapy	I-Claim
# 239	patients	I-Claim
# 240	with	I-Claim
# 241	initially	I-Claim
# 242	higher	I-Claim
# 243	levels	I-Claim
# 244	of	I-Claim
# 245	psychological	I-Claim
# 246	distress	I-Claim
# 247	.	O
# 248	Additional	B-Claim
# 249	research	O
# 250	should	I-Claim
# 251	examine	O
# 252	the	O
# 253	benefits	I-Claim
# 254	of	I-Claim
# 255	stress	I-Claim
# 256	management	I-Claim
# 257	training	I-Claim
# 258	targeted	I-Claim
# 259	specifically	O
# 260	to	I-Claim
# 261	patients	I-Claim
# 262	experiencing	I-Claim
# 263	heightened	I-Claim
# 264	distress	I-Claim
# 265	.	O
#
# (248, 265)	Partial-Attack	(225, 247)
# (107, 149)	Support	(225, 247)
# (172, 224)	Support	(225, 247)
#
# 0	Debilitating	O
# 1	hot	I-Claim
# 2	flushes	I-Claim
# 3	and	I-Claim
# 4	sleep	I-Claim
# 5	dysfunction	I-Claim
# 6	often	I-Claim
# 7	affect	I-Claim
# 8	survivors	I-Claim
# 9	of	I-Claim
# 10	breast	I-Claim
# 11	cancer	I-Claim
# 12	,	I-Claim
# 13	most	I-Claim
# 14	notably	I-Claim
# 15	in	I-Claim
# 16	those	I-Claim
# 17	taking	I-Claim
# 18	anti-oestrogen	I-Claim
# 19	medications	I-Claim
# 20	.	O
# 21	Conventional	B-Claim
# 22	treatments	I-Claim
# 23	have	I-Claim
# 24	been	I-Claim
# 25	only	I-Claim
# 26	partially	I-Claim
# 27	effective	I-Claim
# 28	in	I-Claim
# 29	diminishing	I-Claim
# 30	these	I-Claim
# 31	issues	I-Claim
# 32	,	O
# 33	and	O
# 34	some	I-Claim
# 35	have	I-Claim
# 36	serious	I-Claim
# 37	risks	I-Claim
# 38	.	O
# 39	We	O
# 40	did	O
# 41	a	O
# 42	pilot	O
# 43	study	O
# 44	to	O
# 45	investigate	O
# 46	our	O
# 47	hypothesis	O
# 48	that	O
# 49	stellate-ganglion	O
# 50	block	O
# 51	can	O
# 52	be	O
# 53	a	O
# 54	safe	O
# 55	and	O
# 56	effective	O
# 57	treatment	O
# 58	for	O
# 59	hot	O
# 60	flushes	O
# 61	and	O
# 62	sleep	O
# 63	dysfunction	O
# 64	in	O
# 65	this	O
# 66	patient	O
# 67	population	O
# 68	.	O
# 69	13	O
# 70	survivors	O
# 71	of	O
# 72	breast	O
# 73	cancer	O
# 74	(	O
# 75	in	O
# 76	remission	O
# 77	)	O
# 78	with	O
# 79	severe	O
# 80	hot	O
# 81	flushes	O
# 82	and	O
# 83	night	O
# 84	awakenings	O
# 85	were	O
# 86	treated	O
# 87	with	O
# 88	stellate-ganglion	O
# 89	block	O
# 90	at	O
# 91	the	O
# 92	anterolateral	O
# 93	aspect	O
# 94	of	O
# 95	the	O
# 96	C6	O
# 97	vertebra	O
# 98	on	O
# 99	the	O
# 100	right	O
# 101	side	O
# 102	under	O
# 103	fluoroscopy	O
# 104	.	O
# 105	Patients	O
# 106	recorded	O
# 107	hot	O
# 108	flushes	O
# 109	in	O
# 110	a	O
# 111	daily	O
# 112	diary	O
# 113	by	O
# 114	use	O
# 115	of	O
# 116	the	O
# 117	Hot-Flash	O
# 118	Score	O
# 119	,	O
# 120	devised	O
# 121	by	O
# 122	Sloan	O
# 123	and	O
# 124	colleagues	O
# 125	,	O
# 126	and	O
# 127	night	O
# 128	awakenings	O
# 129	by	O
# 130	use	O
# 131	of	O
# 132	the	O
# 133	Pittsburgh	O
# 134	Sleep	O
# 135	Quality	O
# 136	Index	O
# 137	.	O
# 138	Both	O
# 139	instruments	O
# 140	were	O
# 141	used	O
# 142	1	O
# 143	week	O
# 144	before	O
# 145	the	O
# 146	procedure	O
# 147	[	O
# 148	A40	O
# 149	]	O
# 150	and	O
# 151	then	O
# 152	weekly	O
# 153	after	O
# 154	the	O
# 155	procedure	O
# 156	for	O
# 157	12	O
# 158	weeks	O
# 159	.	O
# 160	We	O
# 161	used	O
# 162	the	O
# 163	generalised-estimating-equations	O
# 164	method	O
# 165	to	O
# 166	analyse	O
# 167	the	O
# 168	longitudinal	O
# 169	measurements	O
# 170	of	O
# 171	the	O
# 172	number	O
# 173	of	O
# 174	hot	O
# 175	flushes	O
# 176	and	O
# 177	night	O
# 178	awakenings	O
# 179	over	O
# 180	time	O
# 181	.	O
# 182	This	B-Claim
# 183	method	I-Claim
# 184	is	I-Claim
# 185	a	I-Claim
# 186	popular	I-Claim
# 187	approach	I-Claim
# 188	to	I-Claim
# 189	analysing	I-Claim
# 190	datasets	O
# 191	that	I-Claim
# 192	have	O
# 193	repeated	O
# 194	measures	O
# 195	from	O
# 196	the	O
# 197	same	O
# 198	person	O
# 199	,	O
# 200	and	I-Claim
# 201	is	I-Claim
# 202	robust	I-Claim
# 203	because	I-Claim
# 204	it	I-Claim
# 205	does	I-Claim
# 206	not	I-Premise
# 207	need	I-Premise
# 208	the	I-Premise
# 209	complete	O
# 210	distribution	I-Premise
# 211	of	I-Premise
# 212	the	O
# 213	outcomes	I-Premise
# 214	to	I-Premise
# 215	be	I-Premise
# 216	specified	I-Premise
# 217	.	O
# 218	This	O
# 219	trial	O
# 220	is	O
# 221	registered	O
# 222	on	O
# 223	the	O
# 224	International	O
# 225	Standard	O
# 226	Randomised	O
# 227	Controlled	O
# 228	Trial	O
# 229	Number	O
# 230	register	O
# 231	(	O
# 232	ISRCTN	O
# 233	14318565	O
# 234	)	O
# 235	.	O
# 236	There	B-Premise
# 237	were	I-Premise
# 238	no	I-Premise
# 239	adverse	I-Premise
# 240	events	I-Premise
# 241	resulting	I-Premise
# 242	from	I-Premise
# 243	the	I-Premise
# 244	stellate-ganglion	I-Premise
# 245	block	I-Premise
# 246	,	I-Premise
# 247	although	I-Premise
# 248	patients	I-Premise
# 249	had	I-Premise
# 250	temporary	I-Premise
# 251	Horner's	I-Premise
# 252	syndrome	I-Premise
# 253	indicating	I-Premise
# 254	the	I-Premise
# 255	effectiveness	I-Premise
# 256	of	I-Premise
# 257	the	I-Premise
# 258	block	I-Premise
# 259	.	O
# 260	Five	B-Premise
# 261	patients	I-Premise
# 262	had	I-Premise
# 263	only	I-Premise
# 264	one	I-Premise
# 265	stellate-ganglion	I-Premise
# 266	block	I-Premise
# 267	and	I-Premise
# 268	eight	I-Premise
# 269	had	I-Premise
# 270	two	I-Premise
# 271	stellate-ganglion	I-Premise
# 272	blocks	I-Premise
# 273	.	O
# 274	The	B-Premise
# 275	total	I-Premise
# 276	number	I-Premise
# 277	of	I-Premise
# 278	hot	I-Premise
# 279	flushes	I-Premise
# 280	decreased	I-Premise
# 281	from	I-Premise
# 282	a	I-Premise
# 283	mean	I-Premise
# 284	of	I-Premise
# 285	79.4	I-Premise
# 286	(	I-Premise
# 287	SD	I-Premise
# 288	37.4	I-Premise
# 289	)	I-Premise
# 290	per	I-Premise
# 291	week	I-Premise
# 292	before	I-Premise
# 293	the	I-Premise
# 294	procedure	I-Premise
# 295	to	I-Premise
# 296	a	I-Premise
# 297	mean	I-Premise
# 298	of	I-Premise
# 299	49.9	I-Premise
# 300	(	I-Premise
# 301	SD	I-Premise
# 302	39.9	I-Premise
# 303	)	I-Premise
# 304	per	I-Premise
# 305	week	I-Premise
# 306	during	I-Premise
# 307	the	I-Premise
# 308	first	I-Premise
# 309	2	I-Premise
# 310	weeks	I-Premise
# 311	after	I-Premise
# 312	the	I-Premise
# 313	procedure	I-Premise
# 314	(	I-Premise
# 315	p=	I-Premise
# 316	0.0002	I-Premise
# 317	)	I-Premise
# 318	.	O
# 319	The	B-Premise
# 320	total	I-Premise
# 321	number	I-Premise
# 322	of	I-Premise
# 323	hot	I-Premise
# 324	flushes	I-Premise
# 325	continued	I-Premise
# 326	to	I-Premise
# 327	decrease	I-Premise
# 328	over	I-Premise
# 329	the	I-Premise
# 330	remaining	I-Premise
# 331	follow-up	I-Premise
# ...
# 238	)	I-Premise
# 239	.	O
# 240	Clinical	B-Premise
# 241	adverse	I-Premise
# 242	events	I-Premise
# 243	of	I-Premise
# 244	≥	I-Premise
# 245	grade	I-Premise
# 246	3	I-Premise
# 247	were	I-Premise
# 248	more	I-Premise
# 249	common	I-Premise
# 250	with	I-Premise
# 251	CET	I-Premise
# 252	/	I-Premise
# 253	BRIV	I-Premise
# 254	than	I-Premise
# 255	with	I-Premise
# 256	CET	I-Premise
# 257	/	I-Premise
# 258	placebo	I-Premise
# 259	,	I-Premise
# 260	including	I-Premise
# 261	fatigue	I-Premise
# 262	(	I-Premise
# 263	25	I-Premise
# 264	%	I-Premise
# 265	vs	I-Premise
# 266	11	I-Premise
# 267	%	I-Premise
# 268	)	I-Premise
# 269	,	I-Premise
# 270	hypertension	I-Premise
# 271	,	I-Premise
# 272	rash	I-Premise
# 273	,	I-Premise
# 274	diarrhea	I-Premise
# 275	,	I-Premise
# 276	abdominal	I-Premise
# 277	pain	I-Premise
# 278	,	I-Premise
# 279	dehydration	I-Premise
# 280	,	I-Premise
# 281	and	I-Premise
# 282	anorexia	I-Premise
# 283	.	O
# 284	Compared	B-Premise
# 285	with	I-Premise
# 286	CET	I-Premise
# 287	/	I-Premise
# 288	placebo	I-Premise
# 289	,	I-Premise
# 290	the	I-Premise
# 291	combination	I-Premise
# 292	of	I-Premise
# 293	CET	I-Premise
# 294	/	I-Premise
# 295	BRIV	I-Premise
# 296	worsened	I-Premise
# 297	time	I-Premise
# 298	to	I-Premise
# 299	QoL	I-Premise
# 300	deterioration	I-Premise
# 301	for	I-Premise
# 302	patients	I-Premise
# 303	with	I-Premise
# 304	K-RAS	I-Claim
# 305	wild-type	I-Claim
# 306	,	I-Claim
# 307	chemotherapy-refractory	I-Claim
# 308	,	I-Claim
# 309	metastatic	I-Claim
# 310	colorectal	I-Claim
# 311	cancer	I-Claim
# 312	on	I-Claim
# 313	the	I-Claim
# 314	PF	I-Claim
# 315	and	I-Claim
# 316	GHS	I-Claim
# 317	scales	I-Claim
# 318	of	I-Claim
# 319	European	I-Claim
# 320	Organization	I-Claim
# 321	for	I-Claim
# 322	Research	I-Claim
# 323	and	I-Claim
# 324	Treatment	I-Claim
# 325	of	I-Claim
# 326	Cancer	I-Claim
# 327	Quality	I-Claim
# 328	of	I-Claim
# 329	Life	I-Claim
# 330	Questionnaire	I-Claim
# 331	C30	I-Claim
# 332	.	O
# 333	This	B-Claim
# 334	result	I-Claim
# 335	may	I-Claim
# 336	be	I-Claim
# 337	due	I-Claim
# 338	to	I-Claim
# 339	higher	I-Claim
# 340	rates	I-Claim
# 341	of	I-Claim
# 342	fatigue	I-Claim
# 343	and	I-Claim
# 344	gastrointestinal	I-Claim
# 345	adverse	I-Claim
# 346	events	I-Claim
# 347	.	O
#
# (151, 188)	Support	(284, 332)
# (189, 214)	Support	(284, 332)
# (333, 347)	Partial-Attack	(284, 332)
# (240, 283)	Support	(333, 347)
#
# 0	Surgical	O
# 1	resection	I-Claim
# 2	enhances	I-Claim
# 3	long-term	I-Claim
# 4	survival	I-Claim
# 5	after	I-Claim
# 6	lung	I-Claim
# 7	cancer	I-Claim
# 8	,	I-Claim
# 9	but	I-Claim
# 10	survivors	I-Claim
# 11	face	I-Claim
# 12	functional	I-Claim
# 13	deficits	I-Claim
# 14	and	I-Claim
# 15	report	I-Claim
# 16	on	I-Claim
# 17	poor	I-Claim
# 18	quality	I-Claim
# 19	of	I-Claim
# 20	life	I-Claim
# 21	long	I-Claim
# 22	time	I-Claim
# 23	after	I-Claim
# 24	surgery	I-Claim
# 25	.	O
# 26	This	O
# 27	study	O
# 28	evaluated	O
# 29	short	O
# 30	and	O
# 31	long-term	O
# 32	effects	O
# 33	of	O
# 34	supervised	O
# 35	group	O
# 36	exercise	O
# 37	training	O
# 38	on	O
# 39	health-related	O
# 40	quality	O
# 41	of	O
# 42	life	O
# 43	and	O
# 44	physical	O
# 45	performance	O
# 46	in	O
# 47	patients	O
# 48	,	O
# 49	who	O
# 50	were	O
# 51	radically	O
# 52	operated	O
# 53	for	O
# 54	lung	O
# 55	cancer	O
# 56	.	O
# 57	A	O
# 58	randomized	O
# 59	,	O
# 60	assessor-blinded	O
# 61	,	O
# 62	controlled	O
# 63	trial	O
# 64	was	O
# 65	performed	O
# 66	on	O
# 67	78	O
# 68	patients	O
# 69	undergoing	O
# 70	lung	O
# 71	cancer	O
# 72	surgery	O
# 73	.	O
# 74	The	O
# 75	intervention	O
# 76	group	O
# 77	(	O
# 78	IG	O
# 79	,	O
# 80	n	O
# 81	=	O
# 82	41	O
# 83	)	O
# 84	participated	O
# 85	in	O
# 86	supervised	O
# 87	out-patient	O
# 88	exercise	O
# 89	training	O
# 90	sessions	O
# 91	,	O
# 92	one	O
# 93	hour	O
# 94	once	O
# 95	a	O
# 96	week	O
# 97	for	O
# 98	ten	O
# 99	weeks	O
# 100	.	O
# 101	The	O
# 102	sessions	O
# 103	were	O
# 104	based	O
# 105	on	O
# 106	aerobic	O
# 107	exercises	O
# 108	with	O
# 109	target	O
# 110	intensity	O
# 111	of	O
# 112	60-80	O
# 113	%	O
# 114	of	O
# 115	work	O
# 116	capacity	O
# 117	,	O
# 118	resistance	O
# 119	training	O
# 120	and	O
# 121	dyspnoea	O
# 122	management	O
# 123	.	O
# 124	The	O
# 125	control	O
# 126	group	O
# 127	(	O
# 128	CG	O
# 129	,	O
# 130	n	O
# 131	=	O
# 132	37	O
# 133	)	O
# 134	received	O
# 135	one	O
# 136	individual	O
# 137	instruction	O
# 138	in	O
# 139	exercise	O
# 140	training	O
# 141	.	O
# 142	Measurements	O
# 143	consisted	O
# 144	of	O
# 145	:	O
# 146	health-related	O
# 147	quality	O
# 148	of	O
# 149	life	O
# 150	(	O
# 151	SF36	O
# 152	)	O
# 153	,	O
# 154	six	O
# 155	minute	O
# 156	walk	O
# 157	test	O
# 158	(	O
# 159	6MWT	O
# 160	)	O
# 161	and	O
# 162	lung	O
# 163	function	O
# 164	(	O
# 165	spirometry	O
# 166	)	O
# 167	,	O
# 168	assessed	O
# 169	three	O
# 170	weeks	O
# 171	after	O
# 172	surgery	O
# 173	and	O
# 174	after	O
# 175	four	O
# 176	and	O
# 177	twelve	O
# 178	months	O
# 179	.	O
# 180	Both	B-Premise
# 181	groups	O
# 182	were	O
# 183	comparable	O
# 184	at	O
# 185	baseline	O
# 186	on	O
# 187	demographic	O
# 188	characteristic	O
# 189	and	O
# 190	outcome	O
# 191	values	O
# 192	.	O
# 193	We	B-Premise
# 194	found	I-Premise
# 195	a	I-Premise
# 196	statistically	I-Premise
# 197	significant	I-Premise
# 198	effect	I-Premise
# 199	after	I-Premise
# 200	four	I-Premise
# 201	months	I-Premise
# 202	in	I-Premise
# 203	the	I-Premise
# 204	bodily	I-Premise
# 205	pain	I-Premise
# 206	domain	I-Premise
# 207	of	I-Premise
# 208	SF36	I-Premise
# 209	,	I-Premise
# 210	with	I-Premise
# 211	an	I-Premise
# 212	estimated	I-Premise
# 213	mean	I-Premise
# 214	difference	I-Premise
# 215	(	I-Premise
# 216	EMD	I-Premise
# 217	)	I-Premise
# 218	of	I-Premise
# 219	15.3	I-Premise
# 220	(	I-Premise
# 221	95	I-Premise
# 222	%	I-Premise
# 223	CI	I-Premise
# 224	:	I-Premise
# 225	4	I-Premise
# 226	to	I-Premise
# 227	26.6	I-Premise
# 228	,	I-Premise
# 229	p=	I-Premise
# 230	0.01	I-Premise
# 231	)	I-Premise
# 232	and	I-Premise
# 233	a	I-Premise
# 234	trend	I-Premise
# 235	in	I-Premise
# 236	favour	I-Premise
# 237	of	I-Premise
# 238	the	I-Premise
# 239	intervention	I-Premise
# 240	for	I-Premise
# 241	role	I-Premise
# 242	physical	I-Premise
# 243	functioning	I-Premise
# 244	(	I-Premise
# 245	EMD	I-Premise
# 246	12.04	I-Premise
# 247	,	I-Premise
# 248	95	I-Premise
# 249	%	I-Premise
# 250	CI	I-Premise
# 251	:	I-Premise
# 252	-	I-Premise
# 253	1	I-Premise
# 254	to	I-Premise
# 255	25.1	I-Premise
# 256	,	I-Premise
# 257	p=	I-Premise
# 258	0.07	I-Premise
# 259	)	I-Premise
# 260	and	I-Premise
# 261	physical	I-Premise
# 262	component	I-Premise
# 263	summary	I-Premise
# 264	(	I-Premise
# 265	EMD	I-Premise
# 266	3.76	I-Premise
# 267	,	I-Premise
# 268	95	I-Premise
# 269	%	I-Premise
# 270	CI	I-Premise
# 271	:	I-Premise
# 272	-0.1	I-Premise
# 273	to	I-Premise
# 274	7.6	I-Premise
# 275	,	I-Premise
# 276	p=	I-Premise
# 277	0.06	I-Premise
# 278	)	I-Premise
# 279	.	O
# 280	At	B-Premise
# 281	12	I-Premise
# 282	months	I-Premise
# 283	,	I-Premise
# 284	the	I-Premise
# 285	tendency	I-Premise
# 286	was	I-Premise
# 287	reversed	I-Premise
# 288	,	I-Premise
# 289	with	I-Premise
# 290	the	I-Claim
# 291	CG	I-Claim
# 292	presenting	I-Claim
# 293	overall	I-Premise
# 294	slightly	I-Premise
# 295	better	I-Claim
# 296	measures	I-Claim
# 297	.	O
# 298	We	B-Premise
# 299	found	I-Premise
# 300	no	I-Premise
# 301	effect	I-Premise
# 302	of	I-Premise
# 303	the	I-Premise
# 304	intervention	I-Premise
# 305	on	I-Premise
# 306	6MWT	I-Premise
# 307	or	I-Premise
# 308	lung	I-Premise
# 309	volumes	I-Premise
# 310	at	I-Premise
# 311	any	I-Premise
# 312	time-point	I-Premise
# 313	.	O
# 314	Supervised	B-Premise
# 315	compared	I-Claim
# 316	to	I-Claim
# 317	unsupervised	I-Claim
# 318	exercise	I-Claim
# 319	training	I-Claim
# 320	resulted	I-Claim
# 321	in	I-Claim
# 322	no	I-Premise
# 323	improvement	I-Claim
# 324	in	I-Claim
# 325	health-related	I-Claim
# 326	quality	I-Claim
# 327	of	I-Claim
# 328	life	I-Claim
# 329	,	I-Premise
# 330	except	I-Premise
# 331	for	I-Premise
# 332	the	I-Premise
# 333	bodily	I-Claim
# 334	pain	I-Claim
# 335	domain	I-Premise
# 336	,	I-Premise
# 337	four	I-Premise
# 338	months	I-Claim
# 339	after	I-Premise
# 340	lung	I-Claim
# 341	cancer	I-Claim
# 342	surgery	I-Claim
# 343	.	O
# 344	No	B-Premise
# 345	effects	I-Claim
# 346	of	I-Claim
# 347	the	I-Claim
# 348	intervention	I-Claim
# 349	were	I-Claim
# 350	found	I-Claim
# 351	for	I-Claim
# 352	any	I-Claim
# 353	outcome	I-Claim
# 354	after	I-Premise
# 355	one	I-Premise
# 356	year	I-Premise
# 357	.	O
#
# (330, 343)	Partial-Attack	(314, 329)
# (298, 313)	Support	(344, 357)
# (314, 329)	Support	(344, 357)
# (280, 297)	Attack	(193, 279)
# (193, 279)	Attack	(344, 357)
#
# 0	To	O
# 1	compare	O
# 2	two	O
# 3	cisplatin	O
# 4	based	O
# 5	chemotherapy	O
# 6	schedules	O
# 7	in	O
# 8	patients	O
# 9	with	O
# 10	advanced	O
# 11	non-small-cell	O
# 12	lung	O
# 13	cancer	O
# 14	(	O
# 15	NSCLC	O
# 16	)	O
# 17	.	O
# 18	A	O
# 19	total	O
# 20	of	O
# 21	332	O
# 22	patients	O
# 23	with	O
# 24	advanced	O
# 25	NSCLC	O
# 26	were	O
# 27	randomized	O
# 28	to	O
# 29	receive	O
# 30	cisplatin	O
# 31	80	O
# 32	mg	O
# 33	/	O
# 34	m2	O
# 35	on	O
# 36	day	O
# 37	1	O
# 38	either	O
# 39	in	O
# 40	combination	O
# 41	with	O
# 42	teniposide	O
# 43	100	O
# 44	mg	O
# 45	/	O
# 46	m2	O
# 47	on	O
# 48	days	O
# 49	1	O
# 50	,	O
# 51	3	O
# 52	,	O
# 53	and	O
# 54	5	O
# 55	(	O
# 56	arm	O
# 57	A	O
# 58	)	O
# 59	or	O
# 60	paclitaxel	O
# 61	175	O
# 62	mg	O
# 63	/	O
# 64	m2	O
# 65	by	O
# 66	3	O
# 67	-	O
# 68	hour	O
# 69	infusion	O
# 70	on	O
# 71	day	O
# 72	1	O
# 73	(	O
# 74	arm	O
# 75	B	O
# 76	);	O
# 77	cycles	O
# 78	were	O
# 79	repeated	O
# 80	every	O
# 81	3	O
# 82	weeks	O
# 83	.	O
# 84	Fifteen	O
# 85	patients	O
# 86	were	O
# 87	ineligible	O
# 88	;	O
# 89	patient	O
# 90	characteristics	O
# 91	were	O
# 92	well	O
# 93	balanced	O
# 94	between	O
# 95	the	O
# 96	two	O
# 97	arms	O
# 98	:	O
# 99	71	O
# 100	%	O
# 101	were	O
# 102	male	O
# 103	,	O
# 104	71	O
# 105	%	O
# 106	had	O
# 107	less	O
# 108	than	O
# 109	5	O
# 110	%	O
# 111	weight	O
# 112	loss	O
# 113	,	O
# 114	89	O
# 115	%	O
# 116	had	O
# 117	a	O
# 118	World	O
# 119	Health	O
# 120	Organization	O
# 121	(	O
# 122	WHO	O
# 123	)	O
# 124	performance	O
# 125	status	O
# 126	of	O
# 127	0	O
# 128	to	O
# 129	1	O
# 130	,	O
# 131	51	O
# 132	%	O
# 133	had	O
# 134	adenocarcinoma	O
# 135	,	O
# 136	and	O
# 137	61	O
# 138	%	O
# 139	had	O
# 140	stage	O
# 141	IV	O
# 142	disease	O
# 143	.	O
# 144	Hematologic	B-Premise
# 145	toxicity	I-Premise
# 146	was	I-Premise
# 147	significantly	I-Premise
# 148	more	I-Premise
# 149	severe	I-Premise
# 150	in	I-Premise
# 151	arm	I-Premise
# 152	A	I-Premise
# 153	(	I-Premise
# 154	leukopenia	I-Premise
# 155	,	I-Premise
# 156	neutropenia	I-Premise
# 157	,	I-Premise
# 158	and	I-Premise
# 159	thrombocytopenia	I-Premise
# 160	grade	I-Premise
# 161	3	I-Premise
# 162	or	I-Premise
# 163	4	I-Premise
# 164	:	I-Premise
# 165	66	I-Premise
# 166	%	I-Premise
# 167	v	I-Premise
# 168	19	I-Premise
# 169	%	I-Premise
# 170	,	I-Premise
# 171	83	I-Premise
# 172	%	I-Premise
# 173	v	I-Premise
# 174	55	I-Premise
# 175	%	I-Premise
# 176	,	I-Premise
# 177	36	I-Premise
# 178	%	I-Premise
# 179	v	I-Premise
# 180	2	I-Premise
# 181	%	I-Premise
# 182	in	I-Premise
# 183	arms	I-Premise
# 184	A	I-Premise
# 185	and	I-Premise
# 186	B	I-Premise
# 187	,	I-Premise
# 188	respectively	I-Premise
# 189	)	I-Premise
# 190	,	I-Premise
# 191	which	I-Premise
# 192	resulted	I-Premise
# 193	in	I-Premise
# 194	more	I-Premise
# 195	febrile	I-Premise
# 196	neutropenia	I-Premise
# 197	(	I-Premise
# 198	27	I-Premise
# 199	%	I-Premise
# 200	v	I-Premise
# 201	3	I-Premise
# 202	%	I-Premise
# 203	in	I-Premise
# 204	arms	I-Premise
# 205	A	I-Premise
# 206	and	I-Premise
# 207	B	I-Premise
# 208	,	I-Premise
# 209	respectively	I-Premise
# 210	)	I-Premise
# 211	,	I-Premise
# 212	dose	I-Premise
# 213	reductions	I-Premise
# 214	,	I-Premise
# 215	and	I-Premise
# 216	treatment	I-Premise
# 217	delays	I-Premise
# 218	.	O
# 219	There	B-Premise
# 220	were	I-Premise
# 221	a	I-Premise
# 222	total	I-Premise
# 223	of	I-Premise
# 224	nine	I-Premise
# 225	toxic	I-Premise
# 226	deaths	I-Premise
# 227	,	I-Premise
# 228	six	I-Premise
# 229	due	I-Premise
# 230	to	I-Premise
# 231	neutropenic	I-Premise
# 232	sepsis	I-Premise
# 233	:	I-Premise
# 234	five	I-Premise
# 235	in	I-Premise
# 236	arm	I-Premise
# 237	A	I-Premise
# 238	and	I-Premise
# 239	one	I-Premise
# 240	in	I-Premise
# 241	arm	I-Premise
# 242	B	I-Premise
# 243	.	O
# 244	In	B-Premise
# 245	contrast	B-Premise
# 246	,	I-Premise
# 247	arthralgia	I-Premise
# 248	/	I-Premise
# 249	myalgia	I-Premise
# 250	(	I-Premise
# 251	grade	I-Premise
# 252	2	I-Premise
# 253	or	I-Premise
# 254	3	I-Premise
# 255	,	I-Premise
# 256	4	I-Premise
# 257	%	I-Premise
# 258	v	I-Premise
# 259	17	I-Premise
# 260	%	I-Premise
# 261	)	I-Premise
# 262	,	I-Premise
# 263	peripheral	I-Premise
# 264	neurotoxicity	I-Premise
# 265	(	I-Premise
# 266	grade	I-Premise
# 267	2	I-Premise
# 268	or	I-Premise
# 269	3	I-Premise
# 270	,	I-Premise
# 271	6	I-Premise
# 272	%	I-Premise
# 273	v	I-Premise
# 274	29	I-Premise
# 275	%	I-Premise
# 276	)	I-Premise
# 277	,	I-Premise
# 278	and	I-Premise
# 279	hypersensitivity	I-Premise
# 280	reactions	I-Premise
# 281	(	I-Premise
# 282	1	I-Premise
# 283	%	I-Premise
# 284	v	I-Premise
# 285	7	I-Premise
# 286	%	I-Premise
# 287	,	I-Premise
# 288	all	I-Premise
# 289	grades	I-Premise
# 290	)	I-Premise
# 291	were	I-Premise
# 292	significantly	I-Premise
# 293	more	I-Premise
# 294	frequent	I-Premise
# 295	in	I-Premise
# 296	arm	I-Premise
# 297	B	I-Premise
# 298	.	O
# 299	The	B-Premise
# 300	frequency	I-Premise
# 301	and	I-Premise
# 302	severity	I-Premise
# 303	of	I-Premise
# 304	other	I-Premise
# 305	toxicities	I-Premise
# 306	were	I-Premise
# 307	comparable	I-Premise
# 308	between	I-Premise
# 309	the	I-Premise
# 310	two	I-Premise
# 311	arms	I-Premise
# 312	.	O
# 313	Responses	B-Premise
# 314	were	I-Premise
# 315	one	I-Premise
# 316	complete	I-Premise
# 317	and	I-Premise
# 318	44	I-Premise
# 319	partial	I-Premise
# 320	on	I-Premise
# 321	arm	I-Premise
# 322	A	I-Premise
# 323	(	I-Premise
# 324	28	I-Premise
# 325	%	I-Premise
# 326	)	I-Premise
# 327	and	I-Premise
# 328	two	I-Premise
# 329	complete	I-Premise
# 330	and	I-Premise
# 331	61	I-Premise
# 332	partial	I-Premise
# 333	(	I-Premise
# 334	41	I-Premise
# 335	%	I-Premise
# 336	)	I-Premise
# 337	on	I-Premise
# 338	arm	I-Premise
# 339	B	I-Premise
# 340	(	I-Premise
# 341	P	I-Premise
# 342	=	I-Premise
# 343	.	I-Premise
# 344	018	I-Premise
# 345	)	I-Premise
# 346	.	O
# 347	There	B-Premise
# 348	was	I-Premise
# 349	no	I-Premise
# 350	significant	I-Premise
# 351	difference	I-Premise
# 352	in	I-Premise
# 353	survival	I-Premise
# 354	,	I-Premise
# 355	with	I-Premise
# 356	median	I-Premise
# 357	and	I-Premise
# 358	1	I-Premise
# 359	-	I-Premise
# 360	year	I-Premise
# 361	survivals	I-Premise
# 362	9.9	I-Premise
# 363	versus	I-Premise
# 364	9.7	I-Premise
# 365	months	I-Premise
# 366	and	I-Premise
# 367	41	I-Premise
# 368	%	I-Premise
# 369	versus	I-Premise
# 370	43	I-Premise
# 371	%	I-Premise
# 372	,	I-Premise
# 373	respectively	I-Premise
# 374	in	I-Premise
# 375	arm	I-Premise
# 376	A	I-Premise
# 377	and	I-Premise
# 378	B	I-Premise
# 379	.	O
# 380	Progression-free	B-Premise
# 381	survival	I-Premise
# 382	was	I-Premise
# 383	4.9	I-Premise
# 384	and	I-Premise
# 385	5.4	I-Premise
# 386	months	I-Premise
# 387	in	I-Premise
# 388	arm	I-Premise
# 389	A	I-Premise
# 390	and	I-Premise
# 391	B	I-Premise
# 392	,	I-Premise
# 393	respectively	I-Premise
# 394	.	O
# 395	Selected	O
# 396	centers	O
# 397	participated	O
# 398	in	O
# 399	a	O
# 400	quality-of-life	O
# 401	(	O
# 402	QoL	O
# 403	)	O
# 404	assessment	O
# 405	,	O
# 406	which	O
# 407	was	O
# 408	performed	O
# 409	by	O
# 410	the	O
# 411	European	O
# 412	Organization	O
# 413	for	O
# 414	Research	O
# 415	and	O
# 416	Treatment	O
# 417	of	O
# 418	Cancer	O
# 419	(	O
# 420	EORTC	O
# 421	)	O
# 422	QLQ-C	O
# 423	30	O
# 424	and	O
# 425	LC	O
# 426	-	O
# 427	13	O
# 428	administered	O
# 429	at	O
# 430	baseline	O
# 431	and	O
# 432	every	O
# 433	6	O
# 434	weeks	O
# 435	thereafter	O
# 436	.	O
# 437	Arm	B-Premise
# 438	B	B-Premise
# 439	achieved	I-Premise
# 440	a	I-Premise
# 441	better	I-Premise
# 442	score	I-Premise
# 443	at	I-Premise
# 444	week	I-Premise
# 445	6	I-Premise
# 446	for	I-Premise
# 447	emotional	I-Premise
# 448	,	I-Premise
# 449	cognitive	I-Premise
# 450	and	I-Premise
# 451	social	I-Premise
# 452	functioning	I-Premise
# 453	,	I-Premise
# 454	global	I-Premise
# 455	health	I-Premise
# 456	status	I-Premise
# 457	,	I-Premise
# 458	fatigue	I-Premise
# 459	,	I-Premise
# 460	and	I-Premise
# 461	appetite	I-Premise
# 462	loss	I-Premise
# 463	,	I-Premise
# 464	which	I-Premise
# 465	was	I-Premise
# 466	lost	I-Premise
# 467	at	I-Premise
# 468	12	I-Premise
# 469	weeks	I-Premise
# 470	.	O
# 471	In	O
# 472	conclusion	O
# 473	,	O
# 474	arm	I-Claim
# 475	B	I-Claim
# 476	appears	I-Claim
# 477	superior	I-Claim
# 478	to	I-Claim
# 479	arm	I-Claim
# 480	A	I-Claim
# 481	with	I-Claim
# 482	regard	I-Claim
# 483	to	I-Claim
# 484	response	I-Claim
# 485	rate	I-Claim
# 486	,	I-Claim
# 487	side	I-Claim
# 488	effects	I-Claim
# 489	,	I-Claim
# 490	and	I-Claim
# 491	QoL	I-Claim
# 492	.	O
# 493	Although	B-Premise
# 494	survival	I-Claim
# 495	was	I-Claim
# 496	not	O
# 497	improved	I-Claim
# 498	,	I-Claim
# 499	arm	I-Claim
# 500	B	I-Claim
# 501	offers	I-Claim
# 502	a	I-Claim
# 503	better	I-Claim
# 504	palliation	I-Claim
# 505	for	I-Claim
# 506	advanced	I-Claim
# 507	NSCLC	I-Claim
# 508	patients	I-Claim
# 509	than	I-Claim
# 510	arm	I-Claim
# 511	A	I-Claim
# 512	.	O
#
# (493, 498)	Partial-Attack	(499, 512)
# (437, 470)	Support	(471, 492)
# (380, 394)	Support	(493, 498)
# (347, 379)	Support	(493, 498)
# (313, 346)	Support	(471, 492)
# (219, 243)	Support	(299, 312)
# (244, 298)	Partial-Attack	(299, 312)
# (144, 218)	Partial-Attack	(299, 312)
#
# --------------------------------------------------------------------------------
#
#     num tokens     = 8423
#     num parags     = 72
#     num documents  = 24

# %%
# !python evaluate.py abstrct_neoplasm_predictions_llm.json abstrct_neoplasm_test.json
# Out:
# ********************** SPANS ***************************
#    STRICT EVALUATION
#     > Argument mining spans (unlabeled)
#       Precision : 0.6514414983164982
#       Recall    : 0.7160428691678691
#       F-score   : 0.6739365958115958
#     > Argument mining spans (labeled)
#       Precision : 0.6263392857142857
#       Recall    : 0.6877840909090908
#       F-score   : 0.6474190161690161
#
#     RELAXED EVALUATION (α = 0.5)
#     > Argument mining spans (unlabeled)
#       Precision : 0.702831080956081
#       Recall    : 0.8294748075998076
#       F-score   : 0.752459641536654
#     > Argument mining spans (labeled)
#       Precision : 0.6732956857956859
#       Recall    : 0.7787292568542569
#       F-score   : 0.7142452211531158
#
#
#
# ******************* RELATIONS ***************************
#    STRICT EVALUATION
#     > Argument mining spans (unlabeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#     > Argument mining spans (labeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#
#     RELAXED EVALUATION (α = 0.5)
#     > Argument mining spans (unlabeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0
#     > Argument mining spans (labeled)
#       Precision : 1.0
#       Recall    : 1.0
#       F-score   : 1.0

# %%
# Load test data and generate predictions
with open("abstrct_glaucoma_test.json", "r") as f:
    test_data = json.load(f)

sentences, _ = build_data(test_data, tag2idx)

predictions = predict_labels(
    paragraphs=sentences,
    model=ner_model,
    tokenizer=tokenizer,
    idx2tag=idx2tag,
    device=device
)

create_predictions_json(predictions, test_data, "abstrct_glaucoma_predictions_llm.json")
# !python evaluate.py abstrct_glaucoma_predictions_llm.json abstrct_glaucoma_test.json
# Out:
# Complete JSON file saved at: abstrct_glaucoma_predictions_llm.json
# [error] division by zero

# %%
# Load test data and generate predictions
with open("abstrct_mixed_test.json", "r") as f:
    test_data = json.load(f)

sentences, _ = build_data(test_data, tag2idx)

predictions = predict_labels(
    paragraphs=sentences,
    model=ner_model,
    tokenizer=tokenizer,
    idx2tag=idx2tag,
    device=device
)
create_predictions_json(predictions, test_data, "abstrct_mixed_predictions_llm.json")
# !python evaluate.py abstrct_mixed_predictions_llm.json abstrct_mixed_test.json
# Out:
# Complete JSON file saved at: abstrct_mixed_predictions_llm.json
# [error] division by zero
